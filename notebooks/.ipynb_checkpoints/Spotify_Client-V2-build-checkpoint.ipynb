# %%
#!pip install requests
#!pip install print-dict
# Out:
# Requirement already satisfied: print-dict in c:\users\ikenx\.virtualenvs\spotify_api-qjjjxr6y\lib\site-packages (0.1.19)
# Requirement already satisfied: yapf<0.31.0,>=0.30.0 in c:\users\ikenx\.virtualenvs\spotify_api-qjjjxr6y\lib\site-packages (from print-dict) (0.30.0)

# %%
import base64
import datetime
from urllib.parse import urlencode
import requests as rq
import webbrowser
from print_dict import pd
import os
from dotenv import load_dotenv

# %%
#Client Info
load_dotenv("./config.env")
client_secret = os.getenv("CLIENT_SECRET")
client_id = os.getenv("CLIENT_ID")

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = "https://accounts.spotify.com/api/token"
    auth_url = "https://accounts.spotify.com/authorize"
    baseURL = 'https://api.spotify.com/v1'
    auth_code = None
    refresh_token = None
    
    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret
        self.perform_login()
    
    def get_client_credentials(self):
        """
        Returns a base64 string
        """
        client_id = self.client_id
        client_secret = self.client_secret
        if client_secret == None or client_id == None:
            raise Exception("You must set client_id and client_secret.")
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
    
    def get_token_headers(self):
        
        client_creds_b64 = self.get_client_credentials()
        return {
            "Authorization": f"Basic {client_creds_b64}"
        }
    
    def get_auth_data(self):
        auth_data = {
            'client_id' : self.client_id,
            'response_type' : 'code',
            'redirect_uri' : 'http://localhost:3000/',
            'scope' : 'playlist-read-private playlist-read-collaborative playlist-modify-public playlist-modify-private'
            }
        return auth_data
    
    def perform_login(self):
        response = rq.get(self.auth_url, params=self.get_auth_data())
        if response.status_code not in range(200, 299):
            raise Exception("Could not login!")
        webbrowser.open(response.url)
    
    def parse_url_for_code(self, redirect_url=None):
        #parse URL for code
        if redirect_url == None:
            raise Exception("Invalid URL")
        response_url = redirect_url
        split_url = response_url.split('?')
        split_url = split_url[1].split('=')
        #print(split_url)
        auth_code1 = split_url[1]
        #return auth_code
        self.auth_code = auth_code1
        self.get_initial_access_token()
    
    def get_initial_token_data(self):
        token_data = {
            'grant_type' : "authorization_code",
            'code' : self.auth_code,
            'redirect_uri' : 'http://localhost:3000/',
            'client_id' : client_id,
            'client_secret': client_secret
        }
        return token_data
    
    def get_initial_access_token(self):
        auth_response = rq.post(url=self.token_url, data=self.get_initial_token_data())
        if auth_response.status_code not in range(200, 299):
            raise Exception("Could not get initial access token")
        s = auth_response.json()
        now = datetime.datetime.now()
        self.access_token = s['access_token']
        self.refresh_token = s['refresh_token']
        expires_in = s['expires_in']
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True 
    
    
    def get_refresh_token_data(self):
#         return {
#             'grant_type' : "client_credentials"
#         }
        refresh_data= {
            'grant_type':'refresh_token',
            'refresh_token': self.refresh_token,
            'client_id' : client_id,
            'client_secret': client_secret
        }
        return refresh_data

    
    def perform_auth(self):
        token_url = self.token_url
        refresh_data = self.get_refresh_token_data()
        token_headers = self.get_token_headers()
        
        r = rq.post(url=token_url, data=refresh_data)
        #r = rq.post(token_url, data=token_data, headers=token_headers)
        #print(r.json())
        if r.status_code not in range(200, 299):
            raise Exception("Could not authenticate client.")
            #return False
        data = r.json()
        now = datetime.datetime.now()
        refresh_token = data['access_token']
        expires_in = data['expires_in']
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token = refresh_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True

    def get_access_token(self):
#         auth_done = self.perform_auth()
#         if not auth_done:
#             raise Exception("Authentication failed")
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token()
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization": f"Bearer {access_token}"
        }
        return headers
       
        
    def get_resource(self, lookup_id, resource_type='albums',version='v1'):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{lookup_id}"
        headers = self.get_resource_header()
        r = rq.get(endpoint, headers=headers)
        if r.status_code not in range(200,299):
            return {}
        return r.json()
        
    def get_album(self, _id):
#         baseURL = 'https://api.spotify.com/v1'
#         endpoint = f"{baseURL}/albums/{_id}"
#         pass
        return self.get_resource(_id, resource_type = 'albums')
    
    def get_artist(self, _id):
        return self.get_resource(_id, resource_type = 'artists')
    
    def base_search(self, query_params):
        access_token = self.get_access_token()
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/search"
        lookup_url = f"{endpoint}?{query_params}"
        r = rq.get(lookup_url, headers = headers)
        #print(r.status_code)
        if r.status_code not in range(200, 299):
            return {}
        return r.json()
    
    def search(self, query=None, operator=None, operator_query=None, search_type='artist'):
        if query == None:
            raise Exception("A query is required")
        if isinstance (query, dict):
            query = " ".join([f"{k}:{v}" for k,v in query.items()])
        if operator != None and operator_query != None:
            if operator.lower() == "or" or operator.lower() == "not":
                operator = operator.upper()
                if isinstance(operator_query, str):
                    query = f"{query} {operator} {operator_query}"
        query_params = urlencode({"q": query, "type" : search_type.lower()})
        print(query_params)
        # When doing the queries with operators match the query to the operator query in terms of type(artists, albums,etc.)
        return self.base_search(query_params)
        

#Playlist features

    def get_user_playlists(self, resource_type='users', version='v1', user_id='null', limit=50):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{user_id}/playlists"
        query_params = urlencode({'limit' : 50})
        final_endpoint = f"{endpoint}?{query_params}"
        headers = self.get_resource_header()
        r = rq.get(final_endpoint, headers=headers)
        if r.status_code not in range(200,299):
            return {}
        return r.json()
    
    def get_next_page(self, url=None):
        if url == None:
            raise Exception("Invalid argument")
        headers = self.get_resource_header()
        r = rq.get(url, headers=headers)
        if r.status_code not in range(200,299):
            print(r.status_code)
            return {}
        #print(r.json())
        return r.json()
    
    #this particular vairable/field is only needed for the list_user_playlists method
    user_playlists = []
    def list_user_playlists(self, response=None):
        if response == None:
            raise Exception("Invalid argument")
        #print(self.user_playlists)
        for item in response['items']:
            temp = {'name' : item['name'],
                    'id' : item['id'],
                   'uri' : item['uri']}
            self.user_playlists.append(temp)
        while(response['next'] != None):
            self.list_user_playlists(self.get_next_page(response['next']))
            break
#         if response['next'] != None:
#             self.list_user_playlists(self.get_next_page(response['next']))
#         if response['next'] == None:
        return self.user_playlists
    
    def clear_user_playlists(self):
        self.user_playlists = []
        
    def get_playlist_items(self, resource_type='playlists', version='v1', playlist_id='null', limit=100):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{playlist_id}/tracks"
        query_params = urlencode({'limit' : limit, 'fields': 'items(added_by.id,uri,track(name,artists(href,id,uri,name,spotify),id,uri,duration,explicit,href,album(name,id,uri))),href,limit,next,offset,previous,total'})
        final_endpoint = f"{endpoint}?{query_params}"
        #print(final_endpoint)
        headers = self.get_resource_header()
        r = rq.get(final_endpoint, headers=headers)
        if r.status_code not in range(200,299):
            return {}
        return r.json()
        
#     #this particular vairable/field is only needed for the list_playlists_items method
    
#     def list_playlist_items(self, response=None):
#         if response == None:
#             raise Exception("Invalid argument")
#         #print(self.user_playlists)
#         for item in response['items']:
#             temp = {'name' : item['name'],
#                     'id' : item['id']}
#             self.user_playlists.append(temp)
#         while(response['next'] != None):
#             self.list_user_playlists(self.get_next_page(response['next']))
#             break
# #         if response['next'] != None:
# #             self.list_user_playlists(self.get_next_page(response['next']))
# #         if response['next'] == None:
#         return self.user_playlists
    

    #this particular vairable/field is only needed for the parse_playlists_items method
    playlist_items = []
    def parse_playlist_items(self, response=None):
        if response == None:
            raise Exception("Invalid argument")
        for item in response['items']:
            #pd(item)
            if item['track']==None:
                continue
            artists = []
            for i in item['track']['artists']:
                w = {'name' : i['name'],
                     'id' : i['id'],
                     'uri' : i['uri']
                    }
                #w = {i['name'] : i['id']}
                artists.append(w)

            q = {'song_name' : item['track']['name'], 'id' : item['track']['id'],'uri' : item['track']['uri'],
                                          'artists' : artists }
            self.playlist_items.append(q)
        while(response['next'] != None):
            self.parse_playlist_items(self.get_next_page(response['next']))
            break
        return self.playlist_items

    def clear_playlist_items(self):
        self.playlist_items = []
        
        
    def create_playlist(self, resource_type='users', version='v1', user_id='null', 
                        name=None, description='', public=False, artist=None, playlist_name=None):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{user_id}/playlists"
        #query_params = urlencode({'limit' : 50})
        #final_endpoint = f"{endpoint}?{query_params}"
        headers = self.get_resource_header()
        if name == None:
            name = f"{artist} : {playlist_name}"
            #print(name)
        post_data = {'name' : name,
                    'description' : description,
                    'public' : public}
        r = rq.post(endpoint, headers=headers, json=post_data)
        if r.status_code not in range(200,299):
            #print(r.status_code)
            return {}
        return r.json()
    
    def get_spotify_uri(self, id=None, resource_type='artist'):
        #resource type example = artist,album,track
        if id == None:
            raise Exception("Invalid argument")
        uri = f"spotify:{resource_type}:{id}"
        return uri
    
    def add_song_to_playlist(self, resource_type='playlists', version='v1', uri_list=None, playlist_id=None):
        if uri_list == None or playlist_id == None:
            raise Exception("Invalid argument")
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{playlist_id}/tracks"
        headers = self.get_resource_header()
        post_data = {'uris' : uri_list}
        r = rq.post(endpoint, headers=headers, json=post_data)
        if r.status_code not in range(200,299):
            #print(r.status_code)
            return {}
        return r.json()

# %%
#base64.b64decode(client_creds_b64) #decoding
#endpoint = "https://api.spotify.com/v1/search"

# %%
sc = SpotifyAPI(client_id, client_secret)

# %%
sc.parse_url_for_code('http://localhost:3000/?code=AQCzsCfkeuWu_M9vPiQp5BC3qSMeiVDrbc7dVyh7mjj2407EL_ClN8ay2RHveFrHV5YtRiRw7ZQ9LYal7_m_pl-7PqCn_dPD72UTv-_GlxKpRRrGOjNmOjGxwJRxKdXntbVaCioaQdc3Jacy4HAHRRsVcrxvKybjINrKIwHCyGw7gymxWxtZSikpi2v-AU9UAV7bUC69uonGLVVTWe4m4VKN40QmdhNiwTwuYJjC4Xn2VDuf0lemJUtnsHOR76PsmAkCcbRQhQUF34ycdQxUvF42mTgVCZl9SyrvWtkC4g')

# %%
response = sc.get_user_playlists(user_id='y4yjmhqzanyc6musw2wjfi1hv')
#print(response)
pd(response)
#sc.get_user_playlists(user_id='y4yjmhqzanyc6musw2wjfi1hv')
# Out:
# {
#     'href': 'https://api.spotify.com/v1/users/y4yjmhqzanyc6musw2wjfi1hv/playlists?offset=0&limit=50',
#     'items': [{
#         'collaborative': False,
#         'description': 'A playlist of Drake songs in IKE playlist',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/5bafUXvO08JfyfLbkrY8dk'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/5bafUXvO08JfyfLbkrY8dk',
#         'id': '5bafUXvO08JfyfLbkrY8dk',
#         'images': [{
#             'height': 640,
#             'url': 'https://mosaic.scdn.co/640/ab67616d0000b27359ba1bf8385cb016e62a26c0ab67616d0000b2736cab41f8c84d6164976400d4ab67616d0000b2739c188c494d8bfaf895411890ab67616d0000b273f907de96b9a4fbc04accc0d5',
#             'width': 640
#         }, {
#             'height': 300,
#             'url': 'https://mosaic.scdn.co/300/ab67616d0000b27359ba1bf8385cb016e62a26c0ab67616d0000b2736cab41f8c84d6164976400d4ab67616d0000b2739c188c494d8bfaf895411890ab67616d0000b273f907de96b9a4fbc04accc0d5',
#             'width': 300
#         }, {
#             'height': 60,
#             'url': 'https://mosaic.scdn.co/60/ab67616d0000b27359ba1bf8385cb016e62a26c0ab67616d0000b2736cab41f8c84d6164976400d4ab67616d0000b2739c188c494d8bfaf895411890ab67616d0000b273f907de96b9a4fbc04accc0d5',
#             'width': 60
#         }],
#         'name': 'Drake : Ike',
#         'owner': {
#             'display_name': 'Ike',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/y4yjmhqzanyc6musw2wjfi1hv'
#             },
#             'href': 'https://api.spotify.com/v1/users/y4yjmhqzanyc6musw2wjfi1hv',
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv',
#             'type': 'user',
#             'uri': 'spotify:user:y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MyxkZGFkY2EzY2RlOTg1YjZlMDlmZTI1NmNlMzY5MjE2Y2E4NjVjYTQ0',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/5bafUXvO08JfyfLbkrY8dk/tracks',
#             'total': 75
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:5bafUXvO08JfyfLbkrY8dk'
#     }, {
#         'collaborative': False,
#         'description': 'Every song from Joy Crookes&#x27; debut album &#x27;Skin&#x27; &amp; the EP&#x27;s that preceded it. Including &#x27;Feet Don&#x27;t Fail Me Now&#x27; the soundtrack to '
#         'the UEFA Womens Euro 2022.',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/1PT1LcejkMGoGsmKzkBKax'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/1PT1LcejkMGoGsmKzkBKax',
#         'id': '1PT1LcejkMGoGsmKzkBKax',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb252d43620a6d0fad2d761da6',
#             'width': None
#         }],
#         'name': 'Joy Crookes - The Complete Collection',
#         'owner': {
#             'display_name': 'joycrookes',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/gy67etvjqc9fuvdpsnbezumxe'
#             },
#             'href': 'https://api.spotify.com/v1/users/gy67etvjqc9fuvdpsnbezumxe',
#             'id': 'gy67etvjqc9fuvdpsnbezumxe',
#             'type': 'user',
#             'uri': 'spotify:user:gy67etvjqc9fuvdpsnbezumxe'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'NzAsNDJkYWFhZGJhNGQ1MjUwMzMwYzcxMTk4MWM0Yzk5MjQ1ZjRkZGViMw==',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/1PT1LcejkMGoGsmKzkBKax/tracks',
#             'total': 33
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:1PT1LcejkMGoGsmKzkBKax'
#     }, {
#         'collaborative': False,
#         'description': '',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/7H0gvTCkCh9vA8gw1mcNVd'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/7H0gvTCkCh9vA8gw1mcNVd',
#         'id': '7H0gvTCkCh9vA8gw1mcNVd',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb19049aa463efceb00a63ac12',
#             'width': None
#         }],
#         'name': 'Japanese City Pop',
#         'owner': {
#             'display_name': 'Solace of Sound',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/1210229329'
#             },
#             'href': 'https://api.spotify.com/v1/users/1210229329',
#             'id': '1210229329',
#             'type': 'user',
#             'uri': 'spotify:user:1210229329'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTE5LGI5NDE3Zjk0ZDNkZDJmMzg2NzRjMDQxNjVmN2FhYTQzMGNjYzA2MTE=',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/7H0gvTCkCh9vA8gw1mcNVd/tracks',
#             'total': 96
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:7H0gvTCkCh9vA8gw1mcNVd'
#     }, {
#         'collaborative': False,
#         'description': 'Spotify Wrapped presents the songs that you loved most this year.',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/37i9dQZF1F0sijgNaJdgit'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1F0sijgNaJdgit',
#         'id': '37i9dQZF1F0sijgNaJdgit',
#         'images': [{
#             'height': None,
#             'url': 'https://wrapped-images.spotifycdn.com/image/yts-2022/large/your-top-songs-2022_large_en.jpg',
#             'width': None
#         }],
#         'name': 'Your Top Songs 2022',
#         'owner': {
#             'display_name': 'Spotify',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/spotify'
#             },
#             'href': 'https://api.spotify.com/v1/users/spotify',
#             'id': 'spotify',
#             'type': 'user',
#             'uri': 'spotify:user:spotify'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTY2OTkwODk2MiwwMDAwMDAwMDBiNjFiY2QxNTNkMTdkZjM2MDAwYmUyNjE3M2RmODE5',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1F0sijgNaJdgit/tracks',
#             'total': 101
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:37i9dQZF1F0sijgNaJdgit'
#     }, {
#         'collaborative': False,
#         'description': '"Remember who we are." Music from and inspired by Black Panther: Wakanda Forever.',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX6tq7CPNyNEM'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX6tq7CPNyNEM',
#         'id': '37i9dQZF1DX6tq7CPNyNEM',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706f00000003d150ad6f9a23b19a1f20a837',
#             'width': None
#         }],
#         'name': 'Black Panther: Wakanda Forever Official Playlist',
#         'owner': {
#             'display_name': 'Spotify',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/spotify'
#             },
#             'href': 'https://api.spotify.com/v1/users/spotify',
#             'id': 'spotify',
#             'type': 'user',
#             'uri': 'spotify:user:spotify'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTY2ODc5ODQyNSwwMDAwMDAwMDc0Yjk3MTJlYjc2YTgzMzIxYjUyODU4OTYxZDJkM2Ex',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX6tq7CPNyNEM/tracks',
#             'total': 26
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:37i9dQZF1DX6tq7CPNyNEM'
#     }, {
#         'collaborative': False,
#         'description': '@Malky_malk’s personal playlist Newer songs&#x2F; Artists at the top, Older mainstream songs in the middle ',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/06wrErgQDANLAeVl2NR6NY'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/06wrErgQDANLAeVl2NR6NY',
#         'id': '06wrErgQDANLAeVl2NR6NY',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb6f4249ec52400c2aa448f1fd',
#             'width': None
#         }],
#         'name': 'Calisthenics x Gymtok',
#         'owner': {
#             'display_name': 'Malky_malk',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/314xrtemygz262l7kt2pcmweznq4'
#             },
#             'href': 'https://api.spotify.com/v1/users/314xrtemygz262l7kt2pcmweznq4',
#             'id': '314xrtemygz262l7kt2pcmweznq4',
#             'type': 'user',
#             'uri': 'spotify:user:314xrtemygz262l7kt2pcmweznq4'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'ODM2LDY3Nzk1ZDRjZTIxNTljMTA3ODRmNzIxYzI3ZTM3ODA3NDEyNWEzMDE=',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/06wrErgQDANLAeVl2NR6NY/tracks',
#             'total': 171
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:06wrErgQDANLAeVl2NR6NY'
#     }, {
#         'collaborative': False,
#         'description': '',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/4myVDdbRXNQ8Hu8pQheSMN'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/4myVDdbRXNQ8Hu8pQheSMN',
#         'id': '4myVDdbRXNQ8Hu8pQheSMN',
#         'images': [{
#             'height': 640,
#             'url': 'https://i.scdn.co/image/ab67616d0000b273174134e2ea546b2040749d8b',
#             'width': 640
#         }],
#         'name': 'Synthwave type',
#         'owner': {
#             'display_name': 'Ike',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/y4yjmhqzanyc6musw2wjfi1hv'
#             },
#             'href': 'https://api.spotify.com/v1/users/y4yjmhqzanyc6musw2wjfi1hv',
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv',
#             'type': 'user',
#             'uri': 'spotify:user:y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'NSw5MzNkNTdhMzNmMmJhNmM0MzNjNjFiMDUxNjg4MzBjMzhiZjA0MzVi',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/4myVDdbRXNQ8Hu8pQheSMN/tracks',
#             'total': 2
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:4myVDdbRXNQ8Hu8pQheSMN'
#     }, {
#         'collaborative': False,
#         'description': '',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/1sgNK6s1Gk4kZEOTKPd72X'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/1sgNK6s1Gk4kZEOTKPd72X',
#         'id': '1sgNK6s1Gk4kZEOTKPd72X',
#         'images': [{
#             'height': 640,
#             'url': 'https://mosaic.scdn.co/640/ab67616d0000b273806c160566580d6335d1f16cab67616d0000b273c357070e9c8805e6aacae25bab67616d0000b273cc319cc65277ea17783dca6bab67616d0000b273e896c941a8a6998e93255481',
#             'width': 640
#         }, {
#             'height': 300,
#             'url': 'https://mosaic.scdn.co/300/ab67616d0000b273806c160566580d6335d1f16cab67616d0000b273c357070e9c8805e6aacae25bab67616d0000b273cc319cc65277ea17783dca6bab67616d0000b273e896c941a8a6998e93255481',
#             'width': 300
#         }, {
#             'height': 60,
#             'url': 'https://mosaic.scdn.co/60/ab67616d0000b273806c160566580d6335d1f16cab67616d0000b273c357070e9c8805e6aacae25bab67616d0000b273cc319cc65277ea17783dca6bab67616d0000b273e896c941a8a6998e93255481',
#             'width': 60
#         }],
#         'name': '',
#         'owner': {
#             'display_name': 'Nazarite',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/jonathan007318'
#             },
#             'href': 'https://api.spotify.com/v1/users/jonathan007318',
#             'id': 'jonathan007318',
#             'type': 'user',
#             'uri': 'spotify:user:jonathan007318'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTUxNixiOWEyMWExMTU3MmE3N2Y2NTI5ZWJhY2JkZjAzNDE5OTRiNGI4Mjhm',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/1sgNK6s1Gk4kZEOTKPd72X/tracks',
#             'total': 166
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:1sgNK6s1Gk4kZEOTKPd72X'
#     }, {
#         'collaborative': False,
#         'description': '',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/5fkFpkHk4MaRyNeeXpYd30'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/5fkFpkHk4MaRyNeeXpYd30',
#         'id': '5fkFpkHk4MaRyNeeXpYd30',
#         'images': [{
#             'height': 640,
#             'url': 'https://mosaic.scdn.co/640/ab67616d0000b27302854a7060fccc1a66a4b5adab67616d0000b27313e54d6687e65678d60466c2ab67616d0000b27366b04b41fa6f8908dce86695ab67616d0000b273ffe5b62233340cb6d453fc2f',
#             'width': 640
#         }, {
#             'height': 300,
#             'url': 'https://mosaic.scdn.co/300/ab67616d0000b27302854a7060fccc1a66a4b5adab67616d0000b27313e54d6687e65678d60466c2ab67616d0000b27366b04b41fa6f8908dce86695ab67616d0000b273ffe5b62233340cb6d453fc2f',
#             'width': 300
#         }, {
#             'height': 60,
#             'url': 'https://mosaic.scdn.co/60/ab67616d0000b27302854a7060fccc1a66a4b5adab67616d0000b27313e54d6687e65678d60466c2ab67616d0000b27366b04b41fa6f8908dce86695ab67616d0000b273ffe5b62233340cb6d453fc2f',
#             'width': 60
#         }],
#         'name': '',
#         'owner': {
#             'display_name': 'adrianjoeym',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/adrianm23__'
#             },
#             'href': 'https://api.spotify.com/v1/users/adrianm23__',
#             'id': 'adrianm23__',
#             'type': 'user',
#             'uri': 'spotify:user:adrianm23__'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTUxOCxkMTBiYTM5N2MyZjViZGE1ZDRiZDU3MGVhYmE1OTg0OWRiNzcxZjIz',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/5fkFpkHk4MaRyNeeXpYd30/tracks',
#             'total': 104
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:5fkFpkHk4MaRyNeeXpYd30'
#     }, {
#         'collaborative': False,
#         'description': 'Fourth quarter, two minutes left .. get locked in',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWTl4y3vgJOXW'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTl4y3vgJOXW',
#         'id': '37i9dQZF1DWTl4y3vgJOXW',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706f000000038902742c4dcad187aa82bbd5',
#             'width': None
#         }],
#         'name': 'Locked In',
#         'owner': {
#             'display_name': 'Spotify',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/spotify'
#             },
#             'href': 'https://api.spotify.com/v1/users/spotify',
#             'id': 'spotify',
#             'type': 'user',
#             'uri': 'spotify:user:spotify'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTY3NDc5NTYwMCwwMDAwMDAwMGMyNWQ2NTg1YWJkNWQ4YWQ5Njg1YmNjZjM0ZDhiMjg5',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTl4y3vgJOXW/tracks',
#             'total': 200
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW'
#     }, {
#         'collaborative': False,
#         'description': 'Playlist transferred with SongShift',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/6MPrkSvuZQnQvITxJLr703'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/6MPrkSvuZQnQvITxJLr703',
#         'id': '6MPrkSvuZQnQvITxJLr703',
#         'images': [{
#             'height': 640,
#             'url': 'https://mosaic.scdn.co/640/ab67616d0000b2735ab2e9ee13191c3fcd1d58d3ab67616d0000b2735cd6070603a9f2e5dcb01d0cab67616d0000b2738cca41a6d8d0cae2e9b15d14ab67616d0000b273d00a36fea0639c48eb0ee312',
#             'width': 640
#         }, {
#             'height': 300,
#             'url': 'https://mosaic.scdn.co/300/ab67616d0000b2735ab2e9ee13191c3fcd1d58d3ab67616d0000b2735cd6070603a9f2e5dcb01d0cab67616d0000b2738cca41a6d8d0cae2e9b15d14ab67616d0000b273d00a36fea0639c48eb0ee312',
#             'width': 300
#         }, {
#             'height': 60,
#             'url': 'https://mosaic.scdn.co/60/ab67616d0000b2735ab2e9ee13191c3fcd1d58d3ab67616d0000b2735cd6070603a9f2e5dcb01d0cab67616d0000b2738cca41a6d8d0cae2e9b15d14ab67616d0000b273d00a36fea0639c48eb0ee312',
#             'width': 60
#         }],
#         'name': 'new new',
#         'owner': {
#             'display_name': 'andraj34',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/andraj34'
#             },
#             'href': 'https://api.spotify.com/v1/users/andraj34',
#             'id': 'andraj34',
#             'type': 'user',
#             'uri': 'spotify:user:andraj34'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTIsMTkzNzJmMjIzNzBmYTlmY2I5NTdmZGM2OGJiMzAzMDViYTNmYzJjMQ==',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/6MPrkSvuZQnQvITxJLr703/tracks',
#             'total': 598
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:6MPrkSvuZQnQvITxJLr703'
#     }, {
#         'collaborative': False,
#         'description': '',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/3OX1Mbdhbadze6rcNS41eM'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/3OX1Mbdhbadze6rcNS41eM',
#         'id': '3OX1Mbdhbadze6rcNS41eM',
#         'images': [{
#             'height': 640,
#             'url': 'https://mosaic.scdn.co/640/ab67616d0000b27300030070dd61dad65ab707faab67616d0000b273a859ec0e8aa49edeaafab89cab67616d0000b273e1c9182838a2f73ded76c450ab67616d0000b273f5c30413d754c5b010150d84',
#             'width': 640
#         }, {
#             'height': 300,
#             'url': 'https://mosaic.scdn.co/300/ab67616d0000b27300030070dd61dad65ab707faab67616d0000b273a859ec0e8aa49edeaafab89cab67616d0000b273e1c9182838a2f73ded76c450ab67616d0000b273f5c30413d754c5b010150d84',
#             'width': 300
#         }, {
#             'height': 60,
#             'url': 'https://mosaic.scdn.co/60/ab67616d0000b27300030070dd61dad65ab707faab67616d0000b273a859ec0e8aa49edeaafab89cab67616d0000b273e1c9182838a2f73ded76c450ab67616d0000b273f5c30413d754c5b010150d84',
#             'width': 60
#         }],
#         'name': 'SES Hackathon',
#         'owner': {
#             'display_name': 'Erhan Uyar',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/u0qmpvfzb9zl7zqk9g9eqg8ws'
#             },
#             'href': 'https://api.spotify.com/v1/users/u0qmpvfzb9zl7zqk9g9eqg8ws',
#             'id': 'u0qmpvfzb9zl7zqk9g9eqg8ws',
#             'type': 'user',
#             'uri': 'spotify:user:u0qmpvfzb9zl7zqk9g9eqg8ws'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'NzQsNmJiM2Y3YjI0ZmU3YzNjYjUxZjE5ODkwYzYyNGY5N2VkZTAzNDVkNQ==',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/3OX1Mbdhbadze6rcNS41eM/tracks',
#             'total': 42
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:3OX1Mbdhbadze6rcNS41eM'
#     }, {
#         'collaborative': False,
#         'description': 'Dm me on insta for song requests @andrewmcgee__',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/25DpSFEJ7zeAy6uGWOjlFo'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/25DpSFEJ7zeAy6uGWOjlFo',
#         'id': '25DpSFEJ7zeAy6uGWOjlFo',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebba4b796264734a94a2c3d274a',
#             'width': None
#         }],
#         'name': 'FEELING DISRESPECTFUL😈😈',
#         'owner': {
#             'display_name': 'Him🫡',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/wonderfulwilliam99'
#             },
#             'href': 'https://api.spotify.com/v1/users/wonderfulwilliam99',
#             'id': 'wonderfulwilliam99',
#             'type': 'user',
#             'uri': 'spotify:user:wonderfulwilliam99'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTIxNiw3MDM5MmM4NTY2OWE3NmQ0ODllYWYzODdkMDNhNjZhZDFhYmUyMDg4',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/25DpSFEJ7zeAy6uGWOjlFo/tracks',
#             'total': 561
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:25DpSFEJ7zeAy6uGWOjlFo'
#     }, {
#         'collaborative': False,
#         'description': '',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/52heXxEn3Cdn6ofhR3nObo'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/52heXxEn3Cdn6ofhR3nObo',
#         'id': '52heXxEn3Cdn6ofhR3nObo',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb4aea4dec6522d5227ccc950d',
#             'width': None
#         }],
#         'name': 'dreaming of summer in Brazil ',
#         'owner': {
#             'display_name': 'Tanaka',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/kudzaimushonga1'
#             },
#             'href': 'https://api.spotify.com/v1/users/kudzaimushonga1',
#             'id': 'kudzaimushonga1',
#             'type': 'user',
#             'uri': 'spotify:user:kudzaimushonga1'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTUsYWRkNGIxYTYxNWU3NDA5ZGUxNjQ0NWI2NDYxYThlMDA5ODdjMzdhZA==',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/52heXxEn3Cdn6ofhR3nObo/tracks',
#             'total': 54
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:52heXxEn3Cdn6ofhR3nObo'
#     }, {
#         'collaborative': False,
#         'description': 'That good mood workout to keep the spirits high and weights even higher.',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/4HUido35wAtbof2YMZ7bSQ'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/4HUido35wAtbof2YMZ7bSQ',
#         'id': '4HUido35wAtbof2YMZ7bSQ',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb6486e7566730e6b92226ffb4',
#             'width': None
#         }],
#         'name': 'gym sends (happy/upbeat)',
#         'owner': {
#             'display_name': 'Clay Brubaker',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/22s3xmkwibt2vov47ig66znyy'
#             },
#             'href': 'https://api.spotify.com/v1/users/22s3xmkwibt2vov47ig66znyy',
#             'id': '22s3xmkwibt2vov47ig66znyy',
#             'type': 'user',
#             'uri': 'spotify:user:22s3xmkwibt2vov47ig66znyy'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'NTEsOTM0ZGVjOGViNjRiMWFkOTBmNTU5MDlkOWY4ZDRlOGVlZjA3MmNkNg==',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/4HUido35wAtbof2YMZ7bSQ/tracks',
#             'total': 46
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:4HUido35wAtbof2YMZ7bSQ'
#     }, {
#         'collaborative': False,
#         'description': 'Moving some weights with a side of depression, this playlists got you',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/0LY0evTkp87qtw1dRCbe97'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/0LY0evTkp87qtw1dRCbe97',
#         'id': '0LY0evTkp87qtw1dRCbe97',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb1acbaa890c466a875890dd6d',
#             'width': None
#         }],
#         'name': 'gym sends (sad)',
#         'owner': {
#             'display_name': 'Clay Brubaker',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/22s3xmkwibt2vov47ig66znyy'
#             },
#             'href': 'https://api.spotify.com/v1/users/22s3xmkwibt2vov47ig66znyy',
#             'id': '22s3xmkwibt2vov47ig66znyy',
#             'type': 'user',
#             'uri': 'spotify:user:22s3xmkwibt2vov47ig66znyy'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'NTUsZWUwYjZhYzI2NjQ2ZWJjOWRhYzM5MDQxNmIxNmRiM2MzZmQ4OWZkYQ==',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/0LY0evTkp87qtw1dRCbe97/tracks',
#             'total': 51
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:0LY0evTkp87qtw1dRCbe97'
#     }, {
#         'collaborative': False,
#         'description': 'Need to just slams some things around in the gym, give this a listen ASAP',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/5BVHoZKG1wjPfBJ6RUAlJG'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/5BVHoZKG1wjPfBJ6RUAlJG',
#         'id': '5BVHoZKG1wjPfBJ6RUAlJG',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb077180b12bf075ef846933c3',
#             'width': None
#         }],
#         'name': 'gym sends (angry)',
#         'owner': {
#             'display_name': 'Clay Brubaker',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/22s3xmkwibt2vov47ig66znyy'
#             },
#             'href': 'https://api.spotify.com/v1/users/22s3xmkwibt2vov47ig66znyy',
#             'id': '22s3xmkwibt2vov47ig66znyy',
#             'type': 'user',
#             'uri': 'spotify:user:22s3xmkwibt2vov47ig66znyy'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'NjIsMDA2OWY2YTg5MTNlYTk5OTcxZGY3YTIzY2FlZWZhZDEyYTNlZjNkMA==',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/5BVHoZKG1wjPfBJ6RUAlJG/tracks',
#             'total': 58
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:5BVHoZKG1wjPfBJ6RUAlJG'
#     }, {
#         'collaborative': False,
#         'description': 'A laid back vibe in the gym when you just need some good tunes.',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/77kgw7u48un9NkozrxouOg'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/77kgw7u48un9NkozrxouOg',
#         'id': '77kgw7u48un9NkozrxouOg',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb82154231abeefb29984453bf',
#             'width': None
#         }],
#         'name': 'gym sends (chill)',
#         'owner': {
#             'display_name': 'Clay Brubaker',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/22s3xmkwibt2vov47ig66znyy'
#             },
#             'href': 'https://api.spotify.com/v1/users/22s3xmkwibt2vov47ig66znyy',
#             'id': '22s3xmkwibt2vov47ig66znyy',
#             'type': 'user',
#             'uri': 'spotify:user:22s3xmkwibt2vov47ig66znyy'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'NTMsZmJmMzQxOGU0M2NjNzM5NzE0YmJmOWE1YjhmYmFmNjMwOGZmMWNkZA==',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/77kgw7u48un9NkozrxouOg/tracks',
#             'total': 47
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:77kgw7u48un9NkozrxouOg'
#     }, {
#         'collaborative': False,
#         'description': 'The ultimate gym playlist of every song you need in the gym',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/6ojl7MOYEjFOmM5syFrQXX'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/6ojl7MOYEjFOmM5syFrQXX',
#         'id': '6ojl7MOYEjFOmM5syFrQXX',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb92dbbcda81a08cba08ad2e24',
#             'width': None
#         }],
#         'name': 'gym sends',
#         'owner': {
#             'display_name': 'Clay Brubaker',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/22s3xmkwibt2vov47ig66znyy'
#             },
#             'href': 'https://api.spotify.com/v1/users/22s3xmkwibt2vov47ig66znyy',
#             'id': '22s3xmkwibt2vov47ig66znyy',
#             'type': 'user',
#             'uri': 'spotify:user:22s3xmkwibt2vov47ig66znyy'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTI2LDE1YmEzMzdiYmM0MjA4YmY3MzA5OTE3ODVkZGVhMDI4MmM0NWNhODQ=',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/6ojl7MOYEjFOmM5syFrQXX/tracks',
#             'total': 114
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:6ojl7MOYEjFOmM5syFrQXX'
#     }, {
#         'collaborative': False,
#         'description': '',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/0ef2FFJmYlAiXtDFsEaOYt'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/0ef2FFJmYlAiXtDFsEaOYt',
#         'id': '0ef2FFJmYlAiXtDFsEaOYt',
#         'images': [{
#             'height': 640,
#             'url': 'https://mosaic.scdn.co/640/ab67616d0000b2733355057c7983c79c24d57690ab67616d0000b2738931779a288ea6a8b78a8780ab67616d0000b27392b5c3716cb7287638d032cdab67616d0000b27396710096536accca658e76d9',
#             'width': 640
#         }, {
#             'height': 300,
#             'url': 'https://mosaic.scdn.co/300/ab67616d0000b2733355057c7983c79c24d57690ab67616d0000b2738931779a288ea6a8b78a8780ab67616d0000b27392b5c3716cb7287638d032cdab67616d0000b27396710096536accca658e76d9',
#             'width': 300
#         }, {
#             'height': 60,
#             'url': 'https://mosaic.scdn.co/60/ab67616d0000b2733355057c7983c79c24d57690ab67616d0000b2738931779a288ea6a8b78a8780ab67616d0000b27392b5c3716cb7287638d032cdab67616d0000b27396710096536accca658e76d9',
#             'width': 60
#         }],
#         'name': '~',
#         'owner': {
#             'display_name': 'worldhaspostrock',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/worldhaspostrock'
#             },
#             'href': 'https://api.spotify.com/v1/users/worldhaspostrock',
#             'id': 'worldhaspostrock',
#             'type': 'user',
#             'uri': 'spotify:user:worldhaspostrock'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTA1LDJhOTFjZDlhMTQwMjU5OGRhNzBmMGNhOWVlNDA5MmQxZjI2YWRjNGU=',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/0ef2FFJmYlAiXtDFsEaOYt/tracks',
#             'total': 17
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:0ef2FFJmYlAiXtDFsEaOYt'
#     }, {
#         'collaborative': False,
#         'description': '',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/5wgQHQCjbvAyiddNhXH1et'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/5wgQHQCjbvAyiddNhXH1et',
#         'id': '5wgQHQCjbvAyiddNhXH1et',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb8e478645a9d4ae60bd149f9d',
#             'width': None
#         }],
#         'name': 'brown vibes',
#         'owner': {
#             'display_name': 'suicide joe',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/fafa2n15993eymupnsi0732a1'
#             },
#             'href': 'https://api.spotify.com/v1/users/fafa2n15993eymupnsi0732a1',
#             'id': 'fafa2n15993eymupnsi0732a1',
#             'type': 'user',
#             'uri': 'spotify:user:fafa2n15993eymupnsi0732a1'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'Mzc5LGVjOGNlM2Q5YzMwNTY4YjJiNDc3NzBiOTdiM2I2ODYyMzQ0ZDFkYTc=',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/5wgQHQCjbvAyiddNhXH1et/tracks',
#             'total': 371
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:5wgQHQCjbvAyiddNhXH1et'
#     }, {
#         'collaborative': False,
#         'description': 'Spotify Wrapped presents the songs that you loved most this year.',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/37i9dQZF1EUMDoJuT8yJsl'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EUMDoJuT8yJsl',
#         'id': '37i9dQZF1EUMDoJuT8yJsl',
#         'images': [{
#             'height': None,
#             'url': 'https://lineup-images.scdn.co/wrapped-2021-top100_LARGE-en.jpg',
#             'width': None
#         }],
#         'name': 'Your Top Songs 2021',
#         'owner': {
#             'display_name': 'Spotify',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/spotify'
#             },
#             'href': 'https://api.spotify.com/v1/users/spotify',
#             'id': 'spotify',
#             'type': 'user',
#             'uri': 'spotify:user:spotify'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MCwwMDAwMDAwMDc1NDkzMWZlOTVlZTM1ZGExMzg2NzNhZGE0NmQwM2Ey',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EUMDoJuT8yJsl/tracks',
#             'total': 100
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:37i9dQZF1EUMDoJuT8yJsl'
#     }, {
#         'collaborative': False,
#         'description': 'Essential tracks from the most notable classical works ever recorded - both old and new. Featuring Mozart, Beethoven, Bach, Chopin, Satie, Brahms, Vivaldi, Max Richter, '
#         'Ludovico Einaudi &amp; more…Click our <a href="https://open.spotify.com/user/peacefulclassics">profile</a> for more great playlists',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/1h0CEZCm6IbFTbxThn6Xcs'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/1h0CEZCm6IbFTbxThn6Xcs',
#         'id': '1h0CEZCm6IbFTbxThn6Xcs',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebbd54237616a14c76c37b65f8b',
#             'width': None
#         }],
#         'name': 'Best Classical Music',
#         'owner': {
#             'display_name': 'Peaceful Classics',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/peacefulclassics'
#             },
#             'href': 'https://api.spotify.com/v1/users/peacefulclassics',
#             'id': 'peacefulclassics',
#             'type': 'user',
#             'uri': 'spotify:user:peacefulclassics'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'ODk0LDM0MmI2Mjk5NDBjZmE4OTRjODc4ZTBmNDExMjU2OGRiMTVjMmUwMmM=',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/1h0CEZCm6IbFTbxThn6Xcs/tracks',
#             'total': 179
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:1h0CEZCm6IbFTbxThn6Xcs'
#     }, {
#         'collaborative': False,
#         'description': 'woooahhhh yeahhhh woaaaaaaaaaaa haha yeahhhh my name is scott',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/5ytGiYp3leMjSJLwobwvZY'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/5ytGiYp3leMjSJLwobwvZY',
#         'id': '5ytGiYp3leMjSJLwobwvZY',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb5e501a5d44801966a0754d5e',
#             'width': None
#         }],
#         'name': 'aux',
#         'owner': {
#             'display_name': 'M',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/8j6p6n0zqh2c3yeu8afw4ro7t'
#             },
#             'href': 'https://api.spotify.com/v1/users/8j6p6n0zqh2c3yeu8afw4ro7t',
#             'id': '8j6p6n0zqh2c3yeu8afw4ro7t',
#             'type': 'user',
#             'uri': 'spotify:user:8j6p6n0zqh2c3yeu8afw4ro7t'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'Njg1LGZiZDIwN2FmOWJjNzM2NDkwYzExM2E5NGI0ZmJkMDgwZmEyNGNlZTY=',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/5ytGiYp3leMjSJLwobwvZY/tracks',
#             'total': 368
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:5ytGiYp3leMjSJLwobwvZY'
#     }, {
#         'collaborative': False,
#         'description': 'too underrated. @axel.tanner on IG',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/2726xBFbcKlJVpPODrlPVM'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/2726xBFbcKlJVpPODrlPVM',
#         'id': '2726xBFbcKlJVpPODrlPVM',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebba7c45dac9a65a6080c82ad74',
#             'width': None
#         }],
#         'name': 'hidden gems.',
#         'owner': {
#             'display_name': 'Axel Tanner',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/1298859216'
#             },
#             'href': 'https://api.spotify.com/v1/users/1298859216',
#             'id': '1298859216',
#             'type': 'user',
#             'uri': 'spotify:user:1298859216'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTUxMSw0NWQxOTNhNzljM2Y3M2VhZjgwYWQ2MGVlN2EzYWUzZWVhZWJhYzY4',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/2726xBFbcKlJVpPODrlPVM/tracks',
#             'total': 59
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:2726xBFbcKlJVpPODrlPVM'
#     }, {
#         'collaborative': False,
#         'description': '',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/3sVy6SwZxuvLHYSzdh4iOl'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/3sVy6SwZxuvLHYSzdh4iOl',
#         'id': '3sVy6SwZxuvLHYSzdh4iOl',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb115e02d3da9b831de1426f1d',
#             'width': None
#         }],
#         'name': '2010s rap',
#         'owner': {
#             'display_name': 'natalie',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/ndmiller06'
#             },
#             'href': 'https://api.spotify.com/v1/users/ndmiller06',
#             'id': 'ndmiller06',
#             'type': 'user',
#             'uri': 'spotify:user:ndmiller06'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'ODYsNDMyNzUzMjFjMDcxYmNiYmJiYWZlNGI4ODVkOTJiNzkyNTJkZWIwNA==',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/3sVy6SwZxuvLHYSzdh4iOl/tracks',
#             'total': 75
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:3sVy6SwZxuvLHYSzdh4iOl'
#     }, {
#         'collaborative': False,
#         'description': '',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/36oHhkDlAJ1DBUsOCgR9bn'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/36oHhkDlAJ1DBUsOCgR9bn',
#         'id': '36oHhkDlAJ1DBUsOCgR9bn',
#         'images': [{
#             'height': 640,
#             'url': 'https://mosaic.scdn.co/640/ab67616d0000b2738ac778cc7d88779f74d33311ab67616d0000b2739b9b36b0e22870b9f542d937ab67616d0000b273b33d46dfa2635a47eebf63b2ab67616d0000b273b98afa12c212cbbda4f1799b',
#             'width': 640
#         }, {
#             'height': 300,
#             'url': 'https://mosaic.scdn.co/300/ab67616d0000b2738ac778cc7d88779f74d33311ab67616d0000b2739b9b36b0e22870b9f542d937ab67616d0000b273b33d46dfa2635a47eebf63b2ab67616d0000b273b98afa12c212cbbda4f1799b',
#             'width': 300
#         }, {
#             'height': 60,
#             'url': 'https://mosaic.scdn.co/60/ab67616d0000b2738ac778cc7d88779f74d33311ab67616d0000b2739b9b36b0e22870b9f542d937ab67616d0000b273b33d46dfa2635a47eebf63b2ab67616d0000b273b98afa12c212cbbda4f1799b',
#             'width': 60
#         }],
#         'name': 'Vibezzz',
#         'owner': {
#             'display_name': 'Ike',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/y4yjmhqzanyc6musw2wjfi1hv'
#             },
#             'href': 'https://api.spotify.com/v1/users/y4yjmhqzanyc6musw2wjfi1hv',
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv',
#             'type': 'user',
#             'uri': 'spotify:user:y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTU3LGU5NDFiM2ViZWFkZmVkZGNhNTA4YzJmMWUyN2U4NDU3ZjIyYjk2NjQ=',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/36oHhkDlAJ1DBUsOCgR9bn/tracks',
#             'total': 148
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:36oHhkDlAJ1DBUsOCgR9bn'
#     }, {
#         'collaborative': False,
#         'description': 'The songs you loved most this year, all wrapped up.',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/37i9dQZF1ELWNwZdVoio5g'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1ELWNwZdVoio5g',
#         'id': '37i9dQZF1ELWNwZdVoio5g',
#         'images': [{
#             'height': None,
#             'url': 'https://lineup-images.scdn.co/wrapped-2020-top100_LARGE-en.jpg',
#             'width': None
#         }],
#         'name': 'Your Top Songs 2020',
#         'owner': {
#             'display_name': 'Spotify',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/spotify'
#             },
#             'href': 'https://api.spotify.com/v1/users/spotify',
#             'id': 'spotify',
#             'type': 'user',
#             'uri': 'spotify:user:spotify'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MjY3NzQ2NjMsMDAwMDAwMDAwODhhN2JjZmEyODczMjE5MTgzYzZhMDM1Y2RmYjg5NQ==',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1ELWNwZdVoio5g/tracks',
#             'total': 100
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:37i9dQZF1ELWNwZdVoio5g'
#     }, {
#         'collaborative': False,
#         'description': 'Songs you love right now',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/37i9dQZF1Epx0a0zRRF282'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1Epx0a0zRRF282',
#         'id': '37i9dQZF1Epx0a0zRRF282',
#         'images': [{
#             'height': None,
#             'url': 'https://daily-mix.scdn.co/covers/on_repeat/PZN_On_Repeat2_LARGE-en.jpg',
#             'width': None
#         }],
#         'name': 'On Repeat',
#         'owner': {
#             'display_name': 'Spotify',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/spotify'
#             },
#             'href': 'https://api.spotify.com/v1/users/spotify',
#             'id': 'spotify',
#             'type': 'user',
#             'uri': 'spotify:user:spotify'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTY3NDg5NTAyOSwwMDAwMDAwMDAxYTJlYjM0NDc0ZmU1Y2FjZTViMmI5OWYzMWJhMTk2',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1Epx0a0zRRF282/tracks',
#             'total': 30
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:37i9dQZF1Epx0a0zRRF282'
#     }, {
#         'collaborative': False,
#         'description': 'The latest in hype Christian Hip Hop (CHH). Playlist updated weekly! Follow us on Instagram @CHHTalk',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/6NDHIP1IH6pbvpfULnjDqo'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/6NDHIP1IH6pbvpfULnjDqo',
#         'id': '6NDHIP1IH6pbvpfULnjDqo',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb5237a40cd2e299ffccbbb21c',
#             'width': None
#         }],
#         'name': 'Hype Christian Rap 🔥',
#         'owner': {
#             'display_name': 'CHHTalk',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/dmele012'
#             },
#             'href': 'https://api.spotify.com/v1/users/dmele012',
#             'id': 'dmele012',
#             'type': 'user',
#             'uri': 'spotify:user:dmele012'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTQ3MiwyMDg5NjhlMmU2Y2I3Y2U4ZDgwNWUyOTcwOGJmYThlMzMyNjlhOWU3',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/6NDHIP1IH6pbvpfULnjDqo/tracks',
#             'total': 205
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:6NDHIP1IH6pbvpfULnjDqo'
#     }, {
#         'collaborative': False,
#         'description': 'New music from Sam Smith, ROSALÍA, Zach Bryan & Maggie Rogers, Lil Yachty and more!',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX4JAvHpjipBk'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4JAvHpjipBk',
#         'id': '37i9dQZF1DX4JAvHpjipBk',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706f00000003290e733163c8b52492317ff8',
#             'width': None
#         }],
#         'name': 'New Music Friday',
#         'owner': {
#             'display_name': 'Spotify',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/spotify'
#             },
#             'href': 'https://api.spotify.com/v1/users/spotify',
#             'id': 'spotify',
#             'type': 'user',
#             'uri': 'spotify:user:spotify'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTY3NDg0MTY2MywwMDAwMDAwMGM2MDg2YWU4YTVkOTU0ZWQzZjc4MzhiNDM0YTEzMWMw',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4JAvHpjipBk/tracks',
#             'total': 104
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:37i9dQZF1DX4JAvHpjipBk'
#     }, {
#         'collaborative': False,
#         'description': '',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/2b8tD6ixBKq1z9QTuJs40D'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/2b8tD6ixBKq1z9QTuJs40D',
#         'id': '2b8tD6ixBKq1z9QTuJs40D',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb83934b8db4f355f75c6d16b9',
#             'width': None
#         }],
#         'name': 'IGNITED VIBECHECK',
#         'owner': {
#             'display_name': 'icycoldtowers',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/icycoldtowers'
#             },
#             'href': 'https://api.spotify.com/v1/users/icycoldtowers',
#             'id': 'icycoldtowers',
#             'type': 'user',
#             'uri': 'spotify:user:icycoldtowers'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'NjcsMzc2NTY5MzI2MzhlYzlkYjA0ZTQyODU0MDlhYTA2YWIxMzU0ZjcxYw==',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/2b8tD6ixBKq1z9QTuJs40D/tracks',
#             'total': 43
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:2b8tD6ixBKq1z9QTuJs40D'
#     }, {
#         'collaborative': False,
#         'description': '',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/1bIeEMLGRzYCOHn8nuDV1M'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/1bIeEMLGRzYCOHn8nuDV1M',
#         'id': '1bIeEMLGRzYCOHn8nuDV1M',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb5104f4f1fd1803b1d9431e10',
#             'width': None
#         }],
#         'name': 'Songs to bump on your way to the rapture!!!',
#         'owner': {
#             'display_name': 'Trevisjr',
#             'external_urls': {
# ...
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1E8L5dvOJWfsY5/tracks',
#             'total': 50
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:37i9dQZF1E8L5dvOJWfsY5'
#     }, {
#         'collaborative': False,
#         'description': 'The songs you loved most this year, all wrapped up.',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/37i9dQZF1EtmZDybMAZ0Kt'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EtmZDybMAZ0Kt',
#         'id': '37i9dQZF1EtmZDybMAZ0Kt',
#         'images': [{
#             'height': None,
#             'url': 'https://lineup-images.scdn.co/your-top-songs-2019_LARGE-en.jpg',
#             'width': None
#         }],
#         'name': 'Your Top Songs 2019',
#         'owner': {
#             'display_name': 'Spotify',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/spotify'
#             },
#             'href': 'https://api.spotify.com/v1/users/spotify',
#             'id': 'spotify',
#             'type': 'user',
#             'uri': 'spotify:user:spotify'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MjYyNjk2MzYsMDAwMDAwMDA3MzBmMDFmNjg1YWIxMDFjZmJiNzhkMTY4YTk5ODRjYw==',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EtmZDybMAZ0Kt/tracks',
#             'total': 100
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:37i9dQZF1EtmZDybMAZ0Kt'
#     }, {
#         'collaborative': False,
#         'description': '',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/6Du1ICnVsDtlaZdLMn7ebG'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/6Du1ICnVsDtlaZdLMn7ebG',
#         'id': '6Du1ICnVsDtlaZdLMn7ebG',
#         'images': [{
#             'height': 640,
#             'url': 'https://i.scdn.co/image/ab67616d0000b273f4ca75192df162f78a24023e',
#             'width': 640
#         }],
#         'name': 'Hhh',
#         'owner': {
#             'display_name': 'Ike',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/y4yjmhqzanyc6musw2wjfi1hv'
#             },
#             'href': 'https://api.spotify.com/v1/users/y4yjmhqzanyc6musw2wjfi1hv',
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv',
#             'type': 'user',
#             'uri': 'spotify:user:y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'primary_color': None,
#         'public': True,
#         'snapshot_id': 'NCxlNzNjMjJhMDFlZjg1MjA1OTNjMjMwNWFjZjE4OTZhNGVkN2RmMWNm',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/6Du1ICnVsDtlaZdLMn7ebG/tracks',
#             'total': 3
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:6Du1ICnVsDtlaZdLMn7ebG'
#     }, {
#         'collaborative': False,
#         'description': 'Concentration & Motivation! Focus-enhancing piano music for your study session.',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX8NTLI2TtZa6'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX8NTLI2TtZa6',
#         'id': '37i9dQZF1DX8NTLI2TtZa6',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706f0000000346bd1bd5d9990da7dae58ccc',
#             'width': None
#         }],
#         'name': 'Intense Studying',
#         'owner': {
#             'display_name': 'Spotify',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/spotify'
#             },
#             'href': 'https://api.spotify.com/v1/users/spotify',
#             'id': 'spotify',
#             'type': 'user',
#             'uri': 'spotify:user:spotify'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTY3NDc0MTIyNSwwMDAwMDAwMDM0NjlkYTdiNjRmN2I5OTI5YjU3NjhlNDkxOGQ3ZGIz',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX8NTLI2TtZa6/tracks',
#             'total': 204
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:37i9dQZF1DX8NTLI2TtZa6'
#     }, {
#         'collaborative': False,
#         'description': 'Camp 2018 Playlist',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/0JUnWRE2UPOTZvZnccFSzD'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/0JUnWRE2UPOTZvZnccFSzD',
#         'id': '0JUnWRE2UPOTZvZnccFSzD',
#         'images': [{
#             'height': 640,
#             'url': 'https://mosaic.scdn.co/640/ab67616d0000b27306bd66a29e6b4b22d3c63b8dab67616d0000b273091000c522ec46e10b6bdcf5ab67616d0000b273756031279f394f4db151063cab67616d0000b273bf51145c8eb220ac584cd0a8',
#             'width': 640
#         }, {
#             'height': 300,
#             'url': 'https://mosaic.scdn.co/300/ab67616d0000b27306bd66a29e6b4b22d3c63b8dab67616d0000b273091000c522ec46e10b6bdcf5ab67616d0000b273756031279f394f4db151063cab67616d0000b273bf51145c8eb220ac584cd0a8',
#             'width': 300
#         }, {
#             'height': 60,
#             'url': 'https://mosaic.scdn.co/60/ab67616d0000b27306bd66a29e6b4b22d3c63b8dab67616d0000b273091000c522ec46e10b6bdcf5ab67616d0000b273756031279f394f4db151063cab67616d0000b273bf51145c8eb220ac584cd0a8',
#             'width': 60
#         }],
#         'name': 'Camp Playlist 3.0',
#         'owner': {
#             'display_name': 'Aaron Ninaber',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/1252012643'
#             },
#             'href': 'https://api.spotify.com/v1/users/1252012643',
#             'id': '1252012643',
#             'type': 'user',
#             'uri': 'spotify:user:1252012643'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MjMsNzkzMmJiZTY0NTg5YzIwOWI4MTc4YzUxYmQ1MDhlMjkyYzE2YmIxMg==',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/0JUnWRE2UPOTZvZnccFSzD/tracks',
#             'total': 20
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:0JUnWRE2UPOTZvZnccFSzD'
#     }, {
#         'collaborative': False,
#         'description': '',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/2yKYu70G2TLGoEuU1zR4CL'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/2yKYu70G2TLGoEuU1zR4CL',
#         'id': '2yKYu70G2TLGoEuU1zR4CL',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb2c52ac5b9ba1bf3dd88f4543',
#             'width': None
#         }],
#         'name': 'Guadians Of the Galaxy Vol. 1 & 2',
#         'owner': {
#             'display_name': 'James',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/thepetersparks'
#             },
#             'href': 'https://api.spotify.com/v1/users/thepetersparks',
#             'id': 'thepetersparks',
#             'type': 'user',
#             'uri': 'spotify:user:thepetersparks'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MzEsY2Y4Mjk0MWUxOWE4ZTAwM2YwMmM0NThjOTUwYjhiNjBhMjM3MmM1Mg==',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/2yKYu70G2TLGoEuU1zR4CL/tracks',
#             'total': 25
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:2yKYu70G2TLGoEuU1zR4CL'
#     }, {
#         'collaborative': False,
#         'description': 'Enter WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXcf5pLcPbTwK'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcf5pLcPbTwK',
#         'id': '37i9dQZF1DXcf5pLcPbTwK',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706f00000003327728ac9cde9d5d4d11e868',
#             'width': None
#         }],
#         'name': 'Billie Eilish Experience',
#         'owner': {
#             'display_name': 'Spotify',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/spotify'
#             },
#             'href': 'https://api.spotify.com/v1/users/spotify',
#             'id': 'spotify',
#             'type': 'user',
#             'uri': 'spotify:user:spotify'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTYwNTIwNDgxNSwwMDAwMDAwMDIzMzE0MDNhYzhmMzI2MDEwNThlNGRhNDhlMjEyYzQw',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcf5pLcPbTwK/tracks',
#             'total': 21
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:37i9dQZF1DXcf5pLcPbTwK'
#     }, {
#         'collaborative': False,
#         'description': 'All things Billie!',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX6cg4h2PoN9y'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX6cg4h2PoN9y',
#         'id': '37i9dQZF1DX6cg4h2PoN9y',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706f00000003df12c206fd3c49ad933943f3',
#             'width': None
#         }],
#         'name': 'This Is Billie Eilish',
#         'owner': {
#             'display_name': 'Spotify',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/spotify'
#             },
#             'href': 'https://api.spotify.com/v1/users/spotify',
#             'id': 'spotify',
#             'type': 'user',
#             'uri': 'spotify:user:spotify'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTY3MTE2Njg2MCwwMDAwMDAwMGVkNDRhNGEzYmJiN2YxMmM2NDM5M2QwNDBjZDYxMzU2',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX6cg4h2PoN9y/tracks',
#             'total': 59
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:37i9dQZF1DX6cg4h2PoN9y'
#     }, {
#         'collaborative': False,
#         'description': 'Songs used in MKBHD videos. Starting in 2019.',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/0ZXVX604hmghJgqWCMsqcU'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/0ZXVX604hmghJgqWCMsqcU',
#         'id': '0ZXVX604hmghJgqWCMsqcU',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb3e92c22d045bbe6f5e381815',
#             'width': None
#         }],
#         'name': 'MKBHD Videos',
#         'owner': {
#             'display_name': 'Marques Brownlee',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/mkbhd'
#             },
#             'href': 'https://api.spotify.com/v1/users/mkbhd',
#             'id': 'mkbhd',
#             'type': 'user',
#             'uri': 'spotify:user:mkbhd'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'NTcsZGI0OWViNzllZmYwYzJhZWU2NTUwNDFkMDhiZTU1YjkzNzM2OTUwOA==',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/0ZXVX604hmghJgqWCMsqcU/tracks',
#             'total': 52
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:0ZXVX604hmghJgqWCMsqcU'
#     }, {
#         'collaborative': False,
#         'description': 'Sam Smith is on top of the Hottest 50!',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXcBWIGoYBM5M'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcBWIGoYBM5M',
#         'id': '37i9dQZF1DXcBWIGoYBM5M',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706f00000003c57a3acb9f3f0517fe87abe6',
#             'width': None
#         }],
#         'name': "Today's Top Hits",
#         'owner': {
#             'display_name': 'Spotify',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/spotify'
#             },
#             'href': 'https://api.spotify.com/v1/users/spotify',
#             'id': 'spotify',
#             'type': 'user',
#             'uri': 'spotify:user:spotify'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTY3NTA5NzQ4NCwwMDAwMDAwMDhmMDgyY2NkNTczZGRkYzhlYmE5ZTg0MzdiMjBlMmQ0',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcBWIGoYBM5M/tracks',
#             'total': 50
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:37i9dQZF1DXcBWIGoYBM5M'
#     }, {
#         'collaborative': False,
#         'description': '',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/4R2wevjhrGXkvDxFrczsj2'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/4R2wevjhrGXkvDxFrczsj2',
#         'id': '4R2wevjhrGXkvDxFrczsj2',
#         'images': [{
#             'height': 640,
#             'url': 'https://mosaic.scdn.co/640/ab67616d0000b2730ce91190aaea70dd4fe020c4ab67616d0000b2734a53fad32813802c94bc0667ab67616d0000b27353cf43170dc29787984cf6b4ab67616d0000b273c31996a0e8cacc4c908249ca',
#             'width': 640
#         }, {
#             'height': 300,
#             'url': 'https://mosaic.scdn.co/300/ab67616d0000b2730ce91190aaea70dd4fe020c4ab67616d0000b2734a53fad32813802c94bc0667ab67616d0000b27353cf43170dc29787984cf6b4ab67616d0000b273c31996a0e8cacc4c908249ca',
#             'width': 300
#         }, {
#             'height': 60,
#             'url': 'https://mosaic.scdn.co/60/ab67616d0000b2730ce91190aaea70dd4fe020c4ab67616d0000b2734a53fad32813802c94bc0667ab67616d0000b27353cf43170dc29787984cf6b4ab67616d0000b273c31996a0e8cacc4c908249ca',
#             'width': 60
#         }],
#         'name': 'Old School',
#         'owner': {
#             'display_name': 'King_Lit',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/drw3vj4xdcgloalf8n591wcrm'
#             },
#             'href': 'https://api.spotify.com/v1/users/drw3vj4xdcgloalf8n591wcrm',
#             'id': 'drw3vj4xdcgloalf8n591wcrm',
#             'type': 'user',
#             'uri': 'spotify:user:drw3vj4xdcgloalf8n591wcrm'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MjUyLDhiY2FiNTUzZjhmZTdmMTcwOWY0MWU5OTU3NTcwNDc2NGI0ODY2NTI=',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/4R2wevjhrGXkvDxFrczsj2/tracks',
#             'total': 215
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:4R2wevjhrGXkvDxFrczsj2'
#     }, {
#         'collaborative': False,
#         'description': 'The hottest tracks of today...featuring Drake, Lil Uzi Vert, and Juice WRLD',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWYs83FtTMQFw'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWYs83FtTMQFw',
#         'id': '37i9dQZF1DWYs83FtTMQFw',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706f000000036ace0370b73965e5470b3d47',
#             'width': None
#         }],
#         'name': 'Hot Rhythmic',
#         'owner': {
#             'display_name': 'Spotify',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/spotify'
#             },
#             'href': 'https://api.spotify.com/v1/users/spotify',
#             'id': 'spotify',
#             'type': 'user',
#             'uri': 'spotify:user:spotify'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTY3NDgzNTkwNiwwMDAwMDAwMDQwZTQwNTBkOTlmNWU0NGJmMTgxZjdkNGNhZmFhZjQ4',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWYs83FtTMQFw/tracks',
#             'total': 80
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:37i9dQZF1DWYs83FtTMQFw'
#     }],
#     'limit': 50,
#     'next': 'https://api.spotify.com/v1/users/y4yjmhqzanyc6musw2wjfi1hv/playlists?offset=50&limit=50',
#     'offset': 0,
#     'previous': None,
#     'total': 63
# }

# %%
# user_playlists = []
# for item in response['items']:
#     temp = {item['name']: item['id']}
#     user_playlists.append(temp)

# if response
    
# print(user_playlists)
sc.clear_user_playlists()
q = sc.list_user_playlists(response)
#print(q)
pd(q)
# Out:
# [{
#     'name': 'Joy Crookes - The Complete Collection',
#     'id': '1PT1LcejkMGoGsmKzkBKax',
#     'uri': 'spotify:playlist:1PT1LcejkMGoGsmKzkBKax'
# }, {
#     'name': 'Japanese City Pop',
#     'id': '7H0gvTCkCh9vA8gw1mcNVd',
#     'uri': 'spotify:playlist:7H0gvTCkCh9vA8gw1mcNVd'
# }, {
#     'name': 'Your Top Songs 2022',
#     'id': '37i9dQZF1F0sijgNaJdgit',
#     'uri': 'spotify:playlist:37i9dQZF1F0sijgNaJdgit'
# }, {
#     'name': 'Black Panther: Wakanda Forever Official Playlist',
#     'id': '37i9dQZF1DX6tq7CPNyNEM',
#     'uri': 'spotify:playlist:37i9dQZF1DX6tq7CPNyNEM'
# }, {
#     'name': 'Calisthenics x Gymtok',
#     'id': '06wrErgQDANLAeVl2NR6NY',
#     'uri': 'spotify:playlist:06wrErgQDANLAeVl2NR6NY'
# }, {
#     'name': 'Synthwave type',
#     'id': '4myVDdbRXNQ8Hu8pQheSMN',
#     'uri': 'spotify:playlist:4myVDdbRXNQ8Hu8pQheSMN'
# }, {
#     'name': 'Gym Phonk 🔱',
#     'id': '1sgNK6s1Gk4kZEOTKPd72X',
#     'uri': 'spotify:playlist:1sgNK6s1Gk4kZEOTKPd72X'
# }, {
#     'name': '',
#     'id': '5fkFpkHk4MaRyNeeXpYd30',
#     'uri': 'spotify:playlist:5fkFpkHk4MaRyNeeXpYd30'
# }, {
#     'name': 'Locked In',
#     'id': '37i9dQZF1DWTl4y3vgJOXW',
#     'uri': 'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW'
# }, {
#     'name': 'new new',
#     'id': '6MPrkSvuZQnQvITxJLr703',
#     'uri': 'spotify:playlist:6MPrkSvuZQnQvITxJLr703'
# }, {
#     'name': 'SES Hackathon',
#     'id': '3OX1Mbdhbadze6rcNS41eM',
#     'uri': 'spotify:playlist:3OX1Mbdhbadze6rcNS41eM'
# }, {
#     'name': 'FEELING DISRESPECTFUL😈😈',
#     'id': '25DpSFEJ7zeAy6uGWOjlFo',
#     'uri': 'spotify:playlist:25DpSFEJ7zeAy6uGWOjlFo'
# }, {
#     'name': 'dreaming of summer in Brazil ',
#     'id': '52heXxEn3Cdn6ofhR3nObo',
#     'uri': 'spotify:playlist:52heXxEn3Cdn6ofhR3nObo'
# }, {
#     'name': 'gym sends (happy/upbeat)',
#     'id': '4HUido35wAtbof2YMZ7bSQ',
#     'uri': 'spotify:playlist:4HUido35wAtbof2YMZ7bSQ'
# }, {
#     'name': 'gym sends (sad)',
#     'id': '0LY0evTkp87qtw1dRCbe97',
#     'uri': 'spotify:playlist:0LY0evTkp87qtw1dRCbe97'
# }, {
#     'name': 'gym sends (angry)',
#     'id': '5BVHoZKG1wjPfBJ6RUAlJG',
#     'uri': 'spotify:playlist:5BVHoZKG1wjPfBJ6RUAlJG'
# }, {
#     'name': 'gym sends (chill)',
#     'id': '77kgw7u48un9NkozrxouOg',
#     'uri': 'spotify:playlist:77kgw7u48un9NkozrxouOg'
# }, {
#     'name': 'gym sends',
#     'id': '6ojl7MOYEjFOmM5syFrQXX',
#     'uri': 'spotify:playlist:6ojl7MOYEjFOmM5syFrQXX'
# }, {
#     'name': '~',
#     'id': '0ef2FFJmYlAiXtDFsEaOYt',
#     'uri': 'spotify:playlist:0ef2FFJmYlAiXtDFsEaOYt'
# }, {
#     'name': 'brown vibes',
#     'id': '5wgQHQCjbvAyiddNhXH1et',
#     'uri': 'spotify:playlist:5wgQHQCjbvAyiddNhXH1et'
# }, {
#     'name': 'Your Top Songs 2021',
#     'id': '37i9dQZF1EUMDoJuT8yJsl',
#     'uri': 'spotify:playlist:37i9dQZF1EUMDoJuT8yJsl'
# }, {
#     'name': 'Best Classical Music',
#     'id': '1h0CEZCm6IbFTbxThn6Xcs',
#     'uri': 'spotify:playlist:1h0CEZCm6IbFTbxThn6Xcs'
# }, {
#     'name': 'aux',
#     'id': '5ytGiYp3leMjSJLwobwvZY',
#     'uri': 'spotify:playlist:5ytGiYp3leMjSJLwobwvZY'
# }, {
#     'name': 'hidden gems.',
#     'id': '2726xBFbcKlJVpPODrlPVM',
#     'uri': 'spotify:playlist:2726xBFbcKlJVpPODrlPVM'
# }, {
#     'name': '2010s rap',
#     'id': '3sVy6SwZxuvLHYSzdh4iOl',
#     'uri': 'spotify:playlist:3sVy6SwZxuvLHYSzdh4iOl'
# }, {
#     'name': 'Vibezzz',
#     'id': '36oHhkDlAJ1DBUsOCgR9bn',
#     'uri': 'spotify:playlist:36oHhkDlAJ1DBUsOCgR9bn'
# }, {
#     'name': 'Your Top Songs 2020',
#     'id': '37i9dQZF1ELWNwZdVoio5g',
#     'uri': 'spotify:playlist:37i9dQZF1ELWNwZdVoio5g'
# }, {
#     'name': 'On Repeat',
#     'id': '37i9dQZF1Epx0a0zRRF282',
#     'uri': 'spotify:playlist:37i9dQZF1Epx0a0zRRF282'
# }, {
#     'name': 'Hype Christian Rap 🔥',
#     'id': '6NDHIP1IH6pbvpfULnjDqo',
#     'uri': 'spotify:playlist:6NDHIP1IH6pbvpfULnjDqo'
# }, {
#     'name': 'New Music Friday',
#     'id': '37i9dQZF1DX4JAvHpjipBk',
#     'uri': 'spotify:playlist:37i9dQZF1DX4JAvHpjipBk'
# }, {
#     'name': 'IGNITED VIBECHECK',
#     'id': '2b8tD6ixBKq1z9QTuJs40D',
#     'uri': 'spotify:playlist:2b8tD6ixBKq1z9QTuJs40D'
# }, {
#     'name': 'Songs to bump on your way to the rapture!!!',
#     'id': '1bIeEMLGRzYCOHn8nuDV1M',
#     'uri': 'spotify:playlist:1bIeEMLGRzYCOHn8nuDV1M'
# }, {
#     'name': 'Christian Get up and dance ',
#     'id': '3Y7C7KzCLrwAB9BFS9iAPH',
#     'uri': 'spotify:playlist:3Y7C7KzCLrwAB9BFS9iAPH'
# }, {
#     'name': 'Straight Outta Bethlehem',
#     'id': '13vhXXbyUbTx5jAGpOOsuS',
#     'uri': 'spotify:playlist:13vhXXbyUbTx5jAGpOOsuS'
# }, {
#     'name': 'All around Christian',
#     'id': '7gB0tMdfZv0XEgrikdpDzt',
#     'uri': 'spotify:playlist:7gB0tMdfZv0XEgrikdpDzt'
# }, {
#     'name': 'Lofi Music | Study Playlist 2022',
#     'id': '6hvW8ln3ApfzvDlYkrHmjA',
#     'uri': 'spotify:playlist:6hvW8ln3ApfzvDlYkrHmjA'
# }, {
#     'name': 'Lofi Fruits Music 🍉 lofi hip hop beats to study, relax & sleep to',
#     'id': '3LFIBdP7eZXJKqf3guepZ1',
#     'uri': 'spotify:playlist:3LFIBdP7eZXJKqf3guepZ1'
# }, {
#     'name': 'R.I.P. Fredo (feat. Young Nudy) - Notice Me Radio',
#     'id': '37i9dQZF1E8L5dvOJWfsY5',
#     'uri': 'spotify:playlist:37i9dQZF1E8L5dvOJWfsY5'
# }, {
#     'name': 'Your Top Songs 2019',
#     'id': '37i9dQZF1EtmZDybMAZ0Kt',
#     'uri': 'spotify:playlist:37i9dQZF1EtmZDybMAZ0Kt'
# }, {
#     'name': 'Hhh',
#     'id': '6Du1ICnVsDtlaZdLMn7ebG',
#     'uri': 'spotify:playlist:6Du1ICnVsDtlaZdLMn7ebG'
# }, {
#     'name': 'Intense Studying',
#     'id': '37i9dQZF1DX8NTLI2TtZa6',
#     'uri': 'spotify:playlist:37i9dQZF1DX8NTLI2TtZa6'
# }, {
#     'name': 'Camp Playlist 3.0',
#     'id': '0JUnWRE2UPOTZvZnccFSzD',
#     'uri': 'spotify:playlist:0JUnWRE2UPOTZvZnccFSzD'
# }, {
#     'name': 'Guadians Of the Galaxy Vol. 1 & 2',
#     'id': '2yKYu70G2TLGoEuU1zR4CL',
#     'uri': 'spotify:playlist:2yKYu70G2TLGoEuU1zR4CL'
# }, {
#     'name': 'Billie Eilish Experience',
#     'id': '37i9dQZF1DXcf5pLcPbTwK',
#     'uri': 'spotify:playlist:37i9dQZF1DXcf5pLcPbTwK'
# }, {
#     'name': 'This Is Billie Eilish',
#     'id': '37i9dQZF1DX6cg4h2PoN9y',
#     'uri': 'spotify:playlist:37i9dQZF1DX6cg4h2PoN9y'
# }, {
#     'name': 'MKBHD Videos',
#     'id': '0ZXVX604hmghJgqWCMsqcU',
#     'uri': 'spotify:playlist:0ZXVX604hmghJgqWCMsqcU'
# }, {
#     'name': "Today's Top Hits",
#     'id': '37i9dQZF1DXcBWIGoYBM5M',
#     'uri': 'spotify:playlist:37i9dQZF1DXcBWIGoYBM5M'
# }, {
#     'name': 'Old School',
#     'id': '4R2wevjhrGXkvDxFrczsj2',
#     'uri': 'spotify:playlist:4R2wevjhrGXkvDxFrczsj2'
# }, {
#     'name': 'Hot Rhythmic',
#     'id': '37i9dQZF1DWYs83FtTMQFw',
#     'uri': 'spotify:playlist:37i9dQZF1DWYs83FtTMQFw'
# }, {
#     'name': 'Party Hits',
#     'id': '37i9dQZF1DXa2PvUpywmrr',
#     'uri': 'spotify:playlist:37i9dQZF1DXa2PvUpywmrr'
# }, {
#     'name': 'Coffee Table Jazz',
#     'id': '37i9dQZF1DWVqfgj8NZEp1',
#     'uri': 'spotify:playlist:37i9dQZF1DWVqfgj8NZEp1'
# }, {
#     'name': 'Top Christian Hits',
#     'id': '1KRZH6WH8qYgaVnagjjOFV',
#     'uri': 'spotify:playlist:1KRZH6WH8qYgaVnagjjOFV'
# }, {
#     'name': 'Liked from Radio',
#     'id': '5rMYcR8zz4P82aRdgwUGiV',
#     'uri': 'spotify:playlist:5rMYcR8zz4P82aRdgwUGiV'
# }, {
#     'name': 'Chilled Pop',
#     'id': '4HnOH3VfJCN7HTD0L1sor7',
#     'uri': 'spotify:playlist:4HnOH3VfJCN7HTD0L1sor7'
# }, {
#     'name': 'Iff',
#     'id': '6BKLQbuco1PZ26XLR1ROew',
#     'uri': 'spotify:playlist:6BKLQbuco1PZ26XLR1ROew'
# }, {
#     'name': "Official Why Don't We Playlist",
#     'id': '48JGTYsigQdHKgNEDvlIvX',
#     'uri': 'spotify:playlist:48JGTYsigQdHKgNEDvlIvX'
# }, {
#     'name': 'K-Pop Hits 2023',
#     'id': '7JXJKP3xMvIMbEBBGApTPQ',
#     'uri': 'spotify:playlist:7JXJKP3xMvIMbEBBGApTPQ'
# }, {
#     'name': 'Let the Trap Say Amen',
#     'id': '0HpSR7c0eRVVzzso0X7Rq1',
#     'uri': 'spotify:playlist:0HpSR7c0eRVVzzso0X7Rq1'
# }, {
#     'name': 'Ike Special',
#     'id': '1pe6PfRVXasdpG2vIIVrl8',
#     'uri': 'spotify:playlist:1pe6PfRVXasdpG2vIIVrl8'
# }, {
#     'name': 'My Shazam Tracks',
#     'id': '5zEuy12dOWWqcvSCO86Pzj',
#     'uri': 'spotify:playlist:5zEuy12dOWWqcvSCO86Pzj'
# }, {
#     'name': 'Power Gaming',
#     'id': '37i9dQZF1DX6taq20FeuKj',
#     'uri': 'spotify:playlist:37i9dQZF1DX6taq20FeuKj'
# }, {
#     'name': 'Ike',
#     'id': '6AAW33WKzlJaN0JMqjC3xC',
#     'uri': 'spotify:playlist:6AAW33WKzlJaN0JMqjC3xC'
# }]

# %%
x=1
for i in sc.user_playlists:
    print(str(x) + '.', i)
    x+=1

# %%
#Search for artist fuctionality and parsing
j = sc.search('Drake', search_type='artist')
#print(j)
#Printing names and ids
print((j['artists']['items'][0]['name'])+ ':',(j['artists']['items'][0]['id']))

search_list = []
for i in range(6):
    q = {'name' : j['artists']['items'][i]['name'],
        'id' : j['artists']['items'][i]['id']
        }
    #q = {(j['artists']['items'][i]['name']) : (j['artists']['items'][i]['id'])}
    search_list.append(q)
#print(search_list)
pd(search_list)
# target_artist_id = list(search_list[0].values())[0] 
# target_artist_id
target_artist_id = search_list[0]['id']
target_artist_id
# Out:
# q=Drake&type=artist
# Drake: 3TVXtAsR1Inumwj472S9r4
# [{
#     'name': 'Drake',
#     'id': '3TVXtAsR1Inumwj472S9r4'
# }, {
#     'name': '21 Savage',
#     'id': '1URnnhqYAYcrqrcwql10ft'
# }, {
#     'name': 'Dave',
#     'id': '6Ip8FS7vWT1uKkJSweANQK'
# }, {
#     'name': 'Popcaan',
#     'id': '62DmErcU7dqZbJaDqwsqzR'
# }, {
#     'name': 'Smiley',
#     'id': '6jeg7JBX9J9097esK752iR'
# }, {
#     'name': 'BlocBoy JB',
#     'id': '4TEJudQY2pXxVHPE3gD2EU'
# }]
# '3TVXtAsR1Inumwj472S9r4'

# %%
#get playlist fuctionality
playlist_items_response = sc.get_playlist_items(playlist_id='6AAW33WKzlJaN0JMqjC3xC')
#print(playlist_items_response)
pd(playlist_items_response)
# Out:
# {
#     'href': 'https://api.spotify.com/v1/playlists/6AAW33WKzlJaN0JMqjC3xC/tracks?offset=0&limit=100&fields=items(added_by.id,uri,track(name,artists(href,id,uri,name,spotify),id,uri,duration,explicit,href,album(name,id,uri))),href,limit,next,offset,previous,total',
#     'items': [{
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '6mT3tct9qJ7RRfvN5lCRDL',
#                 'name': 'The Upper Hand',
#                 'uri': 'spotify:album:6mT3tct9qJ7RRfvN5lCRDL'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/1si6mnxJ6IpTOTW13ECa0o',
#                 'id': '1si6mnxJ6IpTOTW13ECa0o',
#                 'name': 'AllttA',
#                 'uri': 'spotify:artist:1si6mnxJ6IpTOTW13ECa0o'
#             }, {
#                 'href': 'https://api.spotify.com/v1/artists/6mA4csYsYvf4Mq02PleZEV',
#                 'id': '6mA4csYsYvf4Mq02PleZEV',
#                 'name': '20syl',
#                 'uri': 'spotify:artist:6mA4csYsYvf4Mq02PleZEV'
#             }, {
#                 'href': 'https://api.spotify.com/v1/artists/0r9XuUo5aHtAEZiWsOA0wT',
#                 'id': '0r9XuUo5aHtAEZiWsOA0wT',
#                 'name': 'Mr. J. Medeiros',
#                 'uri': 'spotify:artist:0r9XuUo5aHtAEZiWsOA0wT'
#             }],
#             'explicit': True,
#             'href': 'https://api.spotify.com/v1/tracks/3edBQuBUK7AKDpGJTK3L5a',
#             'id': '3edBQuBUK7AKDpGJTK3L5a',
#             'name': 'Drugs',
#             'uri': 'spotify:track:3edBQuBUK7AKDpGJTK3L5a'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '7viNUmZZ8ztn2UB4XB3jIL',
#                 'name': '2014 Forest Hills Drive',
#                 'uri': 'spotify:album:7viNUmZZ8ztn2UB4XB3jIL'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/6l3HvQ5sa6mXTsMTB19rO5',
#                 'id': '6l3HvQ5sa6mXTsMTB19rO5',
#                 'name': 'J. Cole',
#                 'uri': 'spotify:artist:6l3HvQ5sa6mXTsMTB19rO5'
#             }],
#             'explicit': True,
#             'href': 'https://api.spotify.com/v1/tracks/62vpWI1CHwFy7tMIcSStl8',
#             'id': '62vpWI1CHwFy7tMIcSStl8',
#             'name': 'No Role Modelz',
#             'uri': 'spotify:track:62vpWI1CHwFy7tMIcSStl8'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '4QUNWTw2FsIz722xjUjFJw',
#                 'name': 'Issa Album',
#                 'uri': 'spotify:album:4QUNWTw2FsIz722xjUjFJw'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/1URnnhqYAYcrqrcwql10ft',
#                 'id': '1URnnhqYAYcrqrcwql10ft',
#                 'name': '21 Savage',
#                 'uri': 'spotify:artist:1URnnhqYAYcrqrcwql10ft'
#             }],
#             'explicit': True,
#             'href': 'https://api.spotify.com/v1/tracks/2fQrGHiQOvpL9UgPvtYy6G',
#             'id': '2fQrGHiQOvpL9UgPvtYy6G',
#             'name': 'Bank Account',
#             'uri': 'spotify:track:2fQrGHiQOvpL9UgPvtYy6G'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '4IFpj2jyRcugt1yzH82m3E',
#                 'name': 'SYRE',
#                 'uri': 'spotify:album:4IFpj2jyRcugt1yzH82m3E'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/0xOeVMOz2fVg5BJY3N6akT',
#                 'id': '0xOeVMOz2fVg5BJY3N6akT',
#                 'name': 'Jaden',
#                 'uri': 'spotify:artist:0xOeVMOz2fVg5BJY3N6akT'
#             }],
#             'explicit': True,
#             'href': 'https://api.spotify.com/v1/tracks/22nyEAEM29tcBRhukR089b',
#             'id': '22nyEAEM29tcBRhukR089b',
#             'name': 'Icon',
#             'uri': 'spotify:track:22nyEAEM29tcBRhukR089b'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '5Xlz4LJwOZ8UHM9G6zqKYi',
#                 'name': 'Betrayed',
#                 'uri': 'spotify:album:5Xlz4LJwOZ8UHM9G6zqKYi'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/3EXdLajEO02ziZ90P90bSW',
#                 'id': '3EXdLajEO02ziZ90P90bSW',
#                 'name': 'Lil Xan',
#                 'uri': 'spotify:artist:3EXdLajEO02ziZ90P90bSW'
#             }],
#             'explicit': True,
#             'href': 'https://api.spotify.com/v1/tracks/3al2hpm92xE0pBalqWQHdD',
#             'id': '3al2hpm92xE0pBalqWQHdD',
#             'name': 'Betrayed',
#             'uri': 'spotify:track:3al2hpm92xE0pBalqWQHdD'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '1TTxcgs3zEngN0EB56yXzY',
#                 'name': 'Church Of Scars',
#                 'uri': 'spotify:album:1TTxcgs3zEngN0EB56yXzY'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/0yb46jwm7gqbZXVXZQ8Z1e',
#                 'id': '0yb46jwm7gqbZXVXZQ8Z1e',
#                 'name': 'Bishop Briggs',
#                 'uri': 'spotify:artist:0yb46jwm7gqbZXVXZQ8Z1e'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/3mRLHiSHYtC8Hk7bzZdUs1',
#             'id': '3mRLHiSHYtC8Hk7bzZdUs1',
#             'name': 'River',
#             'uri': 'spotify:track:3mRLHiSHYtC8Hk7bzZdUs1'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '7GNDuhrcC2PxGpMxhkRXvK',
#                 'name': 'Call Me Sachi',
#                 'uri': 'spotify:album:7GNDuhrcC2PxGpMxhkRXvK'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/2EGblO3Zjp1JonjHzAy7h5',
#                 'id': '2EGblO3Zjp1JonjHzAy7h5',
#                 'name': 'Andreyun',
#                 'uri': 'spotify:artist:2EGblO3Zjp1JonjHzAy7h5'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/1AxmoICtf9Bprk5f2rGOWT',
#             'id': '1AxmoICtf9Bprk5f2rGOWT',
#             'name': 'Call Me Sachi',
#             'uri': 'spotify:track:1AxmoICtf9Bprk5f2rGOWT'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '2bw00gRKNKbTFOqCkohbSh',
#                 'name': 'Silence',
#                 'uri': 'spotify:album:2bw00gRKNKbTFOqCkohbSh'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/64KEffDW9EtZ1y2vBYgq8T',
#                 'id': '64KEffDW9EtZ1y2vBYgq8T',
#                 'name': 'Marshmello',
#                 'uri': 'spotify:artist:64KEffDW9EtZ1y2vBYgq8T'
#             }, {
#                 'href': 'https://api.spotify.com/v1/artists/6LuN9FCkKOj5PcnpouEgny',
#                 'id': '6LuN9FCkKOj5PcnpouEgny',
#                 'name': 'Khalid',
#                 'uri': 'spotify:artist:6LuN9FCkKOj5PcnpouEgny'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/7vGuf3Y35N4wmASOKLUVVU',
#             'id': '7vGuf3Y35N4wmASOKLUVVU',
#             'name': 'Silence',
#             'uri': 'spotify:track:7vGuf3Y35N4wmASOKLUVVU'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '7yf9ZJyHRbp8sHtpDKfPpt',
#                 'name': 'Harder Than Ever',
#                 'uri': 'spotify:album:7yf9ZJyHRbp8sHtpDKfPpt'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/5f7VJjfbwm532GiveGC0ZK',
#                 'id': '5f7VJjfbwm532GiveGC0ZK',
#                 'name': 'Lil Baby',
#                 'uri': 'spotify:artist:5f7VJjfbwm532GiveGC0ZK'
#             }, {
#                 'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#                 'id': '3TVXtAsR1Inumwj472S9r4',
#                 'name': 'Drake',
#                 'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'
#             }],
#             'explicit': True,
#             'href': 'https://api.spotify.com/v1/tracks/6vN77lE9LK6HP2DewaN6HZ',
#             'id': '6vN77lE9LK6HP2DewaN6HZ',
#             'name': 'Yes Indeed',
#             'uri': 'spotify:track:6vN77lE9LK6HP2DewaN6HZ'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '7fd7SEK25VS3gJAUgSwL6y',
#                 'name': 'Culture II',
#                 'uri': 'spotify:album:7fd7SEK25VS3gJAUgSwL6y'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/6oMuImdp5ZcFhWP0ESe6mG',
#                 'id': '6oMuImdp5ZcFhWP0ESe6mG',
#                 'name': 'Migos',
#                 'uri': 'spotify:artist:6oMuImdp5ZcFhWP0ESe6mG'
#             }, {
#                 'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#                 'id': '3TVXtAsR1Inumwj472S9r4',
#                 'name': 'Drake',
#                 'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'
#             }],
#             'explicit': True,
#             'href': 'https://api.spotify.com/v1/tracks/6n4U3TlzUGhdSFbUUhTvLP',
#             'id': '6n4U3TlzUGhdSFbUUhTvLP',
#             'name': 'Walk It Talk It',
#             'uri': 'spotify:track:6n4U3TlzUGhdSFbUUhTvLP'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '5PfGowkEACnsIGuFau0nrR',
#                 'name': 'Squeeze Me (Music from The Spongebob Movie Sponge Out Of Water)',
#                 'uri': 'spotify:album:5PfGowkEACnsIGuFau0nrR'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/5wPoxI5si3eJsYYwyXV4Wi',
#                 'id': '5wPoxI5si3eJsYYwyXV4Wi',
#                 'name': 'N.E.R.D',
#                 'uri': 'spotify:artist:5wPoxI5si3eJsYYwyXV4Wi'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/7J0mZi4vIRqBR9pjAt90nX',
#             'id': '7J0mZi4vIRqBR9pjAt90nX',
#             'name': 'Squeeze Me - Music from The Spongebob Movie Sponge Out Of Water',
#             'uri': 'spotify:track:7J0mZi4vIRqBR9pjAt90nX'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '26mqgId4rrypPiYnN9tXuX',
#                 'name': 'The Kids Are Alright',
#                 'uri': 'spotify:album:26mqgId4rrypPiYnN9tXuX'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/0AsThoR4KZSVktALiNcQwW',
#                 'id': '0AsThoR4KZSVktALiNcQwW',
#                 'name': 'Chloe x Halle',
#                 'uri': 'spotify:artist:0AsThoR4KZSVktALiNcQwW'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/4VLViQtnHrWrDdDoigG3dR',
#             'id': '4VLViQtnHrWrDdDoigG3dR',
#             'name': 'The Kids Are Alright',
#             'uri': 'spotify:track:4VLViQtnHrWrDdDoigG3dR'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '2Ti79nwTsont5ZHfdxIzAm',
#                 'name': '?',
#                 'uri': 'spotify:album:2Ti79nwTsont5ZHfdxIzAm'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/15UsOTVnJzReFVN1VCnxy4',
#                 'id': '15UsOTVnJzReFVN1VCnxy4',
#                 'name': 'XXXTENTACION',
#                 'uri': 'spotify:artist:15UsOTVnJzReFVN1VCnxy4'
#             }],
#             'explicit': True,
#             'href': 'https://api.spotify.com/v1/tracks/3ee8Jmje8o58CHK66QrVC2',
#             'id': '3ee8Jmje8o58CHK66QrVC2',
#             'name': 'SAD!',
#             'uri': 'spotify:track:3ee8Jmje8o58CHK66QrVC2'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '3cyyJALrHc8LawnQNFYRWL',
#                 'name': 'Look At Me!',
#                 'uri': 'spotify:album:3cyyJALrHc8LawnQNFYRWL'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/15UsOTVnJzReFVN1VCnxy4',
#                 'id': '15UsOTVnJzReFVN1VCnxy4',
#                 'name': 'XXXTENTACION',
#                 'uri': 'spotify:artist:15UsOTVnJzReFVN1VCnxy4'
#             }],
#             'explicit': True,
#             'href': 'https://api.spotify.com/v1/tracks/7floNISpH8VF4z4459Qo18',
#             'id': '7floNISpH8VF4z4459Qo18',
#             'name': 'Look At Me!',
#             'uri': 'spotify:track:7floNISpH8VF4z4459Qo18'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '5VdyJkLe3yvOs0l4xXbWp0',
#                 'name': '17',
#                 'uri': 'spotify:album:5VdyJkLe3yvOs0l4xXbWp0'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/15UsOTVnJzReFVN1VCnxy4',
#                 'id': '15UsOTVnJzReFVN1VCnxy4',
#                 'name': 'XXXTENTACION',
#                 'uri': 'spotify:artist:15UsOTVnJzReFVN1VCnxy4'
#             }],
#             'explicit': True,
#             'href': 'https://api.spotify.com/v1/tracks/7m9OqQk4RVRkw9JJdeAw96',
#             'id': '7m9OqQk4RVRkw9JJdeAw96',
#             'name': 'Jocelyn Flores',
#             'uri': 'spotify:track:7m9OqQk4RVRkw9JJdeAw96'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '5VdyJkLe3yvOs0l4xXbWp0',
#                 'name': '17',
#                 'uri': 'spotify:album:5VdyJkLe3yvOs0l4xXbWp0'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/15UsOTVnJzReFVN1VCnxy4',
#                 'id': '15UsOTVnJzReFVN1VCnxy4',
#                 'name': 'XXXTENTACION',
#                 'uri': 'spotify:artist:15UsOTVnJzReFVN1VCnxy4'
#             }, {
#                 'href': 'https://api.spotify.com/v1/artists/6Xgp2XMz1fhVYe7i6yNAax',
#                 'id': '6Xgp2XMz1fhVYe7i6yNAax',
#                 'name': 'Trippie Redd',
#                 'uri': 'spotify:artist:6Xgp2XMz1fhVYe7i6yNAax'
#             }],
#             'explicit': True,
#             'href': 'https://api.spotify.com/v1/tracks/7AQim7LbvFVZJE3O8TYgf2',
#             'id': '7AQim7LbvFVZJE3O8TYgf2',
#             'name': 'Fuck Love (feat. Trippie Redd)',
#             'uri': 'spotify:track:7AQim7LbvFVZJE3O8TYgf2'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '2ybkO5lYEHOiZlAOe1KJrj',
#                 'name': 'Xanarchy',
#                 'uri': 'spotify:album:2ybkO5lYEHOiZlAOe1KJrj'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/3EXdLajEO02ziZ90P90bSW',
#                 'id': '3EXdLajEO02ziZ90P90bSW',
#                 'name': 'Lil Xan',
#                 'uri': 'spotify:artist:3EXdLajEO02ziZ90P90bSW'
#             }],
#             'explicit': True,
#             'href': 'https://api.spotify.com/v1/tracks/3etxMncvnemdyJlDVBuIat',
#             'id': '3etxMncvnemdyJlDVBuIat',
#             'name': 'Xanarchy',
#             'uri': 'spotify:track:3etxMncvnemdyJlDVBuIat'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '7GGoJfKFOwDNuiLjjfzyCS',
#                 'name': 'Look Alive (feat. Drake)',
#                 'uri': 'spotify:album:7GGoJfKFOwDNuiLjjfzyCS'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/4TEJudQY2pXxVHPE3gD2EU',
#                 'id': '4TEJudQY2pXxVHPE3gD2EU',
#                 'name': 'BlocBoy JB',
#                 'uri': 'spotify:artist:4TEJudQY2pXxVHPE3gD2EU'
#             }, {
#                 'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#                 'id': '3TVXtAsR1Inumwj472S9r4',
#                 'name': 'Drake',
#                 'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'
#             }],
#             'explicit': True,
#             'href': 'https://api.spotify.com/v1/tracks/4qKcDkK6siZ7Jp1Jb4m0aL',
#             'id': '4qKcDkK6siZ7Jp1Jb4m0aL',
#             'name': 'Look Alive (feat. Drake)',
#             'uri': 'spotify:track:4qKcDkK6siZ7Jp1Jb4m0aL'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '5UD36hu4fYZ6R8b8crkKL7',
#                 'name': 'Again (feat. XXXTENTACION)',
#                 'uri': 'spotify:album:5UD36hu4fYZ6R8b8crkKL7'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/55fhWPvDiMpLnE4ZzNXZyW',
#                 'id': '55fhWPvDiMpLnE4ZzNXZyW',
#                 'name': 'Noah Cyrus',
#                 'uri': 'spotify:artist:55fhWPvDiMpLnE4ZzNXZyW'
#             }, {
#                 'href': 'https://api.spotify.com/v1/artists/15UsOTVnJzReFVN1VCnxy4',
#                 'id': '15UsOTVnJzReFVN1VCnxy4',
#                 'name': 'XXXTENTACION',
#                 'uri': 'spotify:artist:15UsOTVnJzReFVN1VCnxy4'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/2S2od3hT7ceytw7d1pTRuE',
#             'id': '2S2od3hT7ceytw7d1pTRuE',
#             'name': 'Again (feat. XXXTENTACION)',
#             'uri': 'spotify:track:2S2od3hT7ceytw7d1pTRuE'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '6rVOUFV4qi8MgqF7na73rX',
#                 'name': 'Connection',
#                 'uri': 'spotify:album:6rVOUFV4qi8MgqF7na73rX'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/5Pwc4xIPtQLFEnJriah9YJ',
#                 'id': '5Pwc4xIPtQLFEnJriah9YJ',
#                 'name': 'OneRepublic',
#                 'uri': 'spotify:artist:5Pwc4xIPtQLFEnJriah9YJ'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/3T4UodGkfZObJ43RtA5KFU',
#             'id': '3T4UodGkfZObJ43RtA5KFU',
#             'name': 'Connection',
#             'uri': 'spotify:track:3T4UodGkfZObJ43RtA5KFU'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '5pLlGJrxuQO3jMoQe1XxZY',
#                 'name': 'Unapologetic (Deluxe)',
#                 'uri': 'spotify:album:5pLlGJrxuQO3jMoQe1XxZY'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#                 'id': '5pKCCKE2ajJHZ9KAiaK11H',
#                 'name': 'Rihanna',
#                 'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'
#             }, {
#                 'href': 'https://api.spotify.com/v1/artists/1buzCmyYZE4kcdLRudsb8V',
#                 'id': '1buzCmyYZE4kcdLRudsb8V',
#                 'name': 'Mikky Ekko',
#                 'uri': 'spotify:artist:1buzCmyYZE4kcdLRudsb8V'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/0GNI8K3VATWBABQFAzBAYe',
#             'id': '0GNI8K3VATWBABQFAzBAYe',
#             'name': 'Stay',
#             'uri': 'spotify:track:0GNI8K3VATWBABQFAzBAYe'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '1Val8NiAXyp2yTBiwZ53Ju',
#                 'name': 'Psycho (feat. Ty Dolla $ign)',
#                 'uri': 'spotify:album:1Val8NiAXyp2yTBiwZ53Ju'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#                 'id': '246dkjvS1zLTtiykXe5h60',
#                 'name': 'Post Malone',
#                 'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'
#             }, {
#                 'href': 'https://api.spotify.com/v1/artists/7c0XG5cIJTrrAgEC3ULPiq',
#                 'id': '7c0XG5cIJTrrAgEC3ULPiq',
#                 'name': 'Ty Dolla $ign',
#                 'uri': 'spotify:artist:7c0XG5cIJTrrAgEC3ULPiq'
#             }],
#             'explicit': True,
#             'href': 'https://api.spotify.com/v1/tracks/7wrDRQgHlvDnimrRHfQZxt',
#             'id': '7wrDRQgHlvDnimrRHfQZxt',
#             'name': 'Psycho (feat. Ty Dolla $ign)',
#             'uri': 'spotify:track:7wrDRQgHlvDnimrRHfQZxt'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '6pUg9RDDoVyQQVJ48FkmXz',
#                 'name': 'ATLAS',
#                 'uri': 'spotify:album:6pUg9RDDoVyQQVJ48FkmXz'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/2q3GG88dVwuQPF4FmySr9I',
#                 'id': '2q3GG88dVwuQPF4FmySr9I',
#                 'name': 'The Score',
#                 'uri': 'spotify:artist:2q3GG88dVwuQPF4FmySr9I'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/6rrKbzJGGDlSZgLphopS49',
#             'id': '6rrKbzJGGDlSZgLphopS49',
#             'name': 'Unstoppable',
#             'uri': 'spotify:track:6rrKbzJGGDlSZgLphopS49'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '78sVmB5I2WX4qPe74Gcv0t',
#                 'name': 'Do the Dash',
#                 'uri': 'spotify:album:78sVmB5I2WX4qPe74Gcv0t'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/4sw5s8BqMsNkOSZtNgACKv',
#                 'id': '4sw5s8BqMsNkOSZtNgACKv',
#                 'name': 'The Future Kingz',
#                 'uri': 'spotify:artist:4sw5s8BqMsNkOSZtNgACKv'
#             }],
#             'explicit': True,
#             'href': 'https://api.spotify.com/v1/tracks/5SkvvsR1DCTdLjgfz4RDyK',
#             'id': '5SkvvsR1DCTdLjgfz4RDyK',
#             'name': 'Do the Dash',
#             'uri': 'spotify:track:5SkvvsR1DCTdLjgfz4RDyK'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '5vXH2Az5rn9VnDN7TGJobX',
#                 'name': 'Talk',
#                 'uri': 'spotify:album:5vXH2Az5rn9VnDN7TGJobX'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/2jnIB6XdLvnJUeNTy5A0J2',
#                 'id': '2jnIB6XdLvnJUeNTy5A0J2',
#                 'name': "Why Don't We",
#                 'uri': 'spotify:artist:2jnIB6XdLvnJUeNTy5A0J2'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/4HYNtH7n3TrbbtRa94sA0K',
#             'id': '4HYNtH7n3TrbbtRa94sA0K',
#             'name': 'Talk',
#             'uri': 'spotify:track:4HYNtH7n3TrbbtRa94sA0K'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '02drHFQa59AoJWU6DXSSjd',
#                 'name': 'No Brainer',
#                 'uri': 'spotify:album:02drHFQa59AoJWU6DXSSjd'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/0QHgL1lAIqAw0HtD7YldmP',
#                 'id': '0QHgL1lAIqAw0HtD7YldmP',
#                 'name': 'DJ Khaled',
#                 'uri': 'spotify:artist:0QHgL1lAIqAw0HtD7YldmP'
#             }, {
#                 'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#                 'id': '1uNFoZAHBGtllmzznpCI3s',
#                 'name': 'Justin Bieber',
#                 'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'
#             }, {
#                 'href': 'https://api.spotify.com/v1/artists/0VRj0yCOv2FXJNP47XQnx5',
#                 'id': '0VRj0yCOv2FXJNP47XQnx5',
#                 'name': 'Quavo',
#                 'uri': 'spotify:artist:0VRj0yCOv2FXJNP47XQnx5'
#             }, {
#                 'href': 'https://api.spotify.com/v1/artists/1anyVhU62p31KFi8MEzkbf',
#                 'id': '1anyVhU62p31KFi8MEzkbf',
#                 'name': 'Chance the Rapper',
#                 'uri': 'spotify:artist:1anyVhU62p31KFi8MEzkbf'
#             }],
#             'explicit': True,
#             'href': 'https://api.spotify.com/v1/tracks/5WvAo7DNuPRmk4APhdPzi8',
#             'id': '5WvAo7DNuPRmk4APhdPzi8',
#             'name': 'No Brainer',
#             'uri': 'spotify:track:5WvAo7DNuPRmk4APhdPzi8'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '4X6lXwC3CnCcbQPtoFlIrF',
#                 'name': 'Movement',
#                 'uri': 'spotify:album:4X6lXwC3CnCcbQPtoFlIrF'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/6TLwD7HPWuiOzvXEa3oCNe',
#                 'id': '6TLwD7HPWuiOzvXEa3oCNe',
#                 'name': 'Oliver Tree',
#                 'uri': 'spotify:artist:6TLwD7HPWuiOzvXEa3oCNe'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/4OLI1dUkU9GFHm3IUgChaf',
#             'id': '4OLI1dUkU9GFHm3IUgChaf',
#             'name': 'Movement',
#             'uri': 'spotify:track:4OLI1dUkU9GFHm3IUgChaf'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '6j2MXtmfaGtIGnfrtGOWL9',
#                 'name': 'I Say So',
#                 'uri': 'spotify:album:6j2MXtmfaGtIGnfrtGOWL9'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/0AsThoR4KZSVktALiNcQwW',
#                 'id': '0AsThoR4KZSVktALiNcQwW',
#                 'name': 'Chloe x Halle',
#                 'uri': 'spotify:artist:0AsThoR4KZSVktALiNcQwW'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/4fhQ1ZR0VfptVsCNtXccuZ',
#             'id': '4fhQ1ZR0VfptVsCNtXccuZ',
#             'name': 'I Say So',
#             'uri': 'spotify:track:4fhQ1ZR0VfptVsCNtXccuZ'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '3vpXJ54S3MXLyzysw8qq7c',
#                 'name': 'Revenge',
#                 'uri': 'spotify:album:3vpXJ54S3MXLyzysw8qq7c'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/15UsOTVnJzReFVN1VCnxy4',
#                 'id': '15UsOTVnJzReFVN1VCnxy4',
#                 'name': 'XXXTENTACION',
#                 'uri': 'spotify:artist:15UsOTVnJzReFVN1VCnxy4'
#             }],
#             'explicit': True,
#             'href': 'https://api.spotify.com/v1/tracks/2ooF4088y5L72c4YTEJQoB',
#             'id': '2ooF4088y5L72c4YTEJQoB',
#             'name': 'YuNg BrAtZ',
#             'uri': 'spotify:track:2ooF4088y5L72c4YTEJQoB'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '33pt9HBdGlAbRGBHQgsZsU',
#                 'name': 'Evolve',
#                 'uri': 'spotify:album:33pt9HBdGlAbRGBHQgsZsU'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                 'id': '53XhwfbYqKCa1cC15pYq2q',
#                 'name': 'Imagine Dragons',
#                 'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/0pqnGHJpmpxLKifKRmU6WP',
#             'id': '0pqnGHJpmpxLKifKRmU6WP',
#             'name': 'Believer',
#             'uri': 'spotify:track:0pqnGHJpmpxLKifKRmU6WP'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '2v3AsVBhQVfsxd2RmFg5WG',
#                 'name': "What Everyone's Thinking",
#                 'uri': 'spotify:album:2v3AsVBhQVfsxd2RmFg5WG'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/6s22t5Y3prQHyaHWUN1R1C',
#                 'id': '6s22t5Y3prQHyaHWUN1R1C',
#                 'name': 'AJR',
#                 'uri': 'spotify:artist:6s22t5Y3prQHyaHWUN1R1C'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/45iMRHmfLZu3yjdZ8P5e3t',
#             'id': '45iMRHmfLZu3yjdZ8P5e3t',
#             'name': 'Weak',
#             'uri': 'spotify:track:45iMRHmfLZu3yjdZ8P5e3t'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '7pkLXlFdpQDfmHujT2AbBK',
#                 'name': 'Eastside (with Halsey & Khalid)',
#                 'uri': 'spotify:album:7pkLXlFdpQDfmHujT2AbBK'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/5CiGnKThu5ctn9pBxv7DGa',
#                 'id': '5CiGnKThu5ctn9pBxv7DGa',
#                 'name': 'benny blanco',
#                 'uri': 'spotify:artist:5CiGnKThu5ctn9pBxv7DGa'
#             }, {
#                 'href': 'https://api.spotify.com/v1/artists/26VFTg2z8YR0cCuwLzESi2',
#                 'id': '26VFTg2z8YR0cCuwLzESi2',
#                 'name': 'Halsey',
#                 'uri': 'spotify:artist:26VFTg2z8YR0cCuwLzESi2'
#             }, {
#                 'href': 'https://api.spotify.com/v1/artists/6LuN9FCkKOj5PcnpouEgny',
#                 'id': '6LuN9FCkKOj5PcnpouEgny',
#                 'name': 'Khalid',
#                 'uri': 'spotify:artist:6LuN9FCkKOj5PcnpouEgny'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/0d2iYfpKoM0QCKvcLCkBao',
#             'id': '0d2iYfpKoM0QCKvcLCkBao',
#             'name': 'Eastside (with Halsey & Khalid)',
#             'uri': 'spotify:track:0d2iYfpKoM0QCKvcLCkBao'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '5CqidnVWVxATLLgWn2Dl0e',
#                 'name': 'Leave Me Alone',
#                 'uri': 'spotify:album:5CqidnVWVxATLLgWn2Dl0e'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/2HUwZ0kumzCSlhFcjFZfpp',
#                 'id': '2HUwZ0kumzCSlhFcjFZfpp',
#                 'name': 'Flipp Dinero',
#                 'uri': 'spotify:artist:2HUwZ0kumzCSlhFcjFZfpp'
#             }],
#             'explicit': True,
#             'href': 'https://api.spotify.com/v1/tracks/5vDvBD3ReINP8dXUplj477',
#             'id': '5vDvBD3ReINP8dXUplj477',
#             'name': 'Leave Me Alone',
#             'uri': 'spotify:track:5vDvBD3ReINP8dXUplj477'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '2CH8od3NBJpsvqTdY3H1HH',
#                 'name': 'Jump (with Trippie Redd)',
#                 'uri': 'spotify:album:2CH8od3NBJpsvqTdY3H1HH'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/0ZED1XzwlLHW4ZaG4lOT6m',
#                 'id': '0ZED1XzwlLHW4ZaG4lOT6m',
#                 'name': 'Julia Michaels',
#                 'uri': 'spotify:artist:0ZED1XzwlLHW4ZaG4lOT6m'
#             }, {
#                 'href': 'https://api.spotify.com/v1/artists/6Xgp2XMz1fhVYe7i6yNAax',
#                 'id': '6Xgp2XMz1fhVYe7i6yNAax',
#                 'name': 'Trippie Redd',
#                 'uri': 'spotify:artist:6Xgp2XMz1fhVYe7i6yNAax'
#             }],
#             'explicit': True,
#             'href': 'https://api.spotify.com/v1/tracks/2OvV4NjEBRE9v8Oo7QeUCq',
#             'id': '2OvV4NjEBRE9v8Oo7QeUCq',
#             'name': 'Jump (with Trippie Redd)',
#             'uri': 'spotify:track:2OvV4NjEBRE9v8Oo7QeUCq'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '6aix4lgk9J4pz0pjbIowdo',
#                 'name': 'Trust Fund Baby',
#                 'uri': 'spotify:album:6aix4lgk9J4pz0pjbIowdo'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/2jnIB6XdLvnJUeNTy5A0J2',
#                 'id': '2jnIB6XdLvnJUeNTy5A0J2',
#                 'name': "Why Don't We",
#                 'uri': 'spotify:artist:2jnIB6XdLvnJUeNTy5A0J2'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/54j7EaJPDmSZYcNYvLSJ78',
#             'id': '54j7EaJPDmSZYcNYvLSJ78',
#             'name': 'Trust Fund Baby',
#             'uri': 'spotify:track:54j7EaJPDmSZYcNYvLSJ78'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '3p81zUBFZ3zdzxceXKeVSK',
#                 'name': 'Magic In The Hamptons (feat. Lil Yachty)',
#                 'uri': 'spotify:album:3p81zUBFZ3zdzxceXKeVSK'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/5UjifI1TYefXWn9GdqDOHl',
#                 'id': '5UjifI1TYefXWn9GdqDOHl',
#                 'name': 'Social House',
#                 'uri': 'spotify:artist:5UjifI1TYefXWn9GdqDOHl'
#             }, {
#                 'href': 'https://api.spotify.com/v1/artists/6icQOAFXDZKsumw3YXyusw',
#                 'id': '6icQOAFXDZKsumw3YXyusw',
#                 'name': 'Lil Yachty',
#                 'uri': 'spotify:artist:6icQOAFXDZKsumw3YXyusw'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/2Yer0p7uB2lVBUAtANuuQp',
#             'id': '2Yer0p7uB2lVBUAtANuuQp',
#             'name': 'Magic In The Hamptons (feat. Lil Yachty)',
#             'uri': 'spotify:track:2Yer0p7uB2lVBUAtANuuQp'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '3mN4QrBX6pOg0LcdhzT5Bi',
#                 'name': 'Bishop Briggs',
#                 'uri': 'spotify:album:3mN4QrBX6pOg0LcdhzT5Bi'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/0yb46jwm7gqbZXVXZQ8Z1e',
#                 'id': '0yb46jwm7gqbZXVXZQ8Z1e',
#                 'name': 'Bishop Briggs',
#                 'uri': 'spotify:artist:0yb46jwm7gqbZXVXZQ8Z1e'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/318CwhlHyuxroBtuoeh3oR',
#             'id': '318CwhlHyuxroBtuoeh3oR',
#             'name': "Dead Man's Arms",
#             'uri': 'spotify:track:318CwhlHyuxroBtuoeh3oR'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '5JzxLWdYLLpZTE6kaBLooY',
#                 'name': 'Snow Cougar',
#                 'uri': 'spotify:album:5JzxLWdYLLpZTE6kaBLooY'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/2YOYua8FpudSEiB9s88IgQ',
#                 'id': '2YOYua8FpudSEiB9s88IgQ',
#                 'name': 'Yung Gravy',
#                 'uri': 'spotify:artist:2YOYua8FpudSEiB9s88IgQ'
#             }],
#             'explicit': True,
#             'href': 'https://api.spotify.com/v1/tracks/4KtoztbBnU8JkP96u0B8HQ',
#             'id': '4KtoztbBnU8JkP96u0B8HQ',
#             'name': 'Knockout',
#             'uri': 'spotify:track:4KtoztbBnU8JkP96u0B8HQ'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '4sqrDaJcbCIo6aeqO26maj',
#                 'name': "Don't Leave Me Alone (feat. Anne-Marie)",
#                 'uri': 'spotify:album:4sqrDaJcbCIo6aeqO26maj'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/1Cs0zKBU1kc0i8ypK3B9ai',
#                 'id': '1Cs0zKBU1kc0i8ypK3B9ai',
#                 'name': 'David Guetta',
#                 'uri': 'spotify:artist:1Cs0zKBU1kc0i8ypK3B9ai'
#             }, {
#                 'href': 'https://api.spotify.com/v1/artists/1zNqDE7qDGCsyzJwohVaoX',
#                 'id': '1zNqDE7qDGCsyzJwohVaoX',
#                 'name': 'Anne-Marie',
#                 'uri': 'spotify:artist:1zNqDE7qDGCsyzJwohVaoX'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/2lYTJK94hb0fd1LQtb6Dhk',
#             'id': '2lYTJK94hb0fd1LQtb6Dhk',
#             'name': "Don't Leave Me Alone (feat. Anne-Marie)",
#             'uri': 'spotify:track:2lYTJK94hb0fd1LQtb6Dhk'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '0mRjvB3HLxs4Myma1f8vps',
#                 'name': 'Let Me Down Slowly',
#                 'uri': 'spotify:album:0mRjvB3HLxs4Myma1f8vps'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/5IH6FPUwQTxPSXurCrcIov',
#                 'id': '5IH6FPUwQTxPSXurCrcIov',
#                 'name': 'Alec Benjamin',
#                 'uri': 'spotify:artist:5IH6FPUwQTxPSXurCrcIov'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/2uaiyLKnYvazyfR0Ky3Kbk',
#             'id': '2uaiyLKnYvazyfR0Ky3Kbk',
#             'name': 'Let Me Down Slowly',
#             'uri': 'spotify:track:2uaiyLKnYvazyfR0Ky3Kbk'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '4Hwj8MyVYpdLEGKOFjVjQF',
#                 'name': 'Want To',
#                 'uri': 'spotify:album:4Hwj8MyVYpdLEGKOFjVjQF'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#                 'id': '6M2wZ9GZgrQXHCFfjv46we',
#                 'name': 'Dua Lipa',
#                 'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/5fK0Q3j2iUcQtiRDXlPW0K',
#             'id': '5fK0Q3j2iUcQtiRDXlPW0K',
#             'name': 'Want To',
#             'uri': 'spotify:track:5fK0Q3j2iUcQtiRDXlPW0K'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '41GuZcammIkupMPKH2OJ6I',
#                 'name': 'ASTROWORLD',
#                 'uri': 'spotify:album:41GuZcammIkupMPKH2OJ6I'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY',
#                 'id': '0Y5tJX1MQlPlqiwlOH1tJY',
#                 'name': 'Travis Scott',
#                 'uri': 'spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY'
#             }],
#             'explicit': True,
#             'href': 'https://api.spotify.com/v1/tracks/2xLMifQCjDGFmkHkpNLD9h',
#             'id': '2xLMifQCjDGFmkHkpNLD9h',
#             'name': 'SICKO MODE',
#             'uri': 'spotify:track:2xLMifQCjDGFmkHkpNLD9h'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '2x7pNYipWSrkKUnjzP9GhN',
#                 'name': "NOW That's What I Call Music, Vol. 62",
#                 'uri': 'spotify:album:2x7pNYipWSrkKUnjzP9GhN'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/23fqKkggKUBHNkbKtXEls4',
#                 'id': '23fqKkggKUBHNkbKtXEls4',
#                 'name': 'Kygo',
#                 'uri': 'spotify:artist:23fqKkggKUBHNkbKtXEls4'
#             }, {
#                 'href': 'https://api.spotify.com/v1/artists/0C8ZW7ezQVs4URX5aX7Kqx',
#                 'id': '0C8ZW7ezQVs4URX5aX7Kqx',
#                 'name': 'Selena Gomez',
#                 'uri': 'spotify:artist:0C8ZW7ezQVs4URX5aX7Kqx'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/677RjvAT2lpYjo1Whczjzx',
#             'id': '677RjvAT2lpYjo1Whczjzx',
#             'name': "It Ain't Me",
#             'uri': 'spotify:track:677RjvAT2lpYjo1Whczjzx'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '1KOmHyNLuOe5YrPhD3Juuf',
#                 'name': 'Perception',
#                 'uri': 'spotify:album:1KOmHyNLuOe5YrPhD3Juuf'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/6fOMl44jA4Sp5b9PpYCkzz',
#                 'id': '6fOMl44jA4Sp5b9PpYCkzz',
#                 'name': 'NF',
#                 'uri': 'spotify:artist:6fOMl44jA4Sp5b9PpYCkzz'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/52okn5MNA47tk87PeZJLEL',
#             'id': '52okn5MNA47tk87PeZJLEL',
#             'name': 'Let You Down',
#             'uri': 'spotify:track:52okn5MNA47tk87PeZJLEL'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '3HNnxK7NgLXbDoxRZxNWiR',
#                 'name': 'Kamikaze',
#                 'uri': 'spotify:album:3HNnxK7NgLXbDoxRZxNWiR'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#                 'id': '7dGJo4pcD2V6oG8kP0tJRR',
#                 'name': 'Eminem',
#                 'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'
#             }, {
#                 'href': 'https://api.spotify.com/v1/artists/6C1ohJrd5VydigQtaGy5Wa',
#                 'id': '6C1ohJrd5VydigQtaGy5Wa',
#                 'name': 'Joyner Lucas',
#                 'uri': 'spotify:artist:6C1ohJrd5VydigQtaGy5Wa'
#             }],
#             'explicit': True,
#             'href': 'https://api.spotify.com/v1/tracks/60SdxE8apGAxMiRrpbmLY0',
#             'id': '60SdxE8apGAxMiRrpbmLY0',
#             'name': 'Lucky You (feat. Joyner Lucas)',
#             'uri': 'spotify:track:60SdxE8apGAxMiRrpbmLY0'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '0YZLXTaHLcgl5UdtKDiUXD',
#                 'name': 'Be Alright',
#                 'uri': 'spotify:album:0YZLXTaHLcgl5UdtKDiUXD'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/3QSQFmccmX81fWCUSPTS7y',
#                 'id': '3QSQFmccmX81fWCUSPTS7y',
#                 'name': 'Dean Lewis',
#                 'uri': 'spotify:artist:3QSQFmccmX81fWCUSPTS7y'
#             }],
#             'explicit': True,
#             'href': 'https://api.spotify.com/v1/tracks/3EPXxR3ImUwfayaurPi3cm',
#             'id': '3EPXxR3ImUwfayaurPi3cm',
#             'name': 'Be Alright',
#             'uri': 'spotify:track:3EPXxR3ImUwfayaurPi3cm'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '2D0Hi3Jj6RFnpWDcSa0Otu',
#                 'name': 'Youngblood (Deluxe)',
#                 'uri': 'spotify:album:2D0Hi3Jj6RFnpWDcSa0Otu'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/5Rl15oVamLq7FbSb0NNBNy',
#                 'id': '5Rl15oVamLq7FbSb0NNBNy',
#                 'name': '5 Seconds of Summer',
#                 'uri': 'spotify:artist:5Rl15oVamLq7FbSb0NNBNy'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/19hh7DkfRBrpRGYfKlw7jb',
#             'id': '19hh7DkfRBrpRGYfKlw7jb',
#             'name': 'Valentine',
#             'uri': 'spotify:track:19hh7DkfRBrpRGYfKlw7jb'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '0Z5H1G2rS6VU79FIObKVXT',
#                 'name': 'Sincerity Is Scary',
#                 'uri': 'spotify:album:0Z5H1G2rS6VU79FIObKVXT'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/3mIj9lX2MWuHmhNCA7LSCW',
#                 'id': '3mIj9lX2MWuHmhNCA7LSCW',
#                 'name': 'The 1975',
#                 'uri': 'spotify:artist:3mIj9lX2MWuHmhNCA7LSCW'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/06Vthiq8nNDuT5nOcch535',
#             'id': '06Vthiq8nNDuT5nOcch535',
#             'name': 'Sincerity Is Scary',
#             'uri': 'spotify:track:06Vthiq8nNDuT5nOcch535'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '3rar7GKCodqR9GIIiNe75H',
#                 'name': 'Natural',
#                 'uri': 'spotify:album:3rar7GKCodqR9GIIiNe75H'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                 'id': '53XhwfbYqKCa1cC15pYq2q',
#                 'name': 'Imagine Dragons',
#                 'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/4zIO3ilp5HvTeK3HJHxhMP',
#             'id': '4zIO3ilp5HvTeK3HJHxhMP',
#             'name': 'Natural',
#             'uri': 'spotify:track:4zIO3ilp5HvTeK3HJHxhMP'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '4Lp0jynclQS3WCmxJZCFOl',
#                 'name': 'Chasing Colors (feat. Noah Cyrus)',
#                 'uri': 'spotify:album:4Lp0jynclQS3WCmxJZCFOl'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/64KEffDW9EtZ1y2vBYgq8T',
#                 'id': '64KEffDW9EtZ1y2vBYgq8T',
#                 'name': 'Marshmello',
#                 'uri': 'spotify:artist:64KEffDW9EtZ1y2vBYgq8T'
#             }, {
#                 'href': 'https://api.spotify.com/v1/artists/1HQGhla3VNj1dBmKTtVT2t',
#                 'id': '1HQGhla3VNj1dBmKTtVT2t',
#                 'name': 'Ookay',
#                 'uri': 'spotify:artist:1HQGhla3VNj1dBmKTtVT2t'
#             }, {
#                 'href': 'https://api.spotify.com/v1/artists/55fhWPvDiMpLnE4ZzNXZyW',
#                 'id': '55fhWPvDiMpLnE4ZzNXZyW',
#                 'name': 'Noah Cyrus',
#                 'uri': 'spotify:artist:55fhWPvDiMpLnE4ZzNXZyW'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/1VxogbO6bfygdfaCnE9oLb',
#             'id': '1VxogbO6bfygdfaCnE9oLb',
#             'name': 'Chasing Colors (feat. Noah Cyrus)',
#             'uri': 'spotify:track:1VxogbO6bfygdfaCnE9oLb'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '3cQO7jp5S9qLBoIVtbkSM1',
#                 'name': 'Blurryface',
#                 'uri': 'spotify:album:3cQO7jp5S9qLBoIVtbkSM1'
#             },
#             'artists': [{
# ...
#                 'id': '7n2wHs1TKAczGzO7Dd2rGr',
#                 'name': 'Shawn Mendes',
#                 'uri': 'spotify:artist:7n2wHs1TKAczGzO7Dd2rGr'
#             }, {
#                 'href': 'https://api.spotify.com/v1/artists/2qxJFvFYMEDqd7ui6kSAcq',
#                 'id': '2qxJFvFYMEDqd7ui6kSAcq',
#                 'name': 'Zedd',
#                 'uri': 'spotify:artist:2qxJFvFYMEDqd7ui6kSAcq'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/575NJxNUVDqwJGdzBrlLbv',
#             'id': '575NJxNUVDqwJGdzBrlLbv',
#             'name': 'Lost In Japan - Remix',
#             'uri': 'spotify:track:575NJxNUVDqwJGdzBrlLbv'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '429B3se6xtZuvblNnS2iy7',
#                 'name': 'Electricity (with Dua Lipa)',
#                 'uri': 'spotify:album:429B3se6xtZuvblNnS2iy7'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/2X97ZAqRKRMYFIDqtvGgGc',
#                 'id': '2X97ZAqRKRMYFIDqtvGgGc',
#                 'name': 'Silk City',
#                 'uri': 'spotify:artist:2X97ZAqRKRMYFIDqtvGgGc'
#             }, {
#                 'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#                 'id': '6M2wZ9GZgrQXHCFfjv46we',
#                 'name': 'Dua Lipa',
#                 'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'
#             }, {
#                 'href': 'https://api.spotify.com/v1/artists/5fMUXHkw8R8eOP2RNVYEZX',
#                 'id': '5fMUXHkw8R8eOP2RNVYEZX',
#                 'name': 'Diplo',
#                 'uri': 'spotify:artist:5fMUXHkw8R8eOP2RNVYEZX'
#             }, {
#                 'href': 'https://api.spotify.com/v1/artists/3hv9jJF3adDNsBSIQDqcjp',
#                 'id': '3hv9jJF3adDNsBSIQDqcjp',
#                 'name': 'Mark Ronson',
#                 'uri': 'spotify:artist:3hv9jJF3adDNsBSIQDqcjp'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/5N4erncE7kuUccm7zEmwzk',
#             'id': '5N4erncE7kuUccm7zEmwzk',
#             'name': 'Electricity (with Dua Lipa)',
#             'uri': 'spotify:track:5N4erncE7kuUccm7zEmwzk'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '2rQu10gUgBVYzgsitDZNyU',
#                 'name': 'aurora',
#                 'uri': 'spotify:album:2rQu10gUgBVYzgsitDZNyU'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/1o2NpYGqHiCq7FoiYdyd1x',
#                 'id': '1o2NpYGqHiCq7FoiYdyd1x',
#                 'name': 'Bea Miller',
#                 'uri': 'spotify:artist:1o2NpYGqHiCq7FoiYdyd1x'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/6E37j4b44JGpdk297urpKM',
#             'id': '6E37j4b44JGpdk297urpKM',
#             'name': 'like that',
#             'uri': 'spotify:track:6E37j4b44JGpdk297urpKM'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '0YcBWlnJCLef8qsaHaFtfU',
#                 'name': 'BAD!',
#                 'uri': 'spotify:album:0YcBWlnJCLef8qsaHaFtfU'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/15UsOTVnJzReFVN1VCnxy4',
#                 'id': '15UsOTVnJzReFVN1VCnxy4',
#                 'name': 'XXXTENTACION',
#                 'uri': 'spotify:artist:15UsOTVnJzReFVN1VCnxy4'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/4CH66Rxcjcj3VBHwmIBj4T',
#             'id': '4CH66Rxcjcj3VBHwmIBj4T',
#             'name': 'BAD!',
#             'uri': 'spotify:track:4CH66Rxcjcj3VBHwmIBj4T'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '2Ti79nwTsont5ZHfdxIzAm',
#                 'name': '?',
#                 'uri': 'spotify:album:2Ti79nwTsont5ZHfdxIzAm'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/15UsOTVnJzReFVN1VCnxy4',
#                 'id': '15UsOTVnJzReFVN1VCnxy4',
#                 'name': 'XXXTENTACION',
#                 'uri': 'spotify:artist:15UsOTVnJzReFVN1VCnxy4'
#             }],
#             'explicit': True,
#             'href': 'https://api.spotify.com/v1/tracks/2ZRo7axmMPeSVUvDbGkJah',
#             'id': '2ZRo7axmMPeSVUvDbGkJah',
#             'name': 'Hope',
#             'uri': 'spotify:track:2ZRo7axmMPeSVUvDbGkJah'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '0AsWVAi3HVTdH6OcgOPxTs',
#                 'name': 'That Vibe',
#                 'uri': 'spotify:album:0AsWVAi3HVTdH6OcgOPxTs'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/3rPvm8XwWnYfRS4H3Ql0je',
#                 'id': '3rPvm8XwWnYfRS4H3Ql0je',
#                 'name': 'The TVC',
#                 'uri': 'spotify:artist:3rPvm8XwWnYfRS4H3Ql0je'
#             }, {
#                 'href': 'https://api.spotify.com/v1/artists/636tbena1jAOUIGdEOHZ6w',
#                 'id': '636tbena1jAOUIGdEOHZ6w',
#                 'name': 'Cass XQ',
#                 'uri': 'spotify:artist:636tbena1jAOUIGdEOHZ6w'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/3sPXeEX8BdT4hFezbbmeha',
#             'id': '3sPXeEX8BdT4hFezbbmeha',
#             'name': 'That Vibe',
#             'uri': 'spotify:track:3sPXeEX8BdT4hFezbbmeha'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '684W6NpKllEexqQlGqetCi',
#                 'name': 'thank u, next',
#                 'uri': 'spotify:album:684W6NpKllEexqQlGqetCi'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#                 'id': '66CXWjxzNUsdJxJ2JdwvnR',
#                 'name': 'Ariana Grande',
#                 'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'
#             }],
#             'explicit': True,
#             'href': 'https://api.spotify.com/v1/tracks/2rPE9A1vEgShuZxxzR2tZH',
#             'id': '2rPE9A1vEgShuZxxzR2tZH',
#             'name': 'thank u, next',
#             'uri': 'spotify:track:2rPE9A1vEgShuZxxzR2tZH'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '6VCDStheOuhrQaoYbHP2iO',
#                 'name': 'On the Run',
#                 'uri': 'spotify:album:6VCDStheOuhrQaoYbHP2iO'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/50co4Is1HCEo8bhOyUWKpn',
#                 'id': '50co4Is1HCEo8bhOyUWKpn',
#                 'name': 'Young Thug',
#                 'uri': 'spotify:artist:50co4Is1HCEo8bhOyUWKpn'
#             }, {
#                 'href': 'https://api.spotify.com/v1/artists/0xOeVMOz2fVg5BJY3N6akT',
#                 'id': '0xOeVMOz2fVg5BJY3N6akT',
#                 'name': 'Jaden',
#                 'uri': 'spotify:artist:0xOeVMOz2fVg5BJY3N6akT'
#             }],
#             'explicit': True,
#             'href': 'https://api.spotify.com/v1/tracks/1Jl21sidRpEdlVBvYbssLx',
#             'id': '1Jl21sidRpEdlVBvYbssLx',
#             'name': 'Sin (feat. Jaden Smith)',
#             'uri': 'spotify:track:1Jl21sidRpEdlVBvYbssLx'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '2drqVzCt52KiDxKgl0Rq0P',
#                 'name': 'Money',
#                 'uri': 'spotify:album:2drqVzCt52KiDxKgl0Rq0P'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/4kYSro6naA4h99UJvo89HB',
#                 'id': '4kYSro6naA4h99UJvo89HB',
#                 'name': 'Cardi B',
#                 'uri': 'spotify:artist:4kYSro6naA4h99UJvo89HB'
#             }],
#             'explicit': True,
#             'href': 'https://api.spotify.com/v1/tracks/2GGMabyHXnJmjY6CXhhB2e',
#             'id': '2GGMabyHXnJmjY6CXhhB2e',
#             'name': 'Money',
#             'uri': 'spotify:track:2GGMabyHXnJmjY6CXhhB2e'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '1NZBzIrSV5yca91Su4i1MC',
#                 'name': 'The Click (Deluxe Edition)',
#                 'uri': 'spotify:album:1NZBzIrSV5yca91Su4i1MC'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/6s22t5Y3prQHyaHWUN1R1C',
#                 'id': '6s22t5Y3prQHyaHWUN1R1C',
#                 'name': 'AJR',
#                 'uri': 'spotify:artist:6s22t5Y3prQHyaHWUN1R1C'
#             }],
#             'explicit': True,
#             'href': 'https://api.spotify.com/v1/tracks/0j7pdNXDzEVQST5Zcoh5xo',
#             'id': '0j7pdNXDzEVQST5Zcoh5xo',
#             'name': 'Burn the House Down',
#             'uri': 'spotify:track:0j7pdNXDzEVQST5Zcoh5xo'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '2Ti79nwTsont5ZHfdxIzAm',
#                 'name': '?',
#                 'uri': 'spotify:album:2Ti79nwTsont5ZHfdxIzAm'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/15UsOTVnJzReFVN1VCnxy4',
#                 'id': '15UsOTVnJzReFVN1VCnxy4',
#                 'name': 'XXXTENTACION',
#                 'uri': 'spotify:artist:15UsOTVnJzReFVN1VCnxy4'
#             }],
#             'explicit': True,
#             'href': 'https://api.spotify.com/v1/tracks/7CkbRn6S0itJqcqn88AtSV',
#             'id': '7CkbRn6S0itJqcqn88AtSV',
#             'name': 'going down!',
#             'uri': 'spotify:track:7CkbRn6S0itJqcqn88AtSV'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '5YLRVHDVRw3QqWbeTGpC5B',
#                 'name': 'So Good',
#                 'uri': 'spotify:album:5YLRVHDVRw3QqWbeTGpC5B'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/1Xylc3o4UrD53lo9CvFvVg',
#                 'id': '1Xylc3o4UrD53lo9CvFvVg',
#                 'name': 'Zara Larsson',
#                 'uri': 'spotify:artist:1Xylc3o4UrD53lo9CvFvVg'
#             }, {
#                 'href': 'https://api.spotify.com/v1/artists/7uMh23xWiuR7zsNkuNcm2G',
#                 'id': '7uMh23xWiuR7zsNkuNcm2G',
#                 'name': 'MNEK',
#                 'uri': 'spotify:artist:7uMh23xWiuR7zsNkuNcm2G'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/6hmhG1b4LEyNuashVvuIAo',
#             'id': '6hmhG1b4LEyNuashVvuIAo',
#             'name': 'Never Forget You',
#             'uri': 'spotify:track:6hmhG1b4LEyNuashVvuIAo'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '6pCYWWK3GomeTRX2SlxhHc',
#                 'name': 'Pumped Up',
#                 'uri': 'spotify:album:6pCYWWK3GomeTRX2SlxhHc'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/1L9i6qZYIGQedgM9QLSyzb',
#                 'id': '1L9i6qZYIGQedgM9QLSyzb',
#                 'name': 'Klingande',
#                 'uri': 'spotify:artist:1L9i6qZYIGQedgM9QLSyzb'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/4BM4ml3TgBFALLaCaJtVhi',
#             'id': '4BM4ml3TgBFALLaCaJtVhi',
#             'name': 'Pumped Up',
#             'uri': 'spotify:track:4BM4ml3TgBFALLaCaJtVhi'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '3MecVG0PeBObAhjwEAczFG',
#                 'name': 'Bloody Tourists',
#                 'uri': 'spotify:album:3MecVG0PeBObAhjwEAczFG'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/6i6WlGzQtXtz7GcC5H5st5',
#                 'id': '6i6WlGzQtXtz7GcC5H5st5',
#                 'name': '10cc',
#                 'uri': 'spotify:artist:6i6WlGzQtXtz7GcC5H5st5'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/1LOZMYF5s8qhW7Rv4w2gun',
#             'id': '1LOZMYF5s8qhW7Rv4w2gun',
#             'name': 'Dreadlock Holiday',
#             'uri': 'spotify:track:1LOZMYF5s8qhW7Rv4w2gun'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '5vAFBjdb2XJCyYp2zlwJDI',
#                 'name': 'Borrowed Time',
#                 'uri': 'spotify:album:5vAFBjdb2XJCyYp2zlwJDI'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/0qG3lxHmrUeKzL1BJJ7IBN',
#                 'id': '0qG3lxHmrUeKzL1BJJ7IBN',
#                 'name': 'Michl',
#                 'uri': 'spotify:artist:0qG3lxHmrUeKzL1BJJ7IBN'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/6T2mmu1pbqUDb0PYr2ca09',
#             'id': '6T2mmu1pbqUDb0PYr2ca09',
#             'name': 'Borrowed Time',
#             'uri': 'spotify:track:6T2mmu1pbqUDb0PYr2ca09'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '02sEJTj1sye1JaqxqpcSCp',
#                 'name': 'Encore',
#                 'uri': 'spotify:album:02sEJTj1sye1JaqxqpcSCp'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/540vIaP2JwjQb9dm3aArA4',
#                 'id': '540vIaP2JwjQb9dm3aArA4',
#                 'name': 'DJ Snake',
#                 'uri': 'spotify:artist:540vIaP2JwjQb9dm3aArA4'
#             }, {
#                 'href': 'https://api.spotify.com/v1/artists/0CjWKoS55T7DOt0HJuwF1H',
#                 'id': '0CjWKoS55T7DOt0HJuwF1H',
#                 'name': 'Bipolar Sunshine',
#                 'uri': 'spotify:artist:0CjWKoS55T7DOt0HJuwF1H'
#             }],
#             'explicit': False,
#             'href': 'https://api.spotify.com/v1/tracks/0g5EKLgdKvNlln7TNqBByK',
#             'id': '0g5EKLgdKvNlln7TNqBByK',
#             'name': 'Middle',
#             'uri': 'spotify:track:0g5EKLgdKvNlln7TNqBByK'
#         }
#     }, {
#         'added_by': {
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'track': {
#             'album': {
#                 'id': '0TIU7ja1rRQo6YhCUuu4T6',
#                 'name': 'Love None',
#                 'uri': 'spotify:album:0TIU7ja1rRQo6YhCUuu4T6'
#             },
#             'artists': [{
#                 'href': 'https://api.spotify.com/v1/artists/7uzZk9ysYBs4JYrQoI1zS6',
#                 'id': '7uzZk9ysYBs4JYrQoI1zS6',
#                 'name': 'Gee Yuhh',
#                 'uri': 'spotify:artist:7uzZk9ysYBs4JYrQoI1zS6'
#             }],
#             'explicit': True,
#             'href': 'https://api.spotify.com/v1/tracks/4xxnseavj6p3l3HMIAT9sU',
#             'id': '4xxnseavj6p3l3HMIAT9sU',
#             'name': 'Love None',
#             'uri': 'spotify:track:4xxnseavj6p3l3HMIAT9sU'
#         }
#     }],
#     'limit': 100,
#     'next': 'https://api.spotify.com/v1/playlists/6AAW33WKzlJaN0JMqjC3xC/tracks?offset=100&limit=100&fields=items(added_by.id,uri,track(name,artists(href,id,uri,name,spotify),id,uri,duration,explicit,href,album(name,id,uri))),href,limit,next,offset,previous,total',
#     'offset': 0,
#     'previous': None,
#     'total': 2155
# }

# %%
# #Parsing playlist functionality

# target_playlist_items = []
# for item in playlist_items_response['items']:
#     artists = []
#     for i in item['track']['artists']:
#         w = {'name' : i['name'],
#              'id' : i['id']
#             }
#         #w = {i['name'] : i['id']}
#         artists.append(w)
        
#     q = {'song_name' : item['track']['name'], 'id' : item['track']['id'],
#                                   'artists' : artists }
#     target_playlist_items.append(q)

# #print(target_playlist_items)
# pd(target_playlist_items)

sc.clear_playlist_items()
rep = sc.parse_playlist_items(playlist_items_response)
#pd(rep)

# %%
#create the list of songs containing the target artist
target_artist_id
target_songs = []
for x in rep:
    for i in x['artists']:
        if i['id'] == target_artist_id:
            target_songs.append(x)
            break

#pd(target_songs)

#create a list of the uris of the target songs
target_songs_uri = []
for i in target_songs:
    target_songs_uri.append(i['uri'])
print(target_songs_uri)
# Out:
# ['spotify:track:6vN77lE9LK6HP2DewaN6HZ', 'spotify:track:6n4U3TlzUGhdSFbUUhTvLP', 'spotify:track:4qKcDkK6siZ7Jp1Jb4m0aL', 'spotify:track:0TlLq3lA83rQOYtrqBqSct', 'spotify:track:2IRZnDFmlqMuOrYOLnZZyc', 'spotify:track:4n4BflhWjCHIxrI4v7Xt9s', 'spotify:track:2sqsNXfN0HtgDEgaHXiUTa', 'spotify:track:5r7WvQtyPfy1xch5zMgGRp', 'spotify:track:5yY9lUy8nbvjM1Uyo1Uqoc', 'spotify:track:6Kj17Afjo1OKJYpf5VzCeo', 'spotify:track:6EDO9iiTtwNv6waLwa1UUq', 'spotify:track:5InOp6q2vvx0fShv3bzFLZ', 'spotify:track:1bzM1cd6oqFozdr4wK6HdR', 'spotify:track:2SAqBLGA283SUiwJ3xOUVI', 'spotify:track:0LEFmgIj8ABU7CelzGh5Bs', 'spotify:track:6Kj17Afjo1OKJYpf5VzCeo', 'spotify:track:2of5xn0GU0TdFneR1saRLH', 'spotify:track:4qKcDkK6siZ7Jp1Jb4m0aL', 'spotify:track:3aQem4jVGdhtg116TmJnHz', 'spotify:track:5mCPDVBb16L4XQwDdbRUpz', 'spotify:track:35RJhm1pEovTBwnNR0zWad', 'spotify:track:0TlLq3lA83rQOYtrqBqSct', 'spotify:track:5r7WvQtyPfy1xch5zMgGRp', 'spotify:track:65OVbaJR5O1RmwOQx0875b', 'spotify:track:3yaYgjEFkRw3PVjW9mV1TO', 'spotify:track:1zi7xx7UVEFkmKfv06H8x0', 'spotify:track:0wwPcA6wtMf6HUMpIRdeP7', 'spotify:track:40iJIUlhi6renaREYGeIDS', 'spotify:track:4s7QLoImIwmPi9L6dq1nVW', 'spotify:track:2HSmyk2qMN8WQjuGhaQgCk', 'spotify:track:0k1WUmIRnG3xU6fvvDVfRG', 'spotify:track:6jy9yJfgCsMHdu2Oz4BGKX', 'spotify:track:4VCbgIdr8ptegWeJpqLVHH', 'spotify:track:3NxAG2ni1lLa8RKL6a0INc', 'spotify:track:3keUgTGEoZJt0QkzTB6kHg', 'spotify:track:5H4mXWKcicuLKDn4Jy0sK7', 'spotify:track:4KDNRh9Oor80z3XIxdWlui', 'spotify:track:4OENnoidV0h8gJV6bhrw7r', 'spotify:track:4ezAjoV01phDz1SqO6SzEU', 'spotify:track:1bzM1cd6oqFozdr4wK6HdR', 'spotify:track:2BcMwX1MPV6ZHP4tUT9uq6', 'spotify:track:6HSqyfGnsHYw9MmIpa9zlZ', 'spotify:track:0lEjxUUlKqjqXrVlIHFduD', 'spotify:track:23NWj2izXAJ4yL6Nah73wf', 'spotify:track:3F5CgOj3wFlRv51JsHbxhe', 'spotify:track:0nAZGkBGKQCXyaoSJfRhC1', 'spotify:track:4rmVZajAF7PkrCagGPHbqa', 'spotify:track:433P7tDcIAi6NLnf4Sh6tI', 'spotify:track:32UIpKdyGzgTPTO8e5ge5c', 'spotify:track:2tUL6dZf1mywCj5WvCPZw6', 'spotify:track:1XsRwo2it6QHdV2OiT6IzF', 'spotify:track:4n1bdaKwynQndm47x5HqWX', 'spotify:track:0g2Bbgy7P41pFjMWJuzsf4', 'spotify:track:6wyhUr4Xw8z5uSy0AhoZfU', 'spotify:track:7y911sqgHGHcyU4ivapjwi', 'spotify:track:59nOXPmaKlBfGMDeOVGrIK', 'spotify:track:3EMp20j5E42MxfFbsEsIvD', 'spotify:track:3cjF2OFRmip8spwZYQRKxP', 'spotify:track:6cblRiEGDRNZgowcm951R3', 'spotify:track:1bDbXMyjaUIooNwFE9wn0N', 'spotify:track:46s57QULU02Voy0Kup6UEb', 'spotify:track:34tz0eDhGuFErIuW3q4mPX', 'spotify:track:0wshkEEcJUQU33RSRBb5dv', 'spotify:track:2ZL7WZcjuYKi1KUDtp4kCC', 'spotify:track:4Flfb4fGscN9kXPOduQLrv', 'spotify:track:2KLwPaRDOB87XOYAT2fgxh', 'spotify:track:45pUWUeEWGoSdH6UF162G8', 'spotify:track:2ZlABhxMMa43COmZ97kKsJ', 'spotify:track:7l2nxyx7IkBX5orhkALg0V', 'spotify:track:7GeTsDIc5ykNB6lORO6Cee', 'spotify:track:410TZrK18uRjtsTunG14cl', 'spotify:track:28JBD8p18xNuOfyV7Cotdn', 'spotify:track:4FRW5Nza1Ym91BGV4nFWXI', 'spotify:track:2P3SLxeQHPqh8qKB6gtJY2', 'spotify:track:5yY9lUy8nbvjM1Uyo1Uqoc']

# %%
# (self, resource_type='users', version='v1', user_id='null', 
#                         name=None, description='', public=False, artist=None, playlist_name=None)
cplay = sc.create_playlist(user_id='y4yjmhqzanyc6musw2wjfi1hv',description='A playlist of Drake songs in IKE playlist', artist='Drake', playlist_name='Ike')
cplay
# Out:
# {'collaborative': False,
#  'description': 'A playlist of Drake songs in IKE playlist',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/5bafUXvO08JfyfLbkrY8dk'},
#  'followers': {'href': None, 'total': 0},
#  'href': 'https://api.spotify.com/v1/playlists/5bafUXvO08JfyfLbkrY8dk',
#  'id': '5bafUXvO08JfyfLbkrY8dk',
#  'images': [],
#  'name': 'Drake : Ike',
#  'owner': {'display_name': 'Ike',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/y4yjmhqzanyc6musw2wjfi1hv'},
#   'href': 'https://api.spotify.com/v1/users/y4yjmhqzanyc6musw2wjfi1hv',
#   'id': 'y4yjmhqzanyc6musw2wjfi1hv',
#   'type': 'user',
#   'uri': 'spotify:user:y4yjmhqzanyc6musw2wjfi1hv'},
#  'primary_color': None,
#  'public': False,
#  'snapshot_id': 'MSw3N2M1Mzc3MTZmYjMwYmUxM2Q5YmMwNTU1YWNkODdiMzMwMzJkMWM4',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/5bafUXvO08JfyfLbkrY8dk/tracks',
#   'items': [],
#   'limit': 100,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 0},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:5bafUXvO08JfyfLbkrY8dk'}

# %%
#add_song_to_playlist(self, resource_type='playlists', version='v1', uri_list=None, playlist_id=None)
done = sc.add_song_to_playlist(uri_list=target_songs_uri, playlist_id=cplay['id'])
print(done)
# Out:
# {'snapshot_id': 'MyxkZGFkY2EzY2RlOTg1YjZlMDlmZTI1NmNlMzY5MjE2Y2E4NjVjYTQ0'}
