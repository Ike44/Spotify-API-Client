# %%
#!pip install requests
#!pip install print-dict

# %%
import base64
import datetime
from urllib.parse import urlencode
import requests as rq
import webbrowser
from print_dict import pd
import os
from dotenv import load_dotenv

# %%
#Client Info
load_dotenv("./config.env")
client_secret = os.getenv("CLIENT_SECRET")
client_id = os.getenv("CLIENT_ID")

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = "https://accounts.spotify.com/api/token"
    auth_url = "https://accounts.spotify.com/authorize"
    baseURL = 'https://api.spotify.com/v1'
    auth_code = None
    refresh_token = None
    
    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret
        self.perform_login()
    
    def get_client_credentials(self):
        """
        Returns a base64 string
        """
        client_id = self.client_id
        client_secret = self.client_secret
        if client_secret == None or client_id == None:
            raise Exception("You must set client_id and client_secret.")
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
    
    def get_token_headers(self):
        
        client_creds_b64 = self.get_client_credentials()
        return {
            "Authorization": f"Basic {client_creds_b64}"
        }
    
    def get_auth_data(self):
        auth_data = {
            'client_id' : self.client_id,
            'response_type' : 'code',
            'redirect_uri' : 'http://localhost:3000/',
            'scope' : 'playlist-read-private playlist-read-collaborative playlist-modify-public playlist-modify-private user-read-private user-read-email'
            }
        return auth_data
    
    def perform_login(self):
        response = rq.get(self.auth_url, params=self.get_auth_data())
        if response.status_code not in range(200, 299):
            raise Exception("Could not login!")
        webbrowser.open(response.url)
    
    def parse_url_for_code(self, redirect_url=None):
        #parse URL for code
        if redirect_url == None:
            raise Exception("Invalid URL")
        response_url = redirect_url
        split_url = response_url.split('?')
        split_url = split_url[1].split('=')
        #print(split_url)
        auth_code1 = split_url[1]
        #return auth_code
        self.auth_code = auth_code1
        self.get_initial_access_token()
    
    def get_initial_token_data(self):
        token_data = {
            'grant_type' : "authorization_code",
            'code' : self.auth_code,
            'redirect_uri' : 'http://localhost:3000/',
            'client_id' : self.client_id,
            'client_secret': self.client_secret
        }
        return token_data
    
    def get_initial_access_token(self):
        auth_response = rq.post(url=self.token_url, data=self.get_initial_token_data())
        if auth_response.status_code not in range(200, 299):
            raise Exception("Could not get initial access token")
        s = auth_response.json()
        now = datetime.datetime.now()
        self.access_token = s['access_token']
        self.refresh_token = s['refresh_token']
        expires_in = s['expires_in']
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True 
    
    
    def get_refresh_token_data(self):
#         return {
#             'grant_type' : "client_credentials"
#         }
        refresh_data= {
            'grant_type':'refresh_token',
            'refresh_token': self.refresh_token,
            'client_id' : self.client_id,
            'client_secret': self.client_secret
        }
        return refresh_data

    
    def perform_auth(self):
        token_url = self.token_url
        refresh_data = self.get_refresh_token_data()
        token_headers = self.get_token_headers()
        
        r = rq.post(url=token_url, data=refresh_data)
        #r = rq.post(token_url, data=token_data, headers=token_headers)
        #print(r.json())
        if r.status_code not in range(200, 299):
            raise Exception("Could not authenticate client.")
            #return False
        data = r.json()
        now = datetime.datetime.now()
        refresh_token = data['access_token']
        expires_in = data['expires_in']
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token = refresh_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True

    def get_access_token(self):
#         auth_done = self.perform_auth()
#         if not auth_done:
#             raise Exception("Authentication failed")
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token()
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization": f"Bearer {access_token}"
        }
        return headers
       
        
    def get_resource(self, lookup_id, resource_type='albums',version='v1'):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{lookup_id}"
        headers = self.get_resource_header()
        r = rq.get(endpoint, headers=headers)
        if r.status_code not in range(200,299):
            return {}
        return r.json()
        
    def get_album(self, _id):
#         baseURL = 'https://api.spotify.com/v1'
#         endpoint = f"{baseURL}/albums/{_id}"
#         pass
        return self.get_resource(_id, resource_type = 'albums')
    
    def get_artist(self, _id):
        return self.get_resource(_id, resource_type = 'artists')
    
    def base_search(self, query_params):
        access_token = self.get_access_token()
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/search"
        lookup_url = f"{endpoint}?{query_params}"
        r = rq.get(lookup_url, headers = headers)
        #print(r.status_code)
        if r.status_code not in range(200, 299):
            return {}
        return r.json()
    
    def search(self, query=None, operator=None, operator_query=None, search_type='artist'):
        if query == None:
            raise Exception("A query is required")
        if isinstance (query, dict):
            query = " ".join([f"{k}:{v}" for k,v in query.items()])
        if operator != None and operator_query != None:
            if operator.lower() == "or" or operator.lower() == "not":
                operator = operator.upper()
                if isinstance(operator_query, str):
                    query = f"{query} {operator} {operator_query}"
        query_params = urlencode({"q": query, "type" : search_type.lower()})
        #print(query_params)
        # When doing the queries with operators match the query to the operator query in terms of type(artists, albums,etc.)
        return self.base_search(query_params)
        
#Get user info

    def get_user_info(self, version='v1'):
        endpoint = f"https://api.spotify.com/{version}/me"
        headers = self.get_resource_header()
        r = rq.get(endpoint, headers=headers)
        if r.status_code not in range(200,299):
            print(r.status_code)
            return {}
        return r.json()

#Playlist features

    def get_user_playlists(self, resource_type='users', version='v1', user_id='null', limit=50):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{user_id}/playlists"
        query_params = urlencode({'limit' : 50})
        final_endpoint = f"{endpoint}?{query_params}"
        headers = self.get_resource_header()
        r = rq.get(final_endpoint, headers=headers)
        if r.status_code not in range(200,299):
            return {}
        return r.json()
    
    def get_next_page(self, url=None):
        if url == None:
            raise Exception("Invalid argument")
        headers = self.get_resource_header()
        r = rq.get(url, headers=headers)
        if r.status_code not in range(200,299):
            print(r.status_code)
            return {}
        #print(r.json())
        return r.json()
    
    #this particular vairable/field is only needed for the list_user_playlists method
    user_playlists = []
    def list_user_playlists(self, response=None):
        if response == None:
            raise Exception("Invalid argument")
        #print(self.user_playlists)
        for item in response['items']:
            temp = {'name' : item['name'],
                    'id' : item['id'],
                   'uri' : item['uri']}
            self.user_playlists.append(temp)
        while(response['next'] != None):
            self.list_user_playlists(self.get_next_page(response['next']))
            break
#         if response['next'] != None:
#             self.list_user_playlists(self.get_next_page(response['next']))
#         if response['next'] == None:
        return self.user_playlists
    
    def clear_user_playlists(self):
        self.user_playlists = []
        
    def get_playlist_items(self, resource_type='playlists', version='v1', playlist_id='null', limit=100):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{playlist_id}/tracks"
        query_params = urlencode({'limit' : limit, 'fields': 'items(added_by.id,uri,track(name,artists(href,id,uri,name,spotify),id,uri,duration,explicit,href,album(name,id,uri))),href,limit,next,offset,previous,total'})
        final_endpoint = f"{endpoint}?{query_params}"
        #print(final_endpoint)
        headers = self.get_resource_header()
        r = rq.get(final_endpoint, headers=headers)
        if r.status_code not in range(200,299):
            return {}
        return r.json()
        
#     #this particular vairable/field is only needed for the list_playlists_items method
    
#     def list_playlist_items(self, response=None):
#         if response == None:
#             raise Exception("Invalid argument")
#         #print(self.user_playlists)
#         for item in response['items']:
#             temp = {'name' : item['name'],
#                     'id' : item['id']}
#             self.user_playlists.append(temp)
#         while(response['next'] != None):
#             self.list_user_playlists(self.get_next_page(response['next']))
#             break
# #         if response['next'] != None:
# #             self.list_user_playlists(self.get_next_page(response['next']))
# #         if response['next'] == None:
#         return self.user_playlists
    

    #this particular vairable/field is only needed for the parse_playlists_items method
    playlist_items = []
    def parse_playlist_items(self, response=None):
        if response == None:
            raise Exception("Invalid argument")
        for item in response['items']:
            #pd(item)
            if item['track']==None:
                continue
            artists = []
            for i in item['track']['artists']:
                w = {'name' : i['name'],
                     'id' : i['id'],
                     'uri' : i['uri']
                    }
                #w = {i['name'] : i['id']}
                artists.append(w)

            q = {'song_name' : item['track']['name'], 'id' : item['track']['id'],'uri' : item['track']['uri'],
                                          'artists' : artists }
            self.playlist_items.append(q)
        while(response['next'] != None):
            self.parse_playlist_items(self.get_next_page(response['next']))
            break
        return self.playlist_items

    def clear_playlist_items(self):
        self.playlist_items = []
        
        
    def create_playlist(self, resource_type='users', version='v1', user_id='null', 
                        name=None, description='', public=False, artist=None, playlist_name=None):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{user_id}/playlists"
        #query_params = urlencode({'limit' : 50})
        #final_endpoint = f"{endpoint}?{query_params}"
        headers = self.get_resource_header()
        if name == None:
            name = f"{artist} : {playlist_name}"
            #print(name)
        post_data = {'name' : name,
                    'description' : description,
                    'public' : public}
        r = rq.post(endpoint, headers=headers, json=post_data)
        if r.status_code not in range(200,299):
            #print(r.status_code)
            return {}
        return r.json()
    
    def get_spotify_uri(self, id=None, resource_type='artist'):
        #resource type example = artist,album,track
        if id == None:
            raise Exception("Invalid argument")
        uri = f"spotify:{resource_type}:{id}"
        return uri
    
    def add_song_to_playlist(self, resource_type='playlists', version='v1', uri_list=None, playlist_id=None):
        if uri_list == None or playlist_id == None:
            raise Exception("Invalid argument")
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{playlist_id}/tracks"
        headers = self.get_resource_header()
        post_data = {'uris' : uri_list}
        r = rq.post(endpoint, headers=headers, json=post_data)
        if r.status_code not in range(200,299):
            #print(r.status_code)
            return {}
        return r.json()

# %%
#base64.b64decode(client_creds_b64) #decoding
#endpoint = "https://api.spotify.com/v1/search"

# %%
sc = SpotifyAPI(client_id, client_secret)

# %%
sc.parse_url_for_code('http://localhost:3000/?code=AQAno-o19oMEinqpvy1qu9rs5fjehnqqRqK0IDlmKWApiOE6pIYhpB6TuGqVXqs4qIwlMgEBSrXcNt5qRNVVfUeSaE1OIhoC13o0i7ftR68mXkgJX_kqGeEgRQdcfANoomO_VuXfZWifbBIzTu0-Eek0rhoQXvaT72-zHU1UV9SRIlPTgZX74QmlUMzCERhg-YUyyjYoFzdYvvsPiSqty09LbG-Vd8h08IVryFwrXxpwqX3ZMYRMaMeVRxx_CygtuNcjcjmufxbUAB1pQh_FX9-WZKzRpKeN1xx64CWJBF4Cnd7KNg_QLDvxIHvQMj3WBEE13ryAqWcYtMIzyxd0fwz6yQ')

# %%
user_info = sc.get_user_info()
pd(user_info)
# Out:
# 403
# {}

# %%
response = sc.get_user_playlists(user_id=user_info['id'])
#print(response)
pd(response)
#sc.get_user_playlists(user_id='y4yjmhqzanyc6musw2wjfi1hv')
# Out:
# {
#     'href': 'https://api.spotify.com/v1/users/y4yjmhqzanyc6musw2wjfi1hv/playlists?offset=0&limit=50',
#     'items': [{
#         'collaborative': False,
#         'description': '',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/34JGK4rI5BZWq99VrYVjKt'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/34JGK4rI5BZWq99VrYVjKt',
#         'id': '34JGK4rI5BZWq99VrYVjKt',
#         'images': [{
#             'height': 640,
#             'url': 'https://mosaic.scdn.co/640/ab67616d0000b2734e267faafd063f288b4890bcab67616d0000b2738b52c6b9bc4e43d873869699ab67616d0000b2739edc391d911405ea9f5c320eab67616d0000b273b5ef185d28724c5573c2ac9c',
#             'width': 640
#         }, {
#             'height': 300,
#             'url': 'https://mosaic.scdn.co/300/ab67616d0000b2734e267faafd063f288b4890bcab67616d0000b2738b52c6b9bc4e43d873869699ab67616d0000b2739edc391d911405ea9f5c320eab67616d0000b273b5ef185d28724c5573c2ac9c',
#             'width': 300
#         }, {
#             'height': 60,
#             'url': 'https://mosaic.scdn.co/60/ab67616d0000b2734e267faafd063f288b4890bcab67616d0000b2738b52c6b9bc4e43d873869699ab67616d0000b2739edc391d911405ea9f5c320eab67616d0000b273b5ef185d28724c5573c2ac9c',
#             'width': 60
#         }],
#         'name': 'Kendrick Lamar : Ike',
#         'owner': {
#             'display_name': 'Ike',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/y4yjmhqzanyc6musw2wjfi1hv'
#             },
#             'href': 'https://api.spotify.com/v1/users/y4yjmhqzanyc6musw2wjfi1hv',
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv',
#             'type': 'user',
#             'uri': 'spotify:user:y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MixmMDE0MmEyNjU1NmJlNmYxMjJmN2I4YTkyNTFjM2Y3ZjM5YmJhNTcz',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/34JGK4rI5BZWq99VrYVjKt/tracks',
#             'total': 38
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:34JGK4rI5BZWq99VrYVjKt'
#     }, {
#         'collaborative': False,
#         'description': 'A playlist of Joy Crookes Songs in IKE',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/4ftmFe65df4SyGZIwpkzJ5'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/4ftmFe65df4SyGZIwpkzJ5',
#         'id': '4ftmFe65df4SyGZIwpkzJ5',
#         'images': [{
#             'height': 640,
#             'url': 'https://mosaic.scdn.co/640/ab67616d0000b27308fa7eea3466782a534990d2ab67616d0000b2738f5b10774f455be8c7b930c6ab67616d0000b273a46834aa71df89c1c66a6662ab67616d0000b273ae0e4c7203e22832cd064cb0',
#             'width': 640
#         }, {
#             'height': 300,
#             'url': 'https://mosaic.scdn.co/300/ab67616d0000b27308fa7eea3466782a534990d2ab67616d0000b2738f5b10774f455be8c7b930c6ab67616d0000b273a46834aa71df89c1c66a6662ab67616d0000b273ae0e4c7203e22832cd064cb0',
#             'width': 300
#         }, {
#             'height': 60,
#             'url': 'https://mosaic.scdn.co/60/ab67616d0000b27308fa7eea3466782a534990d2ab67616d0000b2738f5b10774f455be8c7b930c6ab67616d0000b273a46834aa71df89c1c66a6662ab67616d0000b273ae0e4c7203e22832cd064cb0',
#             'width': 60
#         }],
#         'name': 'Joy Crookes : Ike',
#         'owner': {
#             'display_name': 'Ike',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/y4yjmhqzanyc6musw2wjfi1hv'
#             },
#             'href': 'https://api.spotify.com/v1/users/y4yjmhqzanyc6musw2wjfi1hv',
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv',
#             'type': 'user',
#             'uri': 'spotify:user:y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'NSw5NzRlMTk3ODM1OGFkZjc2MDcyNjI3OTQ5ZjdmZWY0MGRiYzFiYTBh',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/4ftmFe65df4SyGZIwpkzJ5/tracks',
#             'total': 15
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:4ftmFe65df4SyGZIwpkzJ5'
#     }, {
#         'collaborative': False,
#         'description': 'This mixtape is created by Dr. Bradley’s Spring 2023 LBST 2301 classes. Songs have some connection to course concepts about critical thinking, communication, money, and '
#         'inequality, as interpreted by the students.',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/6MdRu5XF7TyJzN5ccBjgpf'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/6MdRu5XF7TyJzN5ccBjgpf',
#         'id': '6MdRu5XF7TyJzN5ccBjgpf',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb93e4fbb1b9a67200b9c8c371',
#             'width': None
#         }],
#         'name': 'LBST 2301 Spring 2023 Mixtape',
#         'owner': {
#             'display_name': 'Stephanie',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/gh4hx1m0h5xaey3pqzh68puid'
#             },
#             'href': 'https://api.spotify.com/v1/users/gh4hx1m0h5xaey3pqzh68puid',
#             'id': 'gh4hx1m0h5xaey3pqzh68puid',
#             'type': 'user',
#             'uri': 'spotify:user:gh4hx1m0h5xaey3pqzh68puid'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'ODYsYjM0MmY1YjM0NjJkNDc0ZDlhMTMxYTA5MjRkYzA2NGZjZTU1NzVlZQ==',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/6MdRu5XF7TyJzN5ccBjgpf/tracks',
#             'total': 82
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:6MdRu5XF7TyJzN5ccBjgpf'
#     }, {
#         'collaborative': False,
#         'description': 'A playlist of Drake songs in IKE playlist',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/5bafUXvO08JfyfLbkrY8dk'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/5bafUXvO08JfyfLbkrY8dk',
#         'id': '5bafUXvO08JfyfLbkrY8dk',
#         'images': [{
#             'height': 640,
#             'url': 'https://mosaic.scdn.co/640/ab67616d0000b27359ba1bf8385cb016e62a26c0ab67616d0000b2736cab41f8c84d6164976400d4ab67616d0000b2739c188c494d8bfaf895411890ab67616d0000b273f907de96b9a4fbc04accc0d5',
#             'width': 640
#         }, {
#             'height': 300,
#             'url': 'https://mosaic.scdn.co/300/ab67616d0000b27359ba1bf8385cb016e62a26c0ab67616d0000b2736cab41f8c84d6164976400d4ab67616d0000b2739c188c494d8bfaf895411890ab67616d0000b273f907de96b9a4fbc04accc0d5',
#             'width': 300
#         }, {
#             'height': 60,
#             'url': 'https://mosaic.scdn.co/60/ab67616d0000b27359ba1bf8385cb016e62a26c0ab67616d0000b2736cab41f8c84d6164976400d4ab67616d0000b2739c188c494d8bfaf895411890ab67616d0000b273f907de96b9a4fbc04accc0d5',
#             'width': 60
#         }],
#         'name': 'Drake : Ike',
#         'owner': {
#             'display_name': 'Ike',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/y4yjmhqzanyc6musw2wjfi1hv'
#             },
#             'href': 'https://api.spotify.com/v1/users/y4yjmhqzanyc6musw2wjfi1hv',
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv',
#             'type': 'user',
#             'uri': 'spotify:user:y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MyxkZGFkY2EzY2RlOTg1YjZlMDlmZTI1NmNlMzY5MjE2Y2E4NjVjYTQ0',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/5bafUXvO08JfyfLbkrY8dk/tracks',
#             'total': 75
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:5bafUXvO08JfyfLbkrY8dk'
#     }, {
#         'collaborative': False,
#         'description': 'Every song from Joy Crookes&#x27; debut album &#x27;Skin&#x27; &amp; the EP&#x27;s that preceded it. Including &#x27;Feet Don&#x27;t Fail Me Now&#x27; the soundtrack to '
#         'the UEFA Womens Euro 2022.',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/1PT1LcejkMGoGsmKzkBKax'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/1PT1LcejkMGoGsmKzkBKax',
#         'id': '1PT1LcejkMGoGsmKzkBKax',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb252d43620a6d0fad2d761da6',
#             'width': None
#         }],
#         'name': 'Joy Crookes - The Complete Collection',
#         'owner': {
#             'display_name': 'joycrookes',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/gy67etvjqc9fuvdpsnbezumxe'
#             },
#             'href': 'https://api.spotify.com/v1/users/gy67etvjqc9fuvdpsnbezumxe',
#             'id': 'gy67etvjqc9fuvdpsnbezumxe',
#             'type': 'user',
#             'uri': 'spotify:user:gy67etvjqc9fuvdpsnbezumxe'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'NzAsNDJkYWFhZGJhNGQ1MjUwMzMwYzcxMTk4MWM0Yzk5MjQ1ZjRkZGViMw==',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/1PT1LcejkMGoGsmKzkBKax/tracks',
#             'total': 33
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:1PT1LcejkMGoGsmKzkBKax'
#     }, {
#         'collaborative': False,
#         'description': '',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/7H0gvTCkCh9vA8gw1mcNVd'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/7H0gvTCkCh9vA8gw1mcNVd',
#         'id': '7H0gvTCkCh9vA8gw1mcNVd',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb19049aa463efceb00a63ac12',
#             'width': None
#         }],
#         'name': 'Japanese City Pop',
#         'owner': {
#             'display_name': 'Solace of Sound',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/1210229329'
#             },
#             'href': 'https://api.spotify.com/v1/users/1210229329',
#             'id': '1210229329',
#             'type': 'user',
#             'uri': 'spotify:user:1210229329'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTE5LGI5NDE3Zjk0ZDNkZDJmMzg2NzRjMDQxNjVmN2FhYTQzMGNjYzA2MTE=',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/7H0gvTCkCh9vA8gw1mcNVd/tracks',
#             'total': 96
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:7H0gvTCkCh9vA8gw1mcNVd'
#     }, {
#         'collaborative': False,
#         'description': 'Spotify Wrapped presents the songs that you loved most this year.',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/37i9dQZF1F0sijgNaJdgit'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1F0sijgNaJdgit',
#         'id': '37i9dQZF1F0sijgNaJdgit',
#         'images': [{
#             'height': None,
#             'url': 'https://wrapped-images.spotifycdn.com/image/yts-2022/large/your-top-songs-2022_large_en.jpg',
#             'width': None
#         }],
#         'name': 'Your Top Songs 2022',
#         'owner': {
#             'display_name': 'Spotify',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/spotify'
#             },
#             'href': 'https://api.spotify.com/v1/users/spotify',
#             'id': 'spotify',
#             'type': 'user',
#             'uri': 'spotify:user:spotify'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTY2OTkwODk2MiwwMDAwMDAwMDBiNjFiY2QxNTNkMTdkZjM2MDAwYmUyNjE3M2RmODE5',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1F0sijgNaJdgit/tracks',
#             'total': 101
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:37i9dQZF1F0sijgNaJdgit'
#     }, {
#         'collaborative': False,
#         'description': '"Remember who we are." Music from and inspired by Black Panther and Black Panther: Wakanda Forever.',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX6tq7CPNyNEM'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX6tq7CPNyNEM',
#         'id': '37i9dQZF1DX6tq7CPNyNEM',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706f000000034e74fe1b56bf74f36c8e06d2',
#             'width': None
#         }],
#         'name': 'Black Panther Official Playlist',
#         'owner': {
#             'display_name': 'Spotify',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/spotify'
#             },
#             'href': 'https://api.spotify.com/v1/users/spotify',
#             'id': 'spotify',
#             'type': 'user',
#             'uri': 'spotify:user:spotify'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTY3NTM2OTA2OCwwMDAwMDAwMGI0OTYxZWQzNzg2ZTY4NjdhOGViMDUxZTAxNmNjMzEz',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX6tq7CPNyNEM/tracks',
#             'total': 57
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:37i9dQZF1DX6tq7CPNyNEM'
#     }, {
#         'collaborative': False,
#         'description': '@Malky_malk’s personal playlist Newer songs&#x2F; Artists at the top, Older mainstream songs in the middle ',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/06wrErgQDANLAeVl2NR6NY'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/06wrErgQDANLAeVl2NR6NY',
#         'id': '06wrErgQDANLAeVl2NR6NY',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb6f4249ec52400c2aa448f1fd',
#             'width': None
#         }],
#         'name': 'Calisthenics x Gymtok',
#         'owner': {
#             'display_name': 'Malky_malk',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/314xrtemygz262l7kt2pcmweznq4'
#             },
#             'href': 'https://api.spotify.com/v1/users/314xrtemygz262l7kt2pcmweznq4',
#             'id': '314xrtemygz262l7kt2pcmweznq4',
#             'type': 'user',
#             'uri': 'spotify:user:314xrtemygz262l7kt2pcmweznq4'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'ODM2LDY3Nzk1ZDRjZTIxNTljMTA3ODRmNzIxYzI3ZTM3ODA3NDEyNWEzMDE=',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/06wrErgQDANLAeVl2NR6NY/tracks',
#             'total': 171
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:06wrErgQDANLAeVl2NR6NY'
#     }, {
#         'collaborative': False,
#         'description': '',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/4myVDdbRXNQ8Hu8pQheSMN'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/4myVDdbRXNQ8Hu8pQheSMN',
#         'id': '4myVDdbRXNQ8Hu8pQheSMN',
#         'images': [{
#             'height': 640,
#             'url': 'https://i.scdn.co/image/ab67616d0000b273174134e2ea546b2040749d8b',
#             'width': 640
#         }],
#         'name': 'Synthwave type',
#         'owner': {
#             'display_name': 'Ike',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/y4yjmhqzanyc6musw2wjfi1hv'
#             },
#             'href': 'https://api.spotify.com/v1/users/y4yjmhqzanyc6musw2wjfi1hv',
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv',
#             'type': 'user',
#             'uri': 'spotify:user:y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'NSw5MzNkNTdhMzNmMmJhNmM0MzNjNjFiMDUxNjg4MzBjMzhiZjA0MzVi',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/4myVDdbRXNQ8Hu8pQheSMN/tracks',
#             'total': 2
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:4myVDdbRXNQ8Hu8pQheSMN'
#     }, {
#         'collaborative': False,
#         'description': 'The best gym music and the best phonk ',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/1sgNK6s1Gk4kZEOTKPd72X'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/1sgNK6s1Gk4kZEOTKPd72X',
#         'id': '1sgNK6s1Gk4kZEOTKPd72X',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebbe0ce47629d4e648dab0d38cf',
#             'width': None
#         }],
#         'name': 'Gym Phonk 🔱',
#         'owner': {
#             'display_name': 'Nazarite',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/jonathan007318'
#             },
#             'href': 'https://api.spotify.com/v1/users/jonathan007318',
#             'id': 'jonathan007318',
#             'type': 'user',
#             'uri': 'spotify:user:jonathan007318'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTU1MCwzY2E4MTM0MWMzNGM1ZGRjZGFkODU5NGE1ZjVjOGE0YWQzNjdkMmFh',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/1sgNK6s1Gk4kZEOTKPd72X/tracks',
#             'total': 175
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:1sgNK6s1Gk4kZEOTKPd72X'
#     }, {
#         'collaborative': False,
#         'description': '',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/5fkFpkHk4MaRyNeeXpYd30'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/5fkFpkHk4MaRyNeeXpYd30',
#         'id': '5fkFpkHk4MaRyNeeXpYd30',
#         'images': [{
#             'height': 640,
#             'url': 'https://mosaic.scdn.co/640/ab67616d0000b27302854a7060fccc1a66a4b5adab67616d0000b27313e54d6687e65678d60466c2ab67616d0000b27366b04b41fa6f8908dce86695ab67616d0000b273ffe5b62233340cb6d453fc2f',
#             'width': 640
#         }, {
#             'height': 300,
#             'url': 'https://mosaic.scdn.co/300/ab67616d0000b27302854a7060fccc1a66a4b5adab67616d0000b27313e54d6687e65678d60466c2ab67616d0000b27366b04b41fa6f8908dce86695ab67616d0000b273ffe5b62233340cb6d453fc2f',
#             'width': 300
#         }, {
#             'height': 60,
#             'url': 'https://mosaic.scdn.co/60/ab67616d0000b27302854a7060fccc1a66a4b5adab67616d0000b27313e54d6687e65678d60466c2ab67616d0000b27366b04b41fa6f8908dce86695ab67616d0000b273ffe5b62233340cb6d453fc2f',
#             'width': 60
#         }],
#         'name': '',
#         'owner': {
#             'display_name': 'adrianjoeym',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/adrianm23__'
#             },
#             'href': 'https://api.spotify.com/v1/users/adrianm23__',
#             'id': 'adrianm23__',
#             'type': 'user',
#             'uri': 'spotify:user:adrianm23__'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTU1NCwxMTY1OTBiMWJkY2YwZTg5OGQ2ZjY0NzIzODRhNTlkMWNmM2MwOWIw',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/5fkFpkHk4MaRyNeeXpYd30/tracks',
#             'total': 103
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:5fkFpkHk4MaRyNeeXpYd30'
#     }, {
#         'collaborative': False,
#         'description': 'Fourth quarter, two minutes left .. get locked in',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWTl4y3vgJOXW'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTl4y3vgJOXW',
#         'id': '37i9dQZF1DWTl4y3vgJOXW',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706f00000003b999ec417b9072ec7350ff15',
#             'width': None
#         }],
#         'name': 'Locked In',
#         'owner': {
#             'display_name': 'Spotify',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/spotify'
#             },
#             'href': 'https://api.spotify.com/v1/users/spotify',
#             'id': 'spotify',
#             'type': 'user',
#             'uri': 'spotify:user:spotify'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTY3NTQwMTQyMCwwMDAwMDAwMDQ1ODcwODhhZjdmYmFkMTI5ODE0N2Y3Y2Q5MTVkZjM5',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTl4y3vgJOXW/tracks',
#             'total': 200
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW'
#     }, {
#         'collaborative': False,
#         'description': 'Playlist transferred with SongShift',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/6MPrkSvuZQnQvITxJLr703'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/6MPrkSvuZQnQvITxJLr703',
#         'id': '6MPrkSvuZQnQvITxJLr703',
#         'images': [{
#             'height': 640,
#             'url': 'https://mosaic.scdn.co/640/ab67616d0000b2735ab2e9ee13191c3fcd1d58d3ab67616d0000b2735cd6070603a9f2e5dcb01d0cab67616d0000b2738cca41a6d8d0cae2e9b15d14ab67616d0000b273d00a36fea0639c48eb0ee312',
#             'width': 640
#         }, {
#             'height': 300,
#             'url': 'https://mosaic.scdn.co/300/ab67616d0000b2735ab2e9ee13191c3fcd1d58d3ab67616d0000b2735cd6070603a9f2e5dcb01d0cab67616d0000b2738cca41a6d8d0cae2e9b15d14ab67616d0000b273d00a36fea0639c48eb0ee312',
#             'width': 300
#         }, {
#             'height': 60,
#             'url': 'https://mosaic.scdn.co/60/ab67616d0000b2735ab2e9ee13191c3fcd1d58d3ab67616d0000b2735cd6070603a9f2e5dcb01d0cab67616d0000b2738cca41a6d8d0cae2e9b15d14ab67616d0000b273d00a36fea0639c48eb0ee312',
#             'width': 60
#         }],
#         'name': 'new new',
#         'owner': {
#             'display_name': 'andraj34',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/andraj34'
#             },
#             'href': 'https://api.spotify.com/v1/users/andraj34',
#             'id': 'andraj34',
#             'type': 'user',
#             'uri': 'spotify:user:andraj34'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTIsMTkzNzJmMjIzNzBmYTlmY2I5NTdmZGM2OGJiMzAzMDViYTNmYzJjMQ==',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/6MPrkSvuZQnQvITxJLr703/tracks',
#             'total': 598
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:6MPrkSvuZQnQvITxJLr703'
#     }, {
#         'collaborative': False,
#         'description': '',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/3OX1Mbdhbadze6rcNS41eM'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/3OX1Mbdhbadze6rcNS41eM',
#         'id': '3OX1Mbdhbadze6rcNS41eM',
#         'images': [{
#             'height': 640,
#             'url': 'https://mosaic.scdn.co/640/ab67616d0000b27300030070dd61dad65ab707faab67616d0000b273a859ec0e8aa49edeaafab89cab67616d0000b273e1c9182838a2f73ded76c450ab67616d0000b273f5c30413d754c5b010150d84',
#             'width': 640
#         }, {
#             'height': 300,
#             'url': 'https://mosaic.scdn.co/300/ab67616d0000b27300030070dd61dad65ab707faab67616d0000b273a859ec0e8aa49edeaafab89cab67616d0000b273e1c9182838a2f73ded76c450ab67616d0000b273f5c30413d754c5b010150d84',
#             'width': 300
#         }, {
#             'height': 60,
#             'url': 'https://mosaic.scdn.co/60/ab67616d0000b27300030070dd61dad65ab707faab67616d0000b273a859ec0e8aa49edeaafab89cab67616d0000b273e1c9182838a2f73ded76c450ab67616d0000b273f5c30413d754c5b010150d84',
#             'width': 60
#         }],
#         'name': 'SES Hackathon',
#         'owner': {
#             'display_name': 'Erhan Uyar',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/u0qmpvfzb9zl7zqk9g9eqg8ws'
#             },
#             'href': 'https://api.spotify.com/v1/users/u0qmpvfzb9zl7zqk9g9eqg8ws',
#             'id': 'u0qmpvfzb9zl7zqk9g9eqg8ws',
#             'type': 'user',
#             'uri': 'spotify:user:u0qmpvfzb9zl7zqk9g9eqg8ws'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'NzQsNmJiM2Y3YjI0ZmU3YzNjYjUxZjE5ODkwYzYyNGY5N2VkZTAzNDVkNQ==',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/3OX1Mbdhbadze6rcNS41eM/tracks',
#             'total': 42
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:3OX1Mbdhbadze6rcNS41eM'
#     }, {
#         'collaborative': False,
#         'description': 'Dm me on insta for song requests @andrewmcgee__',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/25DpSFEJ7zeAy6uGWOjlFo'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/25DpSFEJ7zeAy6uGWOjlFo',
#         'id': '25DpSFEJ7zeAy6uGWOjlFo',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebba4b796264734a94a2c3d274a',
#             'width': None
#         }],
#         'name': 'FEELING DISRESPECTFUL😈😈',
#         'owner': {
#             'display_name': 'Him🫡',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/wonderfulwilliam99'
#             },
#             'href': 'https://api.spotify.com/v1/users/wonderfulwilliam99',
#             'id': 'wonderfulwilliam99',
#             'type': 'user',
#             'uri': 'spotify:user:wonderfulwilliam99'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTIxNiw3MDM5MmM4NTY2OWE3NmQ0ODllYWYzODdkMDNhNjZhZDFhYmUyMDg4',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/25DpSFEJ7zeAy6uGWOjlFo/tracks',
#             'total': 561
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:25DpSFEJ7zeAy6uGWOjlFo'
#     }, {
#         'collaborative': False,
#         'description': '',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/52heXxEn3Cdn6ofhR3nObo'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/52heXxEn3Cdn6ofhR3nObo',
#         'id': '52heXxEn3Cdn6ofhR3nObo',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb4aea4dec6522d5227ccc950d',
#             'width': None
#         }],
#         'name': 'dreaming of summer in Brazil ',
#         'owner': {
#             'display_name': 'Tanaka',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/kudzaimushonga1'
#             },
#             'href': 'https://api.spotify.com/v1/users/kudzaimushonga1',
#             'id': 'kudzaimushonga1',
#             'type': 'user',
#             'uri': 'spotify:user:kudzaimushonga1'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTUsYWRkNGIxYTYxNWU3NDA5ZGUxNjQ0NWI2NDYxYThlMDA5ODdjMzdhZA==',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/52heXxEn3Cdn6ofhR3nObo/tracks',
#             'total': 54
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:52heXxEn3Cdn6ofhR3nObo'
#     }, {
#         'collaborative': False,
#         'description': 'That good mood workout to keep the spirits high and weights even higher.',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/4HUido35wAtbof2YMZ7bSQ'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/4HUido35wAtbof2YMZ7bSQ',
#         'id': '4HUido35wAtbof2YMZ7bSQ',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb6486e7566730e6b92226ffb4',
#             'width': None
#         }],
#         'name': 'gym sends (happy/upbeat)',
#         'owner': {
#             'display_name': 'Clay Brubaker',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/22s3xmkwibt2vov47ig66znyy'
#             },
#             'href': 'https://api.spotify.com/v1/users/22s3xmkwibt2vov47ig66znyy',
#             'id': '22s3xmkwibt2vov47ig66znyy',
#             'type': 'user',
#             'uri': 'spotify:user:22s3xmkwibt2vov47ig66znyy'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'NTEsOTM0ZGVjOGViNjRiMWFkOTBmNTU5MDlkOWY4ZDRlOGVlZjA3MmNkNg==',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/4HUido35wAtbof2YMZ7bSQ/tracks',
#             'total': 46
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:4HUido35wAtbof2YMZ7bSQ'
#     }, {
#         'collaborative': False,
#         'description': 'Moving some weights with a side of depression, this playlists got you',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/0LY0evTkp87qtw1dRCbe97'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/0LY0evTkp87qtw1dRCbe97',
#         'id': '0LY0evTkp87qtw1dRCbe97',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb1acbaa890c466a875890dd6d',
#             'width': None
#         }],
#         'name': 'gym sends (sad)',
#         'owner': {
#             'display_name': 'Clay Brubaker',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/22s3xmkwibt2vov47ig66znyy'
#             },
#             'href': 'https://api.spotify.com/v1/users/22s3xmkwibt2vov47ig66znyy',
#             'id': '22s3xmkwibt2vov47ig66znyy',
#             'type': 'user',
#             'uri': 'spotify:user:22s3xmkwibt2vov47ig66znyy'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'NTUsZWUwYjZhYzI2NjQ2ZWJjOWRhYzM5MDQxNmIxNmRiM2MzZmQ4OWZkYQ==',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/0LY0evTkp87qtw1dRCbe97/tracks',
#             'total': 51
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:0LY0evTkp87qtw1dRCbe97'
#     }, {
#         'collaborative': False,
#         'description': 'Need to just slams some things around in the gym, give this a listen ASAP',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/5BVHoZKG1wjPfBJ6RUAlJG'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/5BVHoZKG1wjPfBJ6RUAlJG',
#         'id': '5BVHoZKG1wjPfBJ6RUAlJG',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb077180b12bf075ef846933c3',
#             'width': None
#         }],
#         'name': 'gym sends (angry)',
#         'owner': {
#             'display_name': 'Clay Brubaker',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/22s3xmkwibt2vov47ig66znyy'
#             },
#             'href': 'https://api.spotify.com/v1/users/22s3xmkwibt2vov47ig66znyy',
#             'id': '22s3xmkwibt2vov47ig66znyy',
#             'type': 'user',
#             'uri': 'spotify:user:22s3xmkwibt2vov47ig66znyy'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'NjIsMDA2OWY2YTg5MTNlYTk5OTcxZGY3YTIzY2FlZWZhZDEyYTNlZjNkMA==',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/5BVHoZKG1wjPfBJ6RUAlJG/tracks',
#             'total': 58
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:5BVHoZKG1wjPfBJ6RUAlJG'
#     }, {
#         'collaborative': False,
#         'description': 'A laid back vibe in the gym when you just need some good tunes.',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/77kgw7u48un9NkozrxouOg'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/77kgw7u48un9NkozrxouOg',
#         'id': '77kgw7u48un9NkozrxouOg',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb82154231abeefb29984453bf',
#             'width': None
#         }],
#         'name': 'gym sends (chill)',
#         'owner': {
#             'display_name': 'Clay Brubaker',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/22s3xmkwibt2vov47ig66znyy'
#             },
#             'href': 'https://api.spotify.com/v1/users/22s3xmkwibt2vov47ig66znyy',
#             'id': '22s3xmkwibt2vov47ig66znyy',
#             'type': 'user',
#             'uri': 'spotify:user:22s3xmkwibt2vov47ig66znyy'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'NTMsZmJmMzQxOGU0M2NjNzM5NzE0YmJmOWE1YjhmYmFmNjMwOGZmMWNkZA==',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/77kgw7u48un9NkozrxouOg/tracks',
#             'total': 47
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:77kgw7u48un9NkozrxouOg'
#     }, {
#         'collaborative': False,
#         'description': 'The ultimate gym playlist of every song you need in the gym',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/6ojl7MOYEjFOmM5syFrQXX'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/6ojl7MOYEjFOmM5syFrQXX',
#         'id': '6ojl7MOYEjFOmM5syFrQXX',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb92dbbcda81a08cba08ad2e24',
#             'width': None
#         }],
#         'name': 'gym sends',
#         'owner': {
#             'display_name': 'Clay Brubaker',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/22s3xmkwibt2vov47ig66znyy'
#             },
#             'href': 'https://api.spotify.com/v1/users/22s3xmkwibt2vov47ig66znyy',
#             'id': '22s3xmkwibt2vov47ig66znyy',
#             'type': 'user',
#             'uri': 'spotify:user:22s3xmkwibt2vov47ig66znyy'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTI2LDE1YmEzMzdiYmM0MjA4YmY3MzA5OTE3ODVkZGVhMDI4MmM0NWNhODQ=',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/6ojl7MOYEjFOmM5syFrQXX/tracks',
#             'total': 114
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:6ojl7MOYEjFOmM5syFrQXX'
#     }, {
#         'collaborative': False,
#         'description': '',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/0ef2FFJmYlAiXtDFsEaOYt'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/0ef2FFJmYlAiXtDFsEaOYt',
#         'id': '0ef2FFJmYlAiXtDFsEaOYt',
#         'images': [{
#             'height': 640,
#             'url': 'https://mosaic.scdn.co/640/ab67616d0000b2733355057c7983c79c24d57690ab67616d0000b2738931779a288ea6a8b78a8780ab67616d0000b27392b5c3716cb7287638d032cdab67616d0000b27396710096536accca658e76d9',
#             'width': 640
#         }, {
#             'height': 300,
#             'url': 'https://mosaic.scdn.co/300/ab67616d0000b2733355057c7983c79c24d57690ab67616d0000b2738931779a288ea6a8b78a8780ab67616d0000b27392b5c3716cb7287638d032cdab67616d0000b27396710096536accca658e76d9',
#             'width': 300
#         }, {
#             'height': 60,
#             'url': 'https://mosaic.scdn.co/60/ab67616d0000b2733355057c7983c79c24d57690ab67616d0000b2738931779a288ea6a8b78a8780ab67616d0000b27392b5c3716cb7287638d032cdab67616d0000b27396710096536accca658e76d9',
#             'width': 60
#         }],
#         'name': '~',
#         'owner': {
#             'display_name': 'worldhaspostrock',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/worldhaspostrock'
#             },
#             'href': 'https://api.spotify.com/v1/users/worldhaspostrock',
#             'id': 'worldhaspostrock',
#             'type': 'user',
#             'uri': 'spotify:user:worldhaspostrock'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTA1LDJhOTFjZDlhMTQwMjU5OGRhNzBmMGNhOWVlNDA5MmQxZjI2YWRjNGU=',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/0ef2FFJmYlAiXtDFsEaOYt/tracks',
#             'total': 17
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:0ef2FFJmYlAiXtDFsEaOYt'
#     }, {
#         'collaborative': False,
#         'description': '',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/5wgQHQCjbvAyiddNhXH1et'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/5wgQHQCjbvAyiddNhXH1et',
#         'id': '5wgQHQCjbvAyiddNhXH1et',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb8e478645a9d4ae60bd149f9d',
#             'width': None
#         }],
#         'name': 'brown vibes',
#         'owner': {
#             'display_name': 'suicide joe',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/fafa2n15993eymupnsi0732a1'
#             },
#             'href': 'https://api.spotify.com/v1/users/fafa2n15993eymupnsi0732a1',
#             'id': 'fafa2n15993eymupnsi0732a1',
#             'type': 'user',
#             'uri': 'spotify:user:fafa2n15993eymupnsi0732a1'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MzgyLDgwZjg0NGNiNmUzNzhmMDg1MGEyNGQ1N2U4NmNiNGNmMTZmNDg0OGQ=',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/5wgQHQCjbvAyiddNhXH1et/tracks',
#             'total': 374
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:5wgQHQCjbvAyiddNhXH1et'
#     }, {
#         'collaborative': False,
#         'description': 'Spotify Wrapped presents the songs that you loved most this year.',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/37i9dQZF1EUMDoJuT8yJsl'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EUMDoJuT8yJsl',
#         'id': '37i9dQZF1EUMDoJuT8yJsl',
#         'images': [{
#             'height': None,
#             'url': 'https://lineup-images.scdn.co/wrapped-2021-top100_LARGE-en.jpg',
#             'width': None
#         }],
#         'name': 'Your Top Songs 2021',
#         'owner': {
#             'display_name': 'Spotify',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/spotify'
#             },
#             'href': 'https://api.spotify.com/v1/users/spotify',
#             'id': 'spotify',
#             'type': 'user',
#             'uri': 'spotify:user:spotify'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MCwwMDAwMDAwMDc1NDkzMWZlOTVlZTM1ZGExMzg2NzNhZGE0NmQwM2Ey',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EUMDoJuT8yJsl/tracks',
#             'total': 100
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:37i9dQZF1EUMDoJuT8yJsl'
#     }, {
#         'collaborative': False,
#         'description': 'Essential tracks from the most notable classical works ever recorded - both old and new. Featuring Mozart, Beethoven, Bach, Chopin, Satie, Brahms, Vivaldi, Max Richter, '
#         'Ludovico Einaudi',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/1h0CEZCm6IbFTbxThn6Xcs'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/1h0CEZCm6IbFTbxThn6Xcs',
#         'id': '1h0CEZCm6IbFTbxThn6Xcs',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb4ed1546759ae6e2e1256cfb0',
#             'width': None
#         }],
#         'name': 'Best Classical Music',
#         'owner': {
#             'display_name': 'Peaceful Classics',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/peacefulclassics'
#             },
#             'href': 'https://api.spotify.com/v1/users/peacefulclassics',
#             'id': 'peacefulclassics',
#             'type': 'user',
#             'uri': 'spotify:user:peacefulclassics'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'OTE4LGFjMjJkNjcyMDRkOThiMTY4ZDI1ZWFmODNmMTM5MTA1NGMwMWQxZmQ=',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/1h0CEZCm6IbFTbxThn6Xcs/tracks',
#             'total': 184
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:1h0CEZCm6IbFTbxThn6Xcs'
#     }, {
#         'collaborative': False,
#         'description': 'woooahhhh yeahhhh woaaaaaaaaaaa haha yeahhhh my name is scott',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/5ytGiYp3leMjSJLwobwvZY'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/5ytGiYp3leMjSJLwobwvZY',
#         'id': '5ytGiYp3leMjSJLwobwvZY',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb5e501a5d44801966a0754d5e',
#             'width': None
#         }],
#         'name': 'aux',
#         'owner': {
#             'display_name': 'M',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/8j6p6n0zqh2c3yeu8afw4ro7t'
#             },
#             'href': 'https://api.spotify.com/v1/users/8j6p6n0zqh2c3yeu8afw4ro7t',
#             'id': '8j6p6n0zqh2c3yeu8afw4ro7t',
#             'type': 'user',
#             'uri': 'spotify:user:8j6p6n0zqh2c3yeu8afw4ro7t'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'Njg1LGZiZDIwN2FmOWJjNzM2NDkwYzExM2E5NGI0ZmJkMDgwZmEyNGNlZTY=',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/5ytGiYp3leMjSJLwobwvZY/tracks',
#             'total': 368
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:5ytGiYp3leMjSJLwobwvZY'
#     }, {
#         'collaborative': False,
#         'description': 'too underrated. @axel.tanner on IG',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/2726xBFbcKlJVpPODrlPVM'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/2726xBFbcKlJVpPODrlPVM',
#         'id': '2726xBFbcKlJVpPODrlPVM',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebba7c45dac9a65a6080c82ad74',
#             'width': None
#         }],
#         'name': 'hidden gems.',
#         'owner': {
#             'display_name': 'Axel Tanner',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/1298859216'
#             },
#             'href': 'https://api.spotify.com/v1/users/1298859216',
#             'id': '1298859216',
#             'type': 'user',
#             'uri': 'spotify:user:1298859216'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTUxNSw4ZDFlOWM0MTc5YzYwYmIwYTBjYWRmYWI0ZmEzZDk3OGMxMmViZGI4',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/2726xBFbcKlJVpPODrlPVM/tracks',
#             'total': 61
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:2726xBFbcKlJVpPODrlPVM'
#     }, {
#         'collaborative': False,
#         'description': '',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/3sVy6SwZxuvLHYSzdh4iOl'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/3sVy6SwZxuvLHYSzdh4iOl',
#         'id': '3sVy6SwZxuvLHYSzdh4iOl',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb115e02d3da9b831de1426f1d',
#             'width': None
#         }],
#         'name': '2010s rap',
#         'owner': {
#             'display_name': 'natalie',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/ndmiller06'
#             },
#             'href': 'https://api.spotify.com/v1/users/ndmiller06',
#             'id': 'ndmiller06',
#             'type': 'user',
#             'uri': 'spotify:user:ndmiller06'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'ODYsNDMyNzUzMjFjMDcxYmNiYmJiYWZlNGI4ODVkOTJiNzkyNTJkZWIwNA==',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/3sVy6SwZxuvLHYSzdh4iOl/tracks',
#             'total': 75
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:3sVy6SwZxuvLHYSzdh4iOl'
#     }, {
#         'collaborative': False,
#         'description': '',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/36oHhkDlAJ1DBUsOCgR9bn'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/36oHhkDlAJ1DBUsOCgR9bn',
#         'id': '36oHhkDlAJ1DBUsOCgR9bn',
#         'images': [{
#             'height': 640,
#             'url': 'https://mosaic.scdn.co/640/ab67616d0000b2738ac778cc7d88779f74d33311ab67616d0000b2739b9b36b0e22870b9f542d937ab67616d0000b273b33d46dfa2635a47eebf63b2ab67616d0000b273b98afa12c212cbbda4f1799b',
#             'width': 640
#         }, {
#             'height': 300,
#             'url': 'https://mosaic.scdn.co/300/ab67616d0000b2738ac778cc7d88779f74d33311ab67616d0000b2739b9b36b0e22870b9f542d937ab67616d0000b273b33d46dfa2635a47eebf63b2ab67616d0000b273b98afa12c212cbbda4f1799b',
#             'width': 300
#         }, {
#             'height': 60,
#             'url': 'https://mosaic.scdn.co/60/ab67616d0000b2738ac778cc7d88779f74d33311ab67616d0000b2739b9b36b0e22870b9f542d937ab67616d0000b273b33d46dfa2635a47eebf63b2ab67616d0000b273b98afa12c212cbbda4f1799b',
#             'width': 60
#         }],
#         'name': 'Vibezzz',
#         'owner': {
#             'display_name': 'Ike',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/y4yjmhqzanyc6musw2wjfi1hv'
#             },
#             'href': 'https://api.spotify.com/v1/users/y4yjmhqzanyc6musw2wjfi1hv',
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv',
#             'type': 'user',
#             'uri': 'spotify:user:y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTU3LGU5NDFiM2ViZWFkZmVkZGNhNTA4YzJmMWUyN2U4NDU3ZjIyYjk2NjQ=',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/36oHhkDlAJ1DBUsOCgR9bn/tracks',
#             'total': 148
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:36oHhkDlAJ1DBUsOCgR9bn'
#     }, {
#         'collaborative': False,
#         'description': 'The songs you loved most this year, all wrapped up.',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/37i9dQZF1ELWNwZdVoio5g'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1ELWNwZdVoio5g',
#         'id': '37i9dQZF1ELWNwZdVoio5g',
#         'images': [{
#             'height': None,
#             'url': 'https://lineup-images.scdn.co/wrapped-2020-top100_LARGE-en.jpg',
#             'width': None
#         }],
#         'name': 'Your Top Songs 2020',
#         'owner': {
#             'display_name': 'Spotify',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/spotify'
#             },
#             'href': 'https://api.spotify.com/v1/users/spotify',
#             'id': 'spotify',
#             'type': 'user',
#             'uri': 'spotify:user:spotify'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MjY3NzQ2NjMsMDAwMDAwMDAwODhhN2JjZmEyODczMjE5MTgzYzZhMDM1Y2RmYjg5NQ==',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1ELWNwZdVoio5g/tracks',
#             'total': 100
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:37i9dQZF1ELWNwZdVoio5g'
#     }, {
#         'collaborative': False,
#         'description': 'Songs you love right now',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/37i9dQZF1Epx0a0zRRF282'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1Epx0a0zRRF282',
#         'id': '37i9dQZF1Epx0a0zRRF282',
#         'images': [{
#             'height': None,
#             'url': 'https://daily-mix.scdn.co/covers/on_repeat/PZN_On_Repeat2_LARGE-en.jpg',
#             'width': None
#         }],
#         'name': 'On Repeat',
#         'owner': {
#             'display_name': 'Spotify',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/spotify'
#             },
#             'href': 'https://api.spotify.com/v1/users/spotify',
#             'id': 'spotify',
#             'type': 'user',
#             'uri': 'spotify:user:spotify'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTY3NTQwOTg2NCwwMDAwMDAwMGNlYjMyNzg0NDA4Mzg3MGQ0NWNmZGJmOGFjNWYxMjBh',
#         'tracks': {
# ...
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MzQ5LGMxMWVmZmZmMjY4MGI4OTM1YjRlOWYyNDVlZmNhYmIwNGEzODRlZGE=',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/7gB0tMdfZv0XEgrikdpDzt/tracks',
#             'total': 376
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:7gB0tMdfZv0XEgrikdpDzt'
#     }, {
#         'collaborative': False,
#         'description': 'The official playlist of <a href="https://www.youtube.com/c/LostFiction?sub_confirmation=1">Lost Fiction</a>. An assortment of relaxing beats and chill music. Genres: '
#         'study music, lofi, chillhop, lo-fi beats. ',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/6hvW8ln3ApfzvDlYkrHmjA'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/6hvW8ln3ApfzvDlYkrHmjA',
#         'id': '6hvW8ln3ApfzvDlYkrHmjA',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebbdb24db8c13ab7917514514ed',
#             'width': None
#         }],
#         'name': 'Lofi Music | Study Playlist 2022',
#         'owner': {
#             'display_name': 'Lost Fiction',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/i9ijw1u2ev5az26152e08obd7'
#             },
#             'href': 'https://api.spotify.com/v1/users/i9ijw1u2ev5az26152e08obd7',
#             'id': 'i9ijw1u2ev5az26152e08obd7',
#             'type': 'user',
#             'uri': 'spotify:user:i9ijw1u2ev5az26152e08obd7'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MjcwMyw2MTNjMjg3MGZkYWRiY2Q2ZTRkNDk1NDk1MzIyM2NhYmE5MGE2MGE3',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/6hvW8ln3ApfzvDlYkrHmjA/tracks',
#             'total': 194
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:6hvW8ln3ApfzvDlYkrHmjA'
#     }, {
#         'collaborative': False,
#         'description': 'Weekly selection of the best relaxing lofi hip hop beats for the perfect chill session - best lofi cover playlist - best lofi songs - lofi hip hop playlist - best study '
#         'music - lofi remix playlist - relaxing beats playlist - chill beats playlist - lofi fruits music - best instrumental beats',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/3LFIBdP7eZXJKqf3guepZ1'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/3LFIBdP7eZXJKqf3guepZ1',
#         'id': '3LFIBdP7eZXJKqf3guepZ1',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb09b238de88c19f52bccb491e',
#             'width': None
#         }],
#         'name': 'Lofi Fruits Music - lofi hip hop beats to study, relax & sleep to',
#         'owner': {
#             'display_name': 'Fruits Music',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/a902190'
#             },
#             'href': 'https://api.spotify.com/v1/users/a902190',
#             'id': 'a902190',
#             'type': 'user',
#             'uri': 'spotify:user:a902190'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'NjY3Myw1MjVmYmQ4ODkyMDNkODFkYzQ2ZWQwZWZmYjcyN2U2NTNhMTJhODQ5',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/3LFIBdP7eZXJKqf3guepZ1/tracks',
#             'total': 456
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:3LFIBdP7eZXJKqf3guepZ1'
#     }, {
#         'collaborative': False,
#         'description': '',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/37i9dQZF1E8L5dvOJWfsY5'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1E8L5dvOJWfsY5',
#         'id': '37i9dQZF1E8L5dvOJWfsY5',
#         'images': [{
#             'height': None,
#             'url': 'https://seeded-session-images.scdn.co/v1/img/track/45Ln3F9PRPYTXBcMFkZMzS/en',
#             'width': None
#         }],
#         'name': 'R.I.P. Fredo (feat. Young Nudy) - Notice Me Radio',
#         'owner': {
#             'display_name': 'Spotify',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/spotify'
#             },
#             'href': 'https://api.spotify.com/v1/users/spotify',
#             'id': 'spotify',
#             'type': 'user',
#             'uri': 'spotify:user:spotify'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTY3NTQ0MjM5NSwwMDAwMDAwMDllNjM1YjMxYzkxMTE4NGQ3MmU1YzZhYTU2NjJhY2Fl',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1E8L5dvOJWfsY5/tracks',
#             'total': 50
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:37i9dQZF1E8L5dvOJWfsY5'
#     }, {
#         'collaborative': False,
#         'description': 'The songs you loved most this year, all wrapped up.',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/37i9dQZF1EtmZDybMAZ0Kt'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EtmZDybMAZ0Kt',
#         'id': '37i9dQZF1EtmZDybMAZ0Kt',
#         'images': [{
#             'height': None,
#             'url': 'https://lineup-images.scdn.co/your-top-songs-2019_LARGE-en.jpg',
#             'width': None
#         }],
#         'name': 'Your Top Songs 2019',
#         'owner': {
#             'display_name': 'Spotify',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/spotify'
#             },
#             'href': 'https://api.spotify.com/v1/users/spotify',
#             'id': 'spotify',
#             'type': 'user',
#             'uri': 'spotify:user:spotify'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MjYyNjk2MzYsMDAwMDAwMDA3MzBmMDFmNjg1YWIxMDFjZmJiNzhkMTY4YTk5ODRjYw==',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EtmZDybMAZ0Kt/tracks',
#             'total': 100
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:37i9dQZF1EtmZDybMAZ0Kt'
#     }, {
#         'collaborative': False,
#         'description': '',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/6Du1ICnVsDtlaZdLMn7ebG'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/6Du1ICnVsDtlaZdLMn7ebG',
#         'id': '6Du1ICnVsDtlaZdLMn7ebG',
#         'images': [{
#             'height': 640,
#             'url': 'https://i.scdn.co/image/ab67616d0000b273f4ca75192df162f78a24023e',
#             'width': 640
#         }],
#         'name': 'Hhh',
#         'owner': {
#             'display_name': 'Ike',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/y4yjmhqzanyc6musw2wjfi1hv'
#             },
#             'href': 'https://api.spotify.com/v1/users/y4yjmhqzanyc6musw2wjfi1hv',
#             'id': 'y4yjmhqzanyc6musw2wjfi1hv',
#             'type': 'user',
#             'uri': 'spotify:user:y4yjmhqzanyc6musw2wjfi1hv'
#         },
#         'primary_color': None,
#         'public': True,
#         'snapshot_id': 'NCxlNzNjMjJhMDFlZjg1MjA1OTNjMjMwNWFjZjE4OTZhNGVkN2RmMWNm',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/6Du1ICnVsDtlaZdLMn7ebG/tracks',
#             'total': 3
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:6Du1ICnVsDtlaZdLMn7ebG'
#     }, {
#         'collaborative': False,
#         'description': 'Concentration & Motivation! Focus-enhancing piano music for your study session.',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX8NTLI2TtZa6'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX8NTLI2TtZa6',
#         'id': '37i9dQZF1DX8NTLI2TtZa6',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706f0000000346bd1bd5d9990da7dae58ccc',
#             'width': None
#         }],
#         'name': 'Intense Studying',
#         'owner': {
#             'display_name': 'Spotify',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/spotify'
#             },
#             'href': 'https://api.spotify.com/v1/users/spotify',
#             'id': 'spotify',
#             'type': 'user',
#             'uri': 'spotify:user:spotify'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTY3NDc0MTIyNSwwMDAwMDAwMDM0NjlkYTdiNjRmN2I5OTI5YjU3NjhlNDkxOGQ3ZGIz',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX8NTLI2TtZa6/tracks',
#             'total': 204
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:37i9dQZF1DX8NTLI2TtZa6'
#     }, {
#         'collaborative': False,
#         'description': 'Camp 2018 Playlist',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/0JUnWRE2UPOTZvZnccFSzD'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/0JUnWRE2UPOTZvZnccFSzD',
#         'id': '0JUnWRE2UPOTZvZnccFSzD',
#         'images': [{
#             'height': 640,
#             'url': 'https://mosaic.scdn.co/640/ab67616d0000b27306bd66a29e6b4b22d3c63b8dab67616d0000b273091000c522ec46e10b6bdcf5ab67616d0000b273756031279f394f4db151063cab67616d0000b273bf51145c8eb220ac584cd0a8',
#             'width': 640
#         }, {
#             'height': 300,
#             'url': 'https://mosaic.scdn.co/300/ab67616d0000b27306bd66a29e6b4b22d3c63b8dab67616d0000b273091000c522ec46e10b6bdcf5ab67616d0000b273756031279f394f4db151063cab67616d0000b273bf51145c8eb220ac584cd0a8',
#             'width': 300
#         }, {
#             'height': 60,
#             'url': 'https://mosaic.scdn.co/60/ab67616d0000b27306bd66a29e6b4b22d3c63b8dab67616d0000b273091000c522ec46e10b6bdcf5ab67616d0000b273756031279f394f4db151063cab67616d0000b273bf51145c8eb220ac584cd0a8',
#             'width': 60
#         }],
#         'name': 'Camp Playlist 3.0',
#         'owner': {
#             'display_name': 'Aaron Ninaber',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/1252012643'
#             },
#             'href': 'https://api.spotify.com/v1/users/1252012643',
#             'id': '1252012643',
#             'type': 'user',
#             'uri': 'spotify:user:1252012643'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MjMsNzkzMmJiZTY0NTg5YzIwOWI4MTc4YzUxYmQ1MDhlMjkyYzE2YmIxMg==',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/0JUnWRE2UPOTZvZnccFSzD/tracks',
#             'total': 20
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:0JUnWRE2UPOTZvZnccFSzD'
#     }, {
#         'collaborative': False,
#         'description': '',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/2yKYu70G2TLGoEuU1zR4CL'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/2yKYu70G2TLGoEuU1zR4CL',
#         'id': '2yKYu70G2TLGoEuU1zR4CL',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb2c52ac5b9ba1bf3dd88f4543',
#             'width': None
#         }],
#         'name': 'Guadians Of the Galaxy Vol. 1 & 2',
#         'owner': {
#             'display_name': 'James',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/thepetersparks'
#             },
#             'href': 'https://api.spotify.com/v1/users/thepetersparks',
#             'id': 'thepetersparks',
#             'type': 'user',
#             'uri': 'spotify:user:thepetersparks'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MzEsY2Y4Mjk0MWUxOWE4ZTAwM2YwMmM0NThjOTUwYjhiNjBhMjM3MmM1Mg==',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/2yKYu70G2TLGoEuU1zR4CL/tracks',
#             'total': 25
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:2yKYu70G2TLGoEuU1zR4CL'
#     }, {
#         'collaborative': False,
#         'description': 'Enter WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXcf5pLcPbTwK'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcf5pLcPbTwK',
#         'id': '37i9dQZF1DXcf5pLcPbTwK',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706f00000003327728ac9cde9d5d4d11e868',
#             'width': None
#         }],
#         'name': 'Billie Eilish Experience',
#         'owner': {
#             'display_name': 'Spotify',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/spotify'
#             },
#             'href': 'https://api.spotify.com/v1/users/spotify',
#             'id': 'spotify',
#             'type': 'user',
#             'uri': 'spotify:user:spotify'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTYwNTIwNDgxNSwwMDAwMDAwMDIzMzE0MDNhYzhmMzI2MDEwNThlNGRhNDhlMjEyYzQw',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcf5pLcPbTwK/tracks',
#             'total': 21
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:37i9dQZF1DXcf5pLcPbTwK'
#     }, {
#         'collaborative': False,
#         'description': 'All things Billie!',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX6cg4h2PoN9y'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX6cg4h2PoN9y',
#         'id': '37i9dQZF1DX6cg4h2PoN9y',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706f00000003df12c206fd3c49ad933943f3',
#             'width': None
#         }],
#         'name': 'This Is Billie Eilish',
#         'owner': {
#             'display_name': 'Spotify',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/spotify'
#             },
#             'href': 'https://api.spotify.com/v1/users/spotify',
#             'id': 'spotify',
#             'type': 'user',
#             'uri': 'spotify:user:spotify'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'MTY3MTE2Njg2MCwwMDAwMDAwMGVkNDRhNGEzYmJiN2YxMmM2NDM5M2QwNDBjZDYxMzU2',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX6cg4h2PoN9y/tracks',
#             'total': 59
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:37i9dQZF1DX6cg4h2PoN9y'
#     }, {
#         'collaborative': False,
#         'description': 'Songs used in MKBHD videos. Starting in 2019.',
#         'external_urls': {
#             'spotify': 'https://open.spotify.com/playlist/0ZXVX604hmghJgqWCMsqcU'
#         },
#         'href': 'https://api.spotify.com/v1/playlists/0ZXVX604hmghJgqWCMsqcU',
#         'id': '0ZXVX604hmghJgqWCMsqcU',
#         'images': [{
#             'height': None,
#             'url': 'https://i.scdn.co/image/ab67706c0000bebb3e92c22d045bbe6f5e381815',
#             'width': None
#         }],
#         'name': 'MKBHD Videos',
#         'owner': {
#             'display_name': 'Marques Brownlee',
#             'external_urls': {
#                 'spotify': 'https://open.spotify.com/user/mkbhd'
#             },
#             'href': 'https://api.spotify.com/v1/users/mkbhd',
#             'id': 'mkbhd',
#             'type': 'user',
#             'uri': 'spotify:user:mkbhd'
#         },
#         'primary_color': None,
#         'public': False,
#         'snapshot_id': 'NTcsZGI0OWViNzllZmYwYzJhZWU2NTUwNDFkMDhiZTU1YjkzNzM2OTUwOA==',
#         'tracks': {
#             'href': 'https://api.spotify.com/v1/playlists/0ZXVX604hmghJgqWCMsqcU/tracks',
#             'total': 52
#         },
#         'type': 'playlist',
#         'uri': 'spotify:playlist:0ZXVX604hmghJgqWCMsqcU'
#     }],
#     'limit': 50,
#     'next': 'https://api.spotify.com/v1/users/y4yjmhqzanyc6musw2wjfi1hv/playlists?offset=50&limit=50',
#     'offset': 0,
#     'previous': None,
#     'total': 66
# }

# %%
# user_playlists = []
# for item in response['items']:
#     temp = {item['name']: item['id']}
#     user_playlists.append(temp)

# if response
    
# print(user_playlists)
sc.clear_user_playlists()
q = sc.list_user_playlists(response)
#print(q)
pd(q)
# Out:
# [{
#     'name': 'Kendrick Lamar : Ike',
#     'id': '34JGK4rI5BZWq99VrYVjKt',
#     'uri': 'spotify:playlist:34JGK4rI5BZWq99VrYVjKt'
# }, {
#     'name': 'Joy Crookes : Ike',
#     'id': '4ftmFe65df4SyGZIwpkzJ5',
#     'uri': 'spotify:playlist:4ftmFe65df4SyGZIwpkzJ5'
# }, {
#     'name': 'LBST 2301 Spring 2023 Mixtape',
#     'id': '6MdRu5XF7TyJzN5ccBjgpf',
#     'uri': 'spotify:playlist:6MdRu5XF7TyJzN5ccBjgpf'
# }, {
#     'name': 'Drake : Ike',
#     'id': '5bafUXvO08JfyfLbkrY8dk',
#     'uri': 'spotify:playlist:5bafUXvO08JfyfLbkrY8dk'
# }, {
#     'name': 'Joy Crookes - The Complete Collection',
#     'id': '1PT1LcejkMGoGsmKzkBKax',
#     'uri': 'spotify:playlist:1PT1LcejkMGoGsmKzkBKax'
# }, {
#     'name': 'Japanese City Pop',
#     'id': '7H0gvTCkCh9vA8gw1mcNVd',
#     'uri': 'spotify:playlist:7H0gvTCkCh9vA8gw1mcNVd'
# }, {
#     'name': 'Your Top Songs 2022',
#     'id': '37i9dQZF1F0sijgNaJdgit',
#     'uri': 'spotify:playlist:37i9dQZF1F0sijgNaJdgit'
# }, {
#     'name': 'Black Panther Official Playlist',
#     'id': '37i9dQZF1DX6tq7CPNyNEM',
#     'uri': 'spotify:playlist:37i9dQZF1DX6tq7CPNyNEM'
# }, {
#     'name': 'Calisthenics x Gymtok',
#     'id': '06wrErgQDANLAeVl2NR6NY',
#     'uri': 'spotify:playlist:06wrErgQDANLAeVl2NR6NY'
# }, {
#     'name': 'Synthwave type',
#     'id': '4myVDdbRXNQ8Hu8pQheSMN',
#     'uri': 'spotify:playlist:4myVDdbRXNQ8Hu8pQheSMN'
# }, {
#     'name': 'Gym Phonk 🔱',
#     'id': '1sgNK6s1Gk4kZEOTKPd72X',
#     'uri': 'spotify:playlist:1sgNK6s1Gk4kZEOTKPd72X'
# }, {
#     'name': '',
#     'id': '5fkFpkHk4MaRyNeeXpYd30',
#     'uri': 'spotify:playlist:5fkFpkHk4MaRyNeeXpYd30'
# }, {
#     'name': 'Locked In',
#     'id': '37i9dQZF1DWTl4y3vgJOXW',
#     'uri': 'spotify:playlist:37i9dQZF1DWTl4y3vgJOXW'
# }, {
#     'name': 'new new',
#     'id': '6MPrkSvuZQnQvITxJLr703',
#     'uri': 'spotify:playlist:6MPrkSvuZQnQvITxJLr703'
# }, {
#     'name': 'SES Hackathon',
#     'id': '3OX1Mbdhbadze6rcNS41eM',
#     'uri': 'spotify:playlist:3OX1Mbdhbadze6rcNS41eM'
# }, {
#     'name': 'FEELING DISRESPECTFUL😈😈',
#     'id': '25DpSFEJ7zeAy6uGWOjlFo',
#     'uri': 'spotify:playlist:25DpSFEJ7zeAy6uGWOjlFo'
# }, {
#     'name': 'dreaming of summer in Brazil ',
#     'id': '52heXxEn3Cdn6ofhR3nObo',
#     'uri': 'spotify:playlist:52heXxEn3Cdn6ofhR3nObo'
# }, {
#     'name': 'gym sends (happy/upbeat)',
#     'id': '4HUido35wAtbof2YMZ7bSQ',
#     'uri': 'spotify:playlist:4HUido35wAtbof2YMZ7bSQ'
# }, {
#     'name': 'gym sends (sad)',
#     'id': '0LY0evTkp87qtw1dRCbe97',
#     'uri': 'spotify:playlist:0LY0evTkp87qtw1dRCbe97'
# }, {
#     'name': 'gym sends (angry)',
#     'id': '5BVHoZKG1wjPfBJ6RUAlJG',
#     'uri': 'spotify:playlist:5BVHoZKG1wjPfBJ6RUAlJG'
# }, {
#     'name': 'gym sends (chill)',
#     'id': '77kgw7u48un9NkozrxouOg',
#     'uri': 'spotify:playlist:77kgw7u48un9NkozrxouOg'
# }, {
#     'name': 'gym sends',
#     'id': '6ojl7MOYEjFOmM5syFrQXX',
#     'uri': 'spotify:playlist:6ojl7MOYEjFOmM5syFrQXX'
# }, {
#     'name': '~',
#     'id': '0ef2FFJmYlAiXtDFsEaOYt',
#     'uri': 'spotify:playlist:0ef2FFJmYlAiXtDFsEaOYt'
# }, {
#     'name': 'brown vibes',
#     'id': '5wgQHQCjbvAyiddNhXH1et',
#     'uri': 'spotify:playlist:5wgQHQCjbvAyiddNhXH1et'
# }, {
#     'name': 'Your Top Songs 2021',
#     'id': '37i9dQZF1EUMDoJuT8yJsl',
#     'uri': 'spotify:playlist:37i9dQZF1EUMDoJuT8yJsl'
# }, {
#     'name': 'Best Classical Music',
#     'id': '1h0CEZCm6IbFTbxThn6Xcs',
#     'uri': 'spotify:playlist:1h0CEZCm6IbFTbxThn6Xcs'
# }, {
#     'name': 'aux',
#     'id': '5ytGiYp3leMjSJLwobwvZY',
#     'uri': 'spotify:playlist:5ytGiYp3leMjSJLwobwvZY'
# }, {
#     'name': 'hidden gems.',
#     'id': '2726xBFbcKlJVpPODrlPVM',
#     'uri': 'spotify:playlist:2726xBFbcKlJVpPODrlPVM'
# }, {
#     'name': '2010s rap',
#     'id': '3sVy6SwZxuvLHYSzdh4iOl',
#     'uri': 'spotify:playlist:3sVy6SwZxuvLHYSzdh4iOl'
# }, {
#     'name': 'Vibezzz',
#     'id': '36oHhkDlAJ1DBUsOCgR9bn',
#     'uri': 'spotify:playlist:36oHhkDlAJ1DBUsOCgR9bn'
# }, {
#     'name': 'Your Top Songs 2020',
#     'id': '37i9dQZF1ELWNwZdVoio5g',
#     'uri': 'spotify:playlist:37i9dQZF1ELWNwZdVoio5g'
# }, {
#     'name': 'On Repeat',
#     'id': '37i9dQZF1Epx0a0zRRF282',
#     'uri': 'spotify:playlist:37i9dQZF1Epx0a0zRRF282'
# }, {
#     'name': 'Hype Christian Rap 🔥',
#     'id': '6NDHIP1IH6pbvpfULnjDqo',
#     'uri': 'spotify:playlist:6NDHIP1IH6pbvpfULnjDqo'
# }, {
#     'name': 'New Music Friday',
#     'id': '37i9dQZF1DX4JAvHpjipBk',
#     'uri': 'spotify:playlist:37i9dQZF1DX4JAvHpjipBk'
# }, {
#     'name': 'IGNITED VIBECHECK',
#     'id': '2b8tD6ixBKq1z9QTuJs40D',
#     'uri': 'spotify:playlist:2b8tD6ixBKq1z9QTuJs40D'
# }, {
#     'name': 'Songs to bump on your way to the rapture!!!',
#     'id': '1bIeEMLGRzYCOHn8nuDV1M',
#     'uri': 'spotify:playlist:1bIeEMLGRzYCOHn8nuDV1M'
# }, {
#     'name': 'Christian Get up and dance ',
#     'id': '3Y7C7KzCLrwAB9BFS9iAPH',
#     'uri': 'spotify:playlist:3Y7C7KzCLrwAB9BFS9iAPH'
# }, {
#     'name': 'Straight Outta Bethlehem',
#     'id': '13vhXXbyUbTx5jAGpOOsuS',
#     'uri': 'spotify:playlist:13vhXXbyUbTx5jAGpOOsuS'
# }, {
#     'name': 'All around Christian',
#     'id': '7gB0tMdfZv0XEgrikdpDzt',
#     'uri': 'spotify:playlist:7gB0tMdfZv0XEgrikdpDzt'
# }, {
#     'name': 'Lofi Music | Study Playlist 2022',
#     'id': '6hvW8ln3ApfzvDlYkrHmjA',
#     'uri': 'spotify:playlist:6hvW8ln3ApfzvDlYkrHmjA'
# }, {
#     'name': 'Lofi Fruits Music - lofi hip hop beats to study, relax & sleep to',
#     'id': '3LFIBdP7eZXJKqf3guepZ1',
#     'uri': 'spotify:playlist:3LFIBdP7eZXJKqf3guepZ1'
# }, {
#     'name': 'R.I.P. Fredo (feat. Young Nudy) - Notice Me Radio',
#     'id': '37i9dQZF1E8L5dvOJWfsY5',
#     'uri': 'spotify:playlist:37i9dQZF1E8L5dvOJWfsY5'
# }, {
#     'name': 'Your Top Songs 2019',
#     'id': '37i9dQZF1EtmZDybMAZ0Kt',
#     'uri': 'spotify:playlist:37i9dQZF1EtmZDybMAZ0Kt'
# }, {
#     'name': 'Hhh',
#     'id': '6Du1ICnVsDtlaZdLMn7ebG',
#     'uri': 'spotify:playlist:6Du1ICnVsDtlaZdLMn7ebG'
# }, {
#     'name': 'Intense Studying',
#     'id': '37i9dQZF1DX8NTLI2TtZa6',
#     'uri': 'spotify:playlist:37i9dQZF1DX8NTLI2TtZa6'
# }, {
#     'name': 'Camp Playlist 3.0',
#     'id': '0JUnWRE2UPOTZvZnccFSzD',
#     'uri': 'spotify:playlist:0JUnWRE2UPOTZvZnccFSzD'
# }, {
#     'name': 'Guadians Of the Galaxy Vol. 1 & 2',
#     'id': '2yKYu70G2TLGoEuU1zR4CL',
#     'uri': 'spotify:playlist:2yKYu70G2TLGoEuU1zR4CL'
# }, {
#     'name': 'Billie Eilish Experience',
#     'id': '37i9dQZF1DXcf5pLcPbTwK',
#     'uri': 'spotify:playlist:37i9dQZF1DXcf5pLcPbTwK'
# }, {
#     'name': 'This Is Billie Eilish',
#     'id': '37i9dQZF1DX6cg4h2PoN9y',
#     'uri': 'spotify:playlist:37i9dQZF1DX6cg4h2PoN9y'
# }, {
#     'name': 'MKBHD Videos',
#     'id': '0ZXVX604hmghJgqWCMsqcU',
#     'uri': 'spotify:playlist:0ZXVX604hmghJgqWCMsqcU'
# }, {
#     'name': "Today's Top Hits",
#     'id': '37i9dQZF1DXcBWIGoYBM5M',
#     'uri': 'spotify:playlist:37i9dQZF1DXcBWIGoYBM5M'
# }, {
#     'name': 'Old School',
#     'id': '4R2wevjhrGXkvDxFrczsj2',
#     'uri': 'spotify:playlist:4R2wevjhrGXkvDxFrczsj2'
# }, {
#     'name': 'Hot Rhythmic',
#     'id': '37i9dQZF1DWYs83FtTMQFw',
#     'uri': 'spotify:playlist:37i9dQZF1DWYs83FtTMQFw'
# }, {
#     'name': 'Party Hits',
#     'id': '37i9dQZF1DXa2PvUpywmrr',
#     'uri': 'spotify:playlist:37i9dQZF1DXa2PvUpywmrr'
# }, {
#     'name': 'Coffee Table Jazz',
#     'id': '37i9dQZF1DWVqfgj8NZEp1',
#     'uri': 'spotify:playlist:37i9dQZF1DWVqfgj8NZEp1'
# }, {
#     'name': 'Top Christian Hits',
#     'id': '1KRZH6WH8qYgaVnagjjOFV',
#     'uri': 'spotify:playlist:1KRZH6WH8qYgaVnagjjOFV'
# }, {
#     'name': 'Liked from Radio',
#     'id': '5rMYcR8zz4P82aRdgwUGiV',
#     'uri': 'spotify:playlist:5rMYcR8zz4P82aRdgwUGiV'
# }, {
#     'name': 'Chilled Pop',
#     'id': '4HnOH3VfJCN7HTD0L1sor7',
#     'uri': 'spotify:playlist:4HnOH3VfJCN7HTD0L1sor7'
# }, {
#     'name': 'Iff',
#     'id': '6BKLQbuco1PZ26XLR1ROew',
#     'uri': 'spotify:playlist:6BKLQbuco1PZ26XLR1ROew'
# }, {
#     'name': "Official Why Don't We Playlist",
#     'id': '48JGTYsigQdHKgNEDvlIvX',
#     'uri': 'spotify:playlist:48JGTYsigQdHKgNEDvlIvX'
# }, {
#     'name': 'K-Pop Hits 2023',
#     'id': '7JXJKP3xMvIMbEBBGApTPQ',
#     'uri': 'spotify:playlist:7JXJKP3xMvIMbEBBGApTPQ'
# }, {
#     'name': 'Let the Trap Say Amen',
#     'id': '0HpSR7c0eRVVzzso0X7Rq1',
#     'uri': 'spotify:playlist:0HpSR7c0eRVVzzso0X7Rq1'
# }, {
#     'name': 'Ike Special',
#     'id': '1pe6PfRVXasdpG2vIIVrl8',
#     'uri': 'spotify:playlist:1pe6PfRVXasdpG2vIIVrl8'
# }, {
#     'name': 'My Shazam Tracks',
#     'id': '5zEuy12dOWWqcvSCO86Pzj',
#     'uri': 'spotify:playlist:5zEuy12dOWWqcvSCO86Pzj'
# }, {
#     'name': 'Power Gaming',
#     'id': '37i9dQZF1DX6taq20FeuKj',
#     'uri': 'spotify:playlist:37i9dQZF1DX6taq20FeuKj'
# }, {
#     'name': 'Ike',
#     'id': '6AAW33WKzlJaN0JMqjC3xC',
#     'uri': 'spotify:playlist:6AAW33WKzlJaN0JMqjC3xC'
# }]

# %%
x=1
for i in sc.user_playlists:
    print(str(x) + '.', i)
    x+=1

# %%
#Search for artist fuctionality and parsing
j = sc.search('Drake', search_type='artist')
#print(j)
#Printing names and ids
print((j['artists']['items'][0]['name'])+ ':',(j['artists']['items'][0]['id']))

search_list = []
for i in range(6):
    q = {'name' : j['artists']['items'][i]['name'],
        'id' : j['artists']['items'][i]['id']
        }
    #q = {(j['artists']['items'][i]['name']) : (j['artists']['items'][i]['id'])}
    search_list.append(q)
#print(search_list)
pd(search_list)
# target_artist_id = list(search_list[0].values())[0] 
# target_artist_id
target_artist_id = search_list[0]['id']
target_artist_id

# %%
#get playlist fuctionality
playlist_items_response = sc.get_playlist_items(playlist_id='6AAW33WKzlJaN0JMqjC3xC')
#print(playlist_items_response)
pd(playlist_items_response)

# %%
# #Parsing playlist functionality

# target_playlist_items = []
# for item in playlist_items_response['items']:
#     artists = []
#     for i in item['track']['artists']:
#         w = {'name' : i['name'],
#              'id' : i['id']
#             }
#         #w = {i['name'] : i['id']}
#         artists.append(w)
        
#     q = {'song_name' : item['track']['name'], 'id' : item['track']['id'],
#                                   'artists' : artists }
#     target_playlist_items.append(q)

# #print(target_playlist_items)
# pd(target_playlist_items)

sc.clear_playlist_items()
rep = sc.parse_playlist_items(playlist_items_response)
#pd(rep)

# %%
#create the list of songs containing the target artist
target_artist_id
target_songs = []
for x in rep:
    for i in x['artists']:
        if i['id'] == target_artist_id:
            target_songs.append(x)
            break

#pd(target_songs)

#create a list of the uris of the target songs
target_songs_uri = []
for i in target_songs:
    target_songs_uri.append(i['uri'])
print(target_songs_uri)

# %%
# (self, resource_type='users', version='v1', user_id='null', 
#                         name=None, description='', public=False, artist=None, playlist_name=None)
cplay = sc.create_playlist(user_id=user_info['id'],description='A playlist of Drake songs in IKE playlist', artist='Drake', playlist_name='Ike')
cplay

# %%
#add_song_to_playlist(self, resource_type='playlists', version='v1', uri_list=None, playlist_id=None)
done = sc.add_song_to_playlist(uri_list=target_songs_uri, playlist_id=cplay['id'])
print(done)
